# %%
# %pip install --upgrade pip
# %pip install pandas
# %pip install scikit-learn
# %pip install tensorflow
# %pip install keras
# %pip install matplotlib
# %pip install ipympl

# %%
import os
import tensorflow as tf 
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Input
from tensorflow.keras.models import load_model
from keras.callbacks import EarlyStopping
from keras import metrics
from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from tensorflow.keras import backend as K
from tensorflow.keras.optimizers import Nadam
import gc
import pickle
import pandas as pd
import numpy as np
# %matplotlib inline
# %matplotlib widget
import matplotlib.pyplot as plt

# %% [markdown]
# ## Lista de hardware para IA

# %%
from tensorflow.python.client import device_lib

print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 9475948968668263552
# xla_global_id: -1
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 10182721536
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 5673593656181228762
# physical_device_desc: "device: 0, name: NVIDIA GeForce RTX 3060, pci bus id: 0000:01:00.0, compute capability: 8.6"
# xla_global_id: 416903419
# ]

# %% [markdown]
# Carregando os dados do sensor 1

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.19.0

# %%
# Carregar os dados do arquivo
file_path = './Dados/dados.txt'
df = pd.read_csv(file_path, header=None, names=['X', 'Y', 'Z'])
df = df[1300:1300000]
# df = df[200000:1300000]
print(len(df))
print(df[:10])
# Out:
# I0000 00:00:1756079876.760608  763927 gpu_device.cc:2019] Created device /device:GPU:0 with 9711 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060, pci bus id: 0000:01:00.0, compute capability: 8.6
# 1298700
#              X         Y          Z
# 1300 -1.781370  0.741914 -64.231506
# 1301 -1.694854  0.759592 -64.239250
# 1302 -1.597467  0.700346 -64.256279
# 1303 -1.739162  0.631860 -64.236961
# 1304 -1.736698  0.634045 -64.259636
# 1305 -1.734998  0.728971 -64.111877
# 1306 -1.678491  0.770313 -64.238266
# 1307 -1.692173  0.711976 -64.377014
# 1308 -1.698621  0.677731 -64.420242
# 1309 -1.707504  0.719441 -64.463936

# %%
print(f"Intervalo X: {df['X'].min()} a {df['X'].max()}")
print(f"Intervalo Y: {df['Y'].min()} a {df['Y'].max()}")
print(f"Intervalo Z: {df['Z'].min()} a {df['Z'].max()}")


# Supondo que 'df' é seu DataFrame original com as colunas 'X', 'Y', 'Z'
plt.figure(figsize=(12, 6))

# Plotando cada coluna
plt.subplot(3, 1, 1)  # 3 linhas, 1 coluna, posição 1
plt.plot(df['X'], label='X')
plt.title('Sensor Data - X')
plt.ylabel('X')

plt.subplot(3, 1, 2)  # 3 linhas, 1 coluna, posição 2
plt.plot(df['Y'], label='Y')
plt.title('Sensor Data - Y')
plt.ylabel('Y')

plt.subplot(3, 1, 3)  # 3 linhas, 1 coluna, posição 3
plt.plot(df['Z'], label='Z')
plt.title('Sensor Data - Z')
plt.ylabel('Z')
plt.xlabel('Sample Number')

# Mostrando o gráfico
plt.tight_layout()
plt.show()
# Out:
# Intervalo X: -16.6888427734375 a 34.93269729614258
# Intervalo Y: -7.707679748535156 a 5.511822700500488
# Intervalo Z: -72.52067565917969 a -27.74943351745605

# %% [markdown]
# ### Retirando os outliers

# %%
def remove_outliers_rolling_mad(df, columns, window=2000, k=15):
    mask_all = pd.Series(True, index=df.index)
    for col in columns:
        med = df[col].rolling(window, center=True).median()
        mad = (df[col] - med).abs().rolling(window, center=True).median() * 1.4826
        mask = ((df[col] - med).abs() <= k*mad).fillna(True)
        mask_all &= mask
    return df[mask_all]
# se k menor = mais agressivo
df_cleaned = remove_outliers_rolling_mad(df, ['X','Y','Z'], window=5000, k=15)
# Exibir as primeiras linhas do DataFrame limpo
print(df_cleaned.head())
# Out:
#              X         Y          Z
# 6300 -1.728978  0.804295 -64.236565
# 6301 -1.727947  0.823530 -64.243980
# 6302 -1.688770  0.835619 -64.357346
# 6303 -1.690171  0.833158 -64.411293
# 6304 -1.710678  0.793233 -64.402336

# %%
print(f"Intervalo X: {df_cleaned['X'].min()} a {df_cleaned['X'].max()}")
print(f"Intervalo Y: {df_cleaned['Y'].min()} a {df_cleaned['Y'].max()}")
print(f"Intervalo Z: {df_cleaned['Z'].min()} a {df_cleaned['Z'].max()}")

plt.figure(figsize=(12, 6))

# Plotar os dados após a remoção de outliers
plt.subplot(3, 1, 1)
plt.plot(df_cleaned['X'], label='X')
plt.title('Sensor Data - X (Sem Outliers)')
plt.ylabel('X')

plt.subplot(3, 1, 2)
plt.plot(df_cleaned['Y'], label='Y')
plt.title('Sensor Data - Y (Sem Outliers)')
plt.ylabel('Y')

plt.subplot(3, 1, 3)
plt.plot(df_cleaned['Z'], label='Z')
plt.title('Sensor Data - Z (Sem Outliers)')
plt.ylabel('Z')
plt.xlabel('Sample Number')

plt.tight_layout()
plt.show()
# Out:
# Intervalo X: -11.215195655822754 a 34.41769027709961
# Intervalo Y: -3.481569766998291 a 3.189526319503784
# Intervalo Z: -72.52067565917969 a -58.70037460327149

# %% [markdown]
# # POR ENQUANDO IGNORE A RETIRADA DOS OUTLIERS

# %%
# COMENTEQUE QUISER QUE IGNORE A RETIRADA DOS OUTLIERS
df=df_cleaned

# %% [markdown]
# ## Normalizando os dados para uso do LSTM

# %%
# Definindo o range para -1 a 1, apropriado para sensores com valores entre -180 e 180
# scaler = MinMaxScaler(feature_range=(-1, 1))
# scaler = StandardScaler()

# Normalizando os dados
# df_scaled = pd.DataFrame(scaler.fit_transform(df), columns=df.columns)

# Salvando o scaler ajustado
# with open('scaler.pkl', 'wb') as f:
#     pickle.dump(scaler, f)

# Visualizando os primeiros dados normalizados
# print(df_scaled.head())
def normalizar_eixos_independente(dataframe):
    """
    Normaliza as colunas 'X', 'Y' e 'Z' de um DataFrame individualmente 
    com MinMaxScaler no intervalo (-1, 1).

    Retorna:
        df_scaled: DataFrame normalizado
        scalers: dicionário com os scalers {'X': scaler_X, 'Y': scaler_Y, 'Z': scaler_Z}
    """
    scaler_X = MinMaxScaler(feature_range=(-1, 1))
    scaler_Y = MinMaxScaler(feature_range=(-1, 1))
    scaler_Z = MinMaxScaler(feature_range=(-1, 1))

    df_scaled = pd.DataFrame()
    df_scaled['X'] = scaler_X.fit_transform(dataframe[['X']]).flatten()
    df_scaled['Y'] = scaler_Y.fit_transform(dataframe[['Y']]).flatten()
    df_scaled['Z'] = scaler_Z.fit_transform(dataframe[['Z']]).flatten()

    scalers = {'X': scaler_X, 'Y': scaler_Y, 'Z': scaler_Z}
    return df_scaled, scalers

df_scaled, scalers_tuple = normalizar_eixos_independente(df)


# # Salvar os scalers em um único arquivo (como uma tupla)
with open('scalers.pkl', 'wb') as f:
    pickle.dump(scalers_tuple, f)

# # Visualizando os primeiros dados normalizados
print(df_scaled.head())
# Out:
#           X         Y         Z
# 0 -0.584238  0.284906  0.198832
# 1 -0.584192  0.290672  0.197759
# 2 -0.582475  0.294297  0.181353
# 3 -0.582537  0.293559  0.173546
# 4 -0.583436  0.281589  0.174843

# %%
# Histogramas dos valores normalizados

df_scaled.hist(bins=50, figsize=(12, 4), layout=(1, 3))
plt.suptitle("Distribuição Normalizada dos Eixos X, Y e Z")
plt.show()

# %%
print(f"Intervalo X: {df_scaled['X'].min()} a {df_scaled['X'].max()}")
print(f"Intervalo Y: {df_scaled['Y'].min()} a {df_scaled['Y'].max()}")
print(f"Intervalo Z: {df_scaled['Z'].min()} a {df_scaled['Z'].max()}")


# Supondo que 'df' é seu DataFrame original com as colunas 'X', 'Y', 'Z'
plt.figure(figsize=(12, 6))

# Plotando cada coluna
plt.subplot(3, 1, 1)  # 3 linhas, 1 coluna, posição 1
plt.plot(df_scaled['X'], label='X')
plt.title('Sensor Data - X')
plt.ylabel('X')

plt.subplot(3, 1, 2)  # 3 linhas, 1 coluna, posição 2
plt.plot(df_scaled['Y'], label='Y')
plt.title('Sensor Data - Y')
plt.ylabel('Y')

plt.subplot(3, 1, 3)  # 3 linhas, 1 coluna, posição 3
plt.plot(df_scaled['Z'], label='Z')
plt.title('Sensor Data - Z')
plt.ylabel('Z')
plt.xlabel('Sample Number')

# Mostrando o gráfico
plt.tight_layout()
plt.show()
# Out:
# Intervalo X: -1.0 a 1.0
# Intervalo Y: -1.0 a 1.0
# Intervalo Z: -1.0 a 1.0

# %% [markdown]
# # ******************************************************
# # HIPERPARAMETROS

# %%
# Valores dos hiperparâmetros
n_splits= 4 # 4
timestepsValue = 80 # 80
pesosValue = tf.constant([ 1.0, 1.0, 1.0]) # ([1.0, 0.1, 1.0])
neuroniosValue = 100 # 262                                                                                                                                                                                                                                 # 25
dropoutValue = 0.14512369139123038
ativacaoType = 'tanh'
best_lr = 0.0019702991167906115
epocasValue = 50 # 50
batchValue = 120 # 120
pacienciaValue = 10 # 10

# Criar uma pasta para salvar os modelos
model_folder = "models_GY87"
os.makedirs(model_folder, exist_ok=True)

# Dicionário com os hiperparâmetros
experiment_config = {
    "Splits": n_splits,
    "timesteps": timestepsValue,
    "wights": pesosValue.numpy().tolist(),
    "neuronios": neuroniosValue,
    "dropout": dropoutValue,
    "ativacao": ativacaoType,
    "learning_rate": best_lr,
    "epocas": epocasValue,
    "batch": batchValue,
    "paciencia": pacienciaValue
}

# Salvar os hiperparâmetros em um arquivo JSON
import json
config_path = os.path.join(model_folder, "hiperparametros.json")
with open(config_path, "w") as f:
    json.dump(experiment_config, f, indent=4)

print(f"Hiperparâmetros salvos em {config_path}")
# Out:
# Hiperparâmetros salvos em models_GY87/hiperparametros.json

# %% [markdown]
# ## Definindo Cross Validation TimeSeriesSplit e Variáveis

# %%
# Função de perda ponderada (se quiser usar)
def weighted_mse(y_true, y_pred):
    weights = pesosValue  # Exemplo: np.array([1.0, 1.0, 0.5]) para X, Y, Z
    loss = K.mean(weights * K.square(y_pred - y_true), axis=-1)
    return loss

# Função para monitorar o erro em cada eixo separadamente durante o treinamento.
# Assim, você pode ver se o modelo está realmente aprendendo em todos os eixos.
def mse_x(y_true, y_pred):
    return K.mean(K.square(y_pred[:, 0] - y_true[:, 0]))

def mse_y(y_true, y_pred):
    return K.mean(K.square(y_pred[:, 1] - y_true[:, 1]))

def mse_z(y_true, y_pred):
    return K.mean(K.square(y_pred[:, 2] - y_true[:, 2]))


tscv = TimeSeriesSplit(n_splits)
print(tscv)
# Out:
# TimeSeriesSplit(gap=0, max_train_size=None, n_splits=4, test_size=None)

# %% [markdown]
# ## Criar Sequências para Treino e Teste
# ### Transformando os dados de treino e teste em sequências temporais para serem usados como entrada no modelo LSTM.

# %%
# # Função para criar sequências
def create_sequences(data, n_timesteps):
    X, y = [], []
    for i in range(len(data) - n_timesteps):
        X.append(data[i:i+n_timesteps, :])  # Sequência de entrada
        y.append(data[i+n_timesteps, :])   # Próxima linha como saída
    return np.array(X), np.array(y)

# Definir o número de timesteps (janelas de tempo)
n_timesteps = timestepsValue  # Exemplo: 80 passos no tempo
n_features = df_scaled.shape[1]  # Número de colunas (X, Y, Z)

# %%
# Visualizar os splits gerados
for train_index, test_index in tscv.split(df_scaled):
    print(f"Treino: {len(train_index)} amostras, Teste: {len(test_index)} amostras")
    print(f"Treino: {train_index[:5]}...{train_index[-5:]}, Teste: {test_index[:5]}...{test_index[-5:]}")
# Out:
# Treino: 257549 amostras, Teste: 257546 amostras
# Treino: [0 1 2 3 4]...[257544 257545 257546 257547 257548], Teste: [257549 257550 257551 257552 257553]...[515090 515091 515092 515093 515094]
# Treino: 515095 amostras, Teste: 257546 amostras
# Treino: [0 1 2 3 4]...[515090 515091 515092 515093 515094], Teste: [515095 515096 515097 515098 515099]...[772636 772637 772638 772639 772640]
# Treino: 772641 amostras, Teste: 257546 amostras
# Treino: [0 1 2 3 4]...[772636 772637 772638 772639 772640], Teste: [772641 772642 772643 772644 772645]...[1030182 1030183 1030184 1030185 1030186]
# Treino: 1030187 amostras, Teste: 257546 amostras
# Treino: [0 1 2 3 4]...[1030182 1030183 1030184 1030185 1030186], Teste: [1030187 1030188 1030189 1030190 1030191]...[1287728 1287729 1287730 1287731 1287732]

# %% [markdown]
# ### Caso não queira treinar novamente, mas apenas executar a predição do modelo, descomente!

# %%
# Loop de treinamento para cada split
# for split_idx, (train_index, test_index) in enumerate(tscv.split(df_scaled.values), start=1):
#     # Criar os dados de treino e teste
#     train_data, test_data = df_scaled.values[train_index], df_scaled.values[test_index]
#     X_train, y_train = create_sequences(train_data, n_timesteps)
#     X_test, y_test = create_sequences(test_data, n_timesteps)
    
#     print(f"Split {split_idx}:")
#     print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
#     print(f"X_test shape: {X_test.shape}, y_test shape: {y_test.shape}")

# %% [markdown]
# # LSTM

# %% [markdown]
# ### Treinar o Modelo em Cada Split usando o Early Stopping e Salvando .keras
# Para cada split será treinado o modelo usando os dados de treino e será avaliado nos dados de teste. O EarlyStopping será usado para evitar overfitting.

# %%
# Loop de treinamento para cada split
for split_idx, (train_index, test_index) in enumerate(tscv.split(df_scaled.values), start=1):
    # Limpeza de memória antes de iniciar o próximo modelo
    K.clear_session()
    gc.collect()
    # Criar os dados de treino e teste
    train_data, test_data = df_scaled.values[train_index], df_scaled.values[test_index]
    X_train, y_train = create_sequences(train_data, n_timesteps)
    X_test, y_test = create_sequences(test_data, n_timesteps)
    
    print(f"Split {split_idx}:")
    print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
    print(f"X_test shape: {X_test.shape}, y_test shape: {y_test.shape}")

    # Configurar o modelo LSTM
    model = Sequential()
    model.add(Input(shape=(n_timesteps, n_features)))
    # Se quiser 4 camadas LSTM, descomente as linhas abaixo:
    # model.add(LSTM(units=270, activation='tanh', return_sequences=True))
    # model.add(LSTM(units=150, activation='tanh', return_sequences=True))
    # model.add(LSTM(units=150, activation='tanh', return_sequences=True))
    # model.add(LSTM(units=150, activation=ativacaoType))
    # Se quiser só 1 camada LSTM, use apenas a linha abaixo:
    model.add(LSTM(units=neuroniosValue, activation=ativacaoType))
    # model.add(Dropout(dropoutValue))
    model.add(Dense(n_features))
    
    model.compile(
        optimizer = "Nadam", # Nadam(learning_rate=best_lr),
        loss = weighted_mse, # 'mse',
        metrics=[
            metrics.MeanSquaredError(),
            metrics.MeanAbsoluteError(),
            metrics.RootMeanSquaredError(),
            mse_x, mse_y, mse_z  # métricas customizadas
        ]
    )

    # Treinar o modelo
    print(f"Treinando o modelo para o split {split_idx}...")
    history = model.fit(
        X_train, y_train,
        epochs=epocasValue,
        batch_size=batchValue,
        validation_data=(X_test, y_test),
        callbacks=[EarlyStopping(monitor='val_loss', patience=pacienciaValue, verbose=1, mode='min')],
        verbose=1
    )

    # Salvar o modelo no formato .keras
    model_path = os.path.join(model_folder, f"lstm_split_{split_idx}.keras")
    model.save(model_path)
    print(f"Modelo do split {split_idx} salvo em {model_path}")
# Out:
# Split 1:
# X_train shape: (257469, 80, 3), y_train shape: (257469, 3)
# X_test shape: (257466, 80, 3), y_test shape: (257466, 3)
# Treinando o modelo para o split 1...
# Epoch 1/50
# 2146/2146 ━━━━━━━━━━━━━━━━━━━━ 35s 16ms/step - loss: 0.0027 - mean_absolute_error: 0.0189 - mean_squared_error: 0.0027 - mse_x: 0.0026 - mse_y: 0.0027 - mse_z: 0.0028 - root_mean_squared_error: 0.0417 - val_loss: 0.0101 - val_mean_absolute_error: 0.0796 - val_mean_squared_error: 0.0101 - val_mse_x: 0.0083 - val_mse_y: 0.0106 - val_mse_z: 0.0115 - val_root_mean_squared_error: 0.1007
# Epoch 2/50
# 2146/2146 ━━━━━━━━━━━━━━━━━━━━ 35s 16ms/step - loss: 3.2844e-04 - mean_absolute_error: 0.0111 - mean_squared_error: 3.2844e-04 - mse_x: 3.4159e-05 - mse_y: 5.3298e-04 - mse_z: 4.1819e-04 - root_mean_squared_error: 0.0181 - val_loss: 0.0117 - val_mean_absolute_error: 0.0932 - val_mean_squared_error: 0.0117 - val_mse_x: 0.0066 - val_mse_y: 0.0127 - val_mse_z: 0.0159 - val_root_mean_squared_error: 0.1083
# Epoch 3/50
# 2146/2146 ━━━━━━━━━━━━━━━━━━━━ 34s 16ms/step - loss: 2.8193e-04 - mean_absolute_error: 0.0102 - mean_squared_error: 2.8193e-04 - mse_x: 2.2661e-05 - mse_y: 4.7820e-04 - mse_z: 3.4493e-04 - root_mean_squared_error: 0.0168 - val_loss: 0.0132 - val_mean_absolute_error: 0.0890 - val_mean_squared_error: 0.0132 - val_mse_x: 0.0034 - val_mse_y: 0.0200 - val_mse_z: 0.0163 - val_root_mean_squared_error: 0.1149
# Epoch 4/50
# 2146/2146 ━━━━━━━━━━━━━━━━━━━━ 34s 16ms/step - loss: 2.7120e-04 - mean_absolute_error: 0.0099 - mean_squared_error: 2.7120e-04 - mse_x: 2.3579e-05 - mse_y: 4.7051e-04 - mse_z: 3.1950e-04 - root_mean_squared_error: 0.0165 - val_loss: 0.0144 - val_mean_absolute_error: 0.0930 - val_mean_squared_error: 0.0144 - val_mse_x: 0.0032 - val_mse_y: 0.0287 - val_mse_z: 0.0113 - val_root_mean_squared_error: 0.1200
# Epoch 5/50
# 2146/2146 ━━━━━━━━━━━━━━━━━━━━ 35s 16ms/step - loss: 2.6317e-04 - mean_absolute_error: 0.0098 - mean_squared_error: 2.6317e-04 - mse_x: 2.2315e-05 - mse_y: 4.6254e-04 - mse_z: 3.0467e-04 - root_mean_squared_error: 0.0162 - val_loss: 0.0113 - val_mean_absolute_error: 0.0893 - val_mean_squared_error: 0.0113 - val_mse_x: 0.0070 - val_mse_y: 0.0150 - val_mse_z: 0.0118 - val_root_mean_squared_error: 0.1062
# Epoch 6/50
# 2146/2146 ━━━━━━━━━━━━━━━━━━━━ 35s 16ms/step - loss: 2.5864e-04 - mean_absolute_error: 0.0096 - mean_squared_error: 2.5864e-04 - mse_x: 1.9001e-05 - mse_y: 4.5473e-04 - mse_z: 3.0219e-04 - root_mean_squared_error: 0.0161 - val_loss: 0.0122 - val_mean_absolute_error: 0.0785 - val_mean_squared_error: 0.0122 - val_mse_x: 0.0019 - val_mse_y: 0.0198 - val_mse_z: 0.0149 - val_root_mean_squared_error: 0.1104
# Epoch 7/50
# 2146/2146 ━━━━━━━━━━━━━━━━━━━━ 35s 16ms/step - loss: 2.6241e-04 - mean_absolute_error: 0.0096 - mean_squared_error: 2.6241e-04 - mse_x: 2.3633e-05 - mse_y: 4.7374e-04 - mse_z: 2.8984e-04 - root_mean_squared_error: 0.0162 - val_loss: 0.0108 - val_mean_absolute_error: 0.0819 - val_mean_squared_error: 0.0108 - val_mse_x: 0.0026 - val_mse_y: 0.0165 - val_mse_z: 0.0134 - val_root_mean_squared_error: 0.1041
# Epoch 8/50
# 2146/2146 ━━━━━━━━━━━━━━━━━━━━ 35s 16ms/step - loss: 2.3863e-04 - mean_absolute_error: 0.0091 - mean_squared_error: 2.3863e-04 - mse_x: 1.7127e-05 - mse_y: 4.4716e-04 - mse_z: 2.5160e-04 - root_mean_squared_error: 0.0154 - val_loss: 0.0253 - val_mean_absolute_error: 0.1275 - val_mean_squared_error: 0.0253 - val_mse_x: 0.0054 - val_mse_y: 0.0492 - val_mse_z: 0.0213 - val_root_mean_squared_error: 0.1590
# Epoch 9/50
# 2146/2146 ━━━━━━━━━━━━━━━━━━━━ 35s 16ms/step - loss: 2.4244e-04 - mean_absolute_error: 0.0091 - mean_squared_error: 2.4244e-04 - mse_x: 1.6979e-05 - mse_y: 4.5984e-04 - mse_z: 2.5050e-04 - root_mean_squared_error: 0.0156 - val_loss: 0.0153 - val_mean_absolute_error: 0.1000 - val_mean_squared_error: 0.0153 - val_mse_x: 0.0030 - val_mse_y: 0.0197 - val_mse_z: 0.0232 - val_root_mean_squared_error: 0.1238
# Epoch 10/50
# 2146/2146 ━━━━━━━━━━━━━━━━━━━━ 35s 17ms/step - loss: 2.3861e-04 - mean_absolute_error: 0.0091 - mean_squared_error: 2.3861e-04 - mse_x: 1.6040e-05 - mse_y: 4.5330e-04 - mse_z: 2.4650e-04 - root_mean_squared_error: 0.0154 - val_loss: 0.0212 - val_mean_absolute_error: 0.1082 - val_mean_squared_error: 0.0212 - val_mse_x: 0.0066 - val_mse_y: 0.0270 - val_mse_z: 0.0300 - val_root_mean_squared_error: 0.1456
# Epoch 11/50
# 2146/2146 ━━━━━━━━━━━━━━━━━━━━ 34s 16ms/step - loss: 2.3412e-04 - mean_absolute_error: 0.0090 - mean_squared_error: 2.3412e-04 - mse_x: 1.4845e-05 - mse_y: 4.3687e-04 - mse_z: 2.5063e-04 - root_mean_squared_error: 0.0153 - val_loss: 0.0211 - val_mean_absolute_error: 0.1109 - val_mean_squared_error: 0.0211 - val_mse_x: 0.0090 - val_mse_y: 0.0290 - val_mse_z: 0.0253 - val_root_mean_squared_error: 0.1453
# Epoch 11: early stopping
# Modelo do split 1 salvo em models_GY87/lstm_split_1.keras
# Split 2:
# X_train shape: (515015, 80, 3), y_train shape: (515015, 3)
# X_test shape: (257466, 80, 3), y_test shape: (257466, 3)
# Treinando o modelo para o split 2...
# Epoch 1/50
# 4292/4292 ━━━━━━━━━━━━━━━━━━━━ 62s 14ms/step - loss: 0.0031 - mean_absolute_error: 0.0199 - mean_squared_error: 0.0031 - mse_x: 0.0038 - mse_y: 0.0026 - mse_z: 0.0030 - root_mean_squared_error: 0.0443 - val_loss: 0.0139 - val_mean_absolute_error: 0.0960 - val_mean_squared_error: 0.0139 - val_mse_x: 0.0011 - val_mse_y: 0.0198 - val_mse_z: 0.0207 - val_root_mean_squared_error: 0.1177
# Epoch 2/50
# 4292/4292 ━━━━━━━━━━━━━━━━━━━━ 59s 14ms/step - loss: 3.3076e-04 - mean_absolute_error: 0.0114 - mean_squared_error: 3.3076e-04 - mse_x: 2.7259e-05 - mse_y: 4.3163e-04 - mse_z: 5.3338e-04 - root_mean_squared_error: 0.0182 - val_loss: 0.0265 - val_mean_absolute_error: 0.1317 - val_mean_squared_error: 0.0265 - val_mse_x: 7.0658e-04 - val_mse_y: 0.0507 - val_mse_z: 0.0280 - val_root_mean_squared_error: 0.1627
# Epoch 3/50
# 4292/4292 ━━━━━━━━━━━━━━━━━━━━ 59s 14ms/step - loss: 3.1668e-04 - mean_absolute_error: 0.0111 - mean_squared_error: 3.1668e-04 - mse_x: 2.3561e-05 - mse_y: 4.0869e-04 - mse_z: 5.1779e-04 - root_mean_squared_error: 0.0178 - val_loss: 0.0339 - val_mean_absolute_error: 0.1473 - val_mean_squared_error: 0.0339 - val_mse_x: 6.6696e-04 - val_mse_y: 0.0673 - val_mse_z: 0.0337 - val_root_mean_squared_error: 0.1841
# Epoch 4/50
# 4292/4292 ━━━━━━━━━━━━━━━━━━━━ 58s 14ms/step - loss: 3.0961e-04 - mean_absolute_error: 0.0110 - mean_squared_error: 3.0961e-04 - mse_x: 1.8817e-05 - mse_y: 3.9705e-04 - mse_z: 5.1296e-04 - root_mean_squared_error: 0.0176 - val_loss: 0.0504 - val_mean_absolute_error: 0.1862 - val_mean_squared_error: 0.0504 - val_mse_x: 0.0026 - val_mse_y: 0.1006 - val_mse_z: 0.0479 - val_root_mean_squared_error: 0.2244
# Epoch 5/50
# 4292/4292 ━━━━━━━━━━━━━━━━━━━━ 58s 13ms/step - loss: 3.0498e-04 - mean_absolute_error: 0.0108 - mean_squared_error: 3.0498e-04 - mse_x: 1.6865e-05 - mse_y: 3.9881e-04 - mse_z: 4.9926e-04 - root_mean_squared_error: 0.0175 - val_loss: 0.0568 - val_mean_absolute_error: 0.1962 - val_mean_squared_error: 0.0568 - val_mse_x: 0.0034 - val_mse_y: 0.1091 - val_mse_z: 0.0580 - val_root_mean_squared_error: 0.2384
# Epoch 6/50
# 4292/4292 ━━━━━━━━━━━━━━━━━━━━ 59s 14ms/step - loss: 3.0032e-04 - mean_absolute_error: 0.0107 - mean_squared_error: 3.0032e-04 - mse_x: 1.5471e-05 - mse_y: 3.9265e-04 - mse_z: 4.9285e-04 - root_mean_squared_error: 0.0173 - val_loss: 0.0669 - val_mean_absolute_error: 0.2170 - val_mean_squared_error: 0.0669 - val_mse_x: 0.0049 - val_mse_y: 0.1301 - val_mse_z: 0.0657 - val_root_mean_squared_error: 0.2587
# Epoch 7/50
# 4292/4292 ━━━━━━━━━━━━━━━━━━━━ 59s 14ms/step - loss: 2.8360e-04 - mean_absolute_error: 0.0103 - mean_squared_error: 2.8360e-04 - mse_x: 1.4342e-05 - mse_y: 3.8843e-04 - mse_z: 4.4804e-04 - root_mean_squared_error: 0.0168 - val_loss: 0.0640 - val_mean_absolute_error: 0.2131 - val_mean_squared_error: 0.0640 - val_mse_x: 0.0085 - val_mse_y: 0.1206 - val_mse_z: 0.0629 - val_root_mean_squared_error: 0.2531
# Epoch 8/50
# 4292/4292 ━━━━━━━━━━━━━━━━━━━━ 60s 14ms/step - loss: 2.8168e-04 - mean_absolute_error: 0.0103 - mean_squared_error: 2.8168e-04 - mse_x: 1.3825e-05 - mse_y: 3.8214e-04 - mse_z: 4.4907e-04 - root_mean_squared_error: 0.0168 - val_loss: 0.0662 - val_mean_absolute_error: 0.2139 - val_mean_squared_error: 0.0662 - val_mse_x: 0.0106 - val_mse_y: 0.1334 - val_mse_z: 0.0547 - val_root_mean_squared_error: 0.2574
# Epoch 9/50
# 4292/4292 ━━━━━━━━━━━━━━━━━━━━ 61s 14ms/step - loss: 2.8016e-04 - mean_absolute_error: 0.0102 - mean_squared_error: 2.8016e-04 - mse_x: 1.3300e-05 - mse_y: 3.8510e-04 - mse_z: 4.4206e-04 - root_mean_squared_error: 0.0167 - val_loss: 0.0792 - val_mean_absolute_error: 0.2422 - val_mean_squared_error: 0.0792 - val_mse_x: 0.0125 - val_mse_y: 0.1636 - val_mse_z: 0.0616 - val_root_mean_squared_error: 0.2814
# Epoch 10/50
# 4292/4292 ━━━━━━━━━━━━━━━━━━━━ 58s 14ms/step - loss: 2.7882e-04 - mean_absolute_error: 0.0102 - mean_squared_error: 2.7882e-04 - mse_x: 1.2887e-05 - mse_y: 3.8150e-04 - mse_z: 4.4205e-04 - root_mean_squared_error: 0.0167 - val_loss: 0.0644 - val_mean_absolute_error: 0.2086 - val_mean_squared_error: 0.0644 - val_mse_x: 0.0059 - val_mse_y: 0.1336 - val_mse_z: 0.0536 - val_root_mean_squared_error: 0.2538
# Epoch 11/50
# 4292/4292 ━━━━━━━━━━━━━━━━━━━━ 59s 14ms/step - loss: 2.7641e-04 - mean_absolute_error: 0.0102 - mean_squared_error: 2.7641e-04 - mse_x: 1.2413e-05 - mse_y: 3.7972e-04 - mse_z: 4.3710e-04 - root_mean_squared_error: 0.0166 - val_loss: 0.0584 - val_mean_absolute_error: 0.1977 - val_mean_squared_error: 0.0584 - val_mse_x: 0.0074 - val_mse_y: 0.1297 - val_mse_z: 0.0380 - val_root_mean_squared_error: 0.2416
# Epoch 11: early stopping
# Modelo do split 2 salvo em models_GY87/lstm_split_2.keras
# Split 3:
# X_train shape: (772561, 80, 3), y_train shape: (772561, 3)
# X_test shape: (257466, 80, 3), y_test shape: (257466, 3)
# Treinando o modelo para o split 3...
# Epoch 1/50
# 6439/6439 ━━━━━━━━━━━━━━━━━━━━ 86s 13ms/step - loss: 0.0028 - mean_absolute_error: 0.0185 - mean_squared_error: 0.0028 - mse_x: 0.0042 - mse_y: 0.0015 - mse_z: 0.0026 - root_mean_squared_error: 0.0415 - val_loss: 0.0014 - val_mean_absolute_error: 0.0337 - val_mean_squared_error: 0.0014 - val_mse_x: 0.0021 - val_mse_y: 8.8252e-04 - val_mse_z: 0.0012 - val_root_mean_squared_error: 0.0373
# Epoch 2/50
# 6439/6439 ━━━━━━━━━━━━━━━━━━━━ 83s 13ms/step - loss: 3.1328e-04 - mean_absolute_error: 0.0112 - mean_squared_error: 3.1328e-04 - mse_x: 2.5644e-05 - mse_y: 4.1993e-04 - mse_z: 4.9428e-04 - root_mean_squared_error: 0.0177 - val_loss: 4.9343e-04 - val_mean_absolute_error: 0.0176 - val_mean_squared_error: 4.9343e-04 - val_mse_x: 2.3328e-04 - val_mse_y: 9.1218e-04 - val_mse_z: 3.3500e-04 - val_root_mean_squared_error: 0.0222
# Epoch 3/50
# 6439/6439 ━━━━━━━━━━━━━━━━━━━━ 83s 13ms/step - loss: 3.0248e-04 - mean_absolute_error: 0.0109 - mean_squared_error: 3.0248e-04 - mse_x: 1.8812e-05 - mse_y: 4.0651e-04 - mse_z: 4.8211e-04 - root_mean_squared_error: 0.0174 - val_loss: 8.1201e-04 - val_mean_absolute_error: 0.0242 - val_mean_squared_error: 8.1201e-04 - val_mse_x: 6.1852e-04 - val_mse_y: 5.5228e-04 - val_mse_z: 0.0013 - val_root_mean_squared_error: 0.0285
# Epoch 4/50
# 6439/6439 ━━━━━━━━━━━━━━━━━━━━ 84s 13ms/step - loss: 2.9828e-04 - mean_absolute_error: 0.0108 - mean_squared_error: 2.9828e-04 - mse_x: 1.5807e-05 - mse_y: 4.0493e-04 - mse_z: 4.7409e-04 - root_mean_squared_error: 0.0173 - val_loss: 0.0013 - val_mean_absolute_error: 0.0322 - val_mean_squared_error: 0.0013 - val_mse_x: 0.0012 - val_mse_y: 9.4241e-04 - val_mse_z: 0.0017 - val_root_mean_squared_error: 0.0356
# Epoch 5/50
# 6439/6439 ━━━━━━━━━━━━━━━━━━━━ 83s 13ms/step - loss: 2.9328e-04 - mean_absolute_error: 0.0107 - mean_squared_error: 2.9328e-04 - mse_x: 1.4855e-05 - mse_y: 3.9872e-04 - mse_z: 4.6626e-04 - root_mean_squared_error: 0.0171 - val_loss: 0.0075 - val_mean_absolute_error: 0.0601 - val_mean_squared_error: 0.0075 - val_mse_x: 7.2110e-04 - val_mse_y: 0.0034 - val_mse_z: 0.0185 - val_root_mean_squared_error: 0.0869
# Epoch 6/50
# 6439/6439 ━━━━━━━━━━━━━━━━━━━━ 83s 13ms/step - loss: 2.9147e-04 - mean_absolute_error: 0.0105 - mean_squared_error: 2.9147e-04 - mse_x: 2.3102e-05 - mse_y: 4.0087e-04 - mse_z: 4.5045e-04 - root_mean_squared_error: 0.0171 - val_loss: 0.0084 - val_mean_absolute_error: 0.0556 - val_mean_squared_error: 0.0084 - val_mse_x: 6.0582e-04 - val_mse_y: 8.5242e-04 - val_mse_z: 0.0237 - val_root_mean_squared_error: 0.0916
# Epoch 7/50
# 6439/6439 ━━━━━━━━━━━━━━━━━━━━ 87s 13ms/step - loss: 2.6953e-04 - mean_absolute_error: 0.0101 - mean_squared_error: 2.6953e-04 - mse_x: 1.3358e-05 - mse_y: 3.8131e-04 - mse_z: 4.1393e-04 - root_mean_squared_error: 0.0164 - val_loss: 0.0166 - val_mean_absolute_error: 0.0839 - val_mean_squared_error: 0.0166 - val_mse_x: 5.6714e-04 - val_mse_y: 0.0028 - val_mse_z: 0.0465 - val_root_mean_squared_error: 0.1290
# Epoch 8/50
# 6439/6439 ━━━━━━━━━━━━━━━━━━━━ 86s 13ms/step - loss: 2.7141e-04 - mean_absolute_error: 0.0101 - mean_squared_error: 2.7141e-04 - mse_x: 1.3370e-05 - mse_y: 3.8940e-04 - mse_z: 4.1146e-04 - root_mean_squared_error: 0.0165 - val_loss: 0.0123 - val_mean_absolute_error: 0.0707 - val_mean_squared_error: 0.0123 - val_mse_x: 0.0010 - val_mse_y: 0.0013 - val_mse_z: 0.0346 - val_root_mean_squared_error: 0.1109
# Epoch 9/50
# 6439/6439 ━━━━━━━━━━━━━━━━━━━━ 86s 13ms/step - loss: 2.6948e-04 - mean_absolute_error: 0.0101 - mean_squared_error: 2.6948e-04 - mse_x: 1.2215e-05 - mse_y: 3.8826e-04 - mse_z: 4.0796e-04 - root_mean_squared_error: 0.0164 - val_loss: 0.0146 - val_mean_absolute_error: 0.0774 - val_mean_squared_error: 0.0146 - val_mse_x: 9.8306e-04 - val_mse_y: 0.0022 - val_mse_z: 0.0405 - val_root_mean_squared_error: 0.1208
# Epoch 10/50
# 6439/6439 ━━━━━━━━━━━━━━━━━━━━ 85s 13ms/step - loss: 2.6810e-04 - mean_absolute_error: 0.0100 - mean_squared_error: 2.6810e-04 - mse_x: 1.1695e-05 - mse_y: 3.8433e-04 - mse_z: 4.0828e-04 - root_mean_squared_error: 0.0164 - val_loss: 0.0137 - val_mean_absolute_error: 0.0895 - val_mean_squared_error: 0.0137 - val_mse_x: 0.0065 - val_mse_y: 0.0025 - val_mse_z: 0.0321 - val_root_mean_squared_error: 0.1170
# Epoch 11/50
# 6439/6439 ━━━━━━━━━━━━━━━━━━━━ 87s 14ms/step - loss: 2.6495e-04 - mean_absolute_error: 0.0100 - mean_squared_error: 2.6495e-04 - mse_x: 1.1810e-05 - mse_y: 3.7933e-04 - mse_z: 4.0371e-04 - root_mean_squared_error: 0.0163 - val_loss: 0.0125 - val_mean_absolute_error: 0.0738 - val_mean_squared_error: 0.0125 - val_mse_x: 0.0019 - val_mse_y: 5.2141e-04 - val_mse_z: 0.0350 - val_root_mean_squared_error: 0.1118
# Epoch 12/50
# 6439/6439 ━━━━━━━━━━━━━━━━━━━━ 87s 14ms/step - loss: 2.6332e-04 - mean_absolute_error: 0.0099 - mean_squared_error: 2.6332e-04 - mse_x: 1.1371e-05 - mse_y: 3.7763e-04 - mse_z: 4.0095e-04 - root_mean_squared_error: 0.0162 - val_loss: 0.0252 - val_mean_absolute_error: 0.1047 - val_mean_squared_error: 0.0252 - val_mse_x: 0.0020 - val_mse_y: 0.0023 - val_mse_z: 0.0712 - val_root_mean_squared_error: 0.1586
# Epoch 12: early stopping
# Modelo do split 3 salvo em models_GY87/lstm_split_3.keras
# Split 4:
# X_train shape: (1030107, 80, 3), y_train shape: (1030107, 3)
# X_test shape: (257466, 80, 3), y_test shape: (257466, 3)
# Treinando o modelo para o split 4...
# Epoch 1/50
# 8585/8585 ━━━━━━━━━━━━━━━━━━━━ 114s 13ms/step - loss: 0.0021 - mean_absolute_error: 0.0166 - mean_squared_error: 0.0021 - mse_x: 0.0021 - mse_y: 0.0023 - mse_z: 0.0020 - root_mean_squared_error: 0.0362 - val_loss: 4.0706e-04 - val_mean_absolute_error: 0.0163 - val_mean_squared_error: 4.0706e-04 - val_mse_x: 3.1386e-04 - val_mse_y: 5.5575e-04 - val_mse_z: 3.5162e-04 - val_root_mean_squared_error: 0.0202
# Epoch 2/50
# 8585/8585 ━━━━━━━━━━━━━━━━━━━━ 113s 13ms/step - loss: 2.7640e-04 - mean_absolute_error: 0.0107 - mean_squared_error: 2.7640e-04 - mse_x: 2.0857e-05 - mse_y: 3.8178e-04 - mse_z: 4.2657e-04 - root_mean_squared_error: 0.0166 - val_loss: 5.5238e-04 - val_mean_absolute_error: 0.0174 - val_mean_squared_error: 5.5238e-04 - val_mse_x: 6.7444e-05 - val_mse_y: 4.6329e-04 - val_mse_z: 0.0011 - val_root_mean_squared_error: 0.0235
# Epoch 3/50
# 8585/8585 ━━━━━━━━━━━━━━━━━━━━ 113s 13ms/step - loss: 2.6430e-04 - mean_absolute_error: 0.0103 - mean_squared_error: 2.6430e-04 - mse_x: 1.5182e-05 - mse_y: 3.6907e-04 - mse_z: 4.0866e-04 - root_mean_squared_error: 0.0163 - val_loss: 4.6338e-04 - val_mean_absolute_error: 0.0164 - val_mean_squared_error: 4.6338e-04 - val_mse_x: 8.1210e-05 - val_mse_y: 6.0817e-04 - val_mse_z: 7.0090e-04 - val_root_mean_squared_error: 0.0215
# Epoch 4/50
# 8585/8585 ━━━━━━━━━━━━━━━━━━━━ 115s 13ms/step - loss: 2.6206e-04 - mean_absolute_error: 0.0101 - mean_squared_error: 2.6206e-04 - mse_x: 1.3000e-05 - mse_y: 3.6917e-04 - mse_z: 4.0402e-04 - root_mean_squared_error: 0.0162 - val_loss: 5.7239e-04 - val_mean_absolute_error: 0.0182 - val_mean_squared_error: 5.7239e-04 - val_mse_x: 8.0708e-05 - val_mse_y: 0.0012 - val_mse_z: 4.3824e-04 - val_root_mean_squared_error: 0.0239
# Epoch 5/50
# 8585/8585 ━━━━━━━━━━━━━━━━━━━━ 114s 13ms/step - loss: 2.5174e-04 - mean_absolute_error: 0.0099 - mean_squared_error: 2.5174e-04 - mse_x: 1.3588e-05 - mse_y: 3.5896e-04 - mse_z: 3.8266e-04 - root_mean_squared_error: 0.0159 - val_loss: 4.9462e-04 - val_mean_absolute_error: 0.0164 - val_mean_squared_error: 4.9462e-04 - val_mse_x: 4.5917e-05 - val_mse_y: 0.0011 - val_mse_z: 3.7238e-04 - val_root_mean_squared_error: 0.0222
# Epoch 6/50
# 8585/8585 ━━━━━━━━━━━━━━━━━━━━ 115s 13ms/step - loss: 2.4090e-04 - mean_absolute_error: 0.0097 - mean_squared_error: 2.4090e-04 - mse_x: 1.1766e-05 - mse_y: 3.5406e-04 - mse_z: 3.5688e-04 - root_mean_squared_error: 0.0155 - val_loss: 3.8058e-04 - val_mean_absolute_error: 0.0148 - val_mean_squared_error: 3.8058e-04 - val_mse_x: 1.3130e-04 - val_mse_y: 7.3771e-04 - val_mse_z: 2.7281e-04 - val_root_mean_squared_error: 0.0195
# Epoch 7/50
# 8585/8585 ━━━━━━━━━━━━━━━━━━━━ 114s 13ms/step - loss: 2.3969e-04 - mean_absolute_error: 0.0096 - mean_squared_error: 2.3969e-04 - mse_x: 1.1339e-05 - mse_y: 3.5454e-04 - mse_z: 3.5320e-04 - root_mean_squared_error: 0.0155 - val_loss: 6.9193e-04 - val_mean_absolute_error: 0.0202 - val_mean_squared_error: 6.9193e-04 - val_mse_x: 1.8295e-04 - val_mse_y: 0.0015 - val_mse_z: 3.7342e-04 - val_root_mean_squared_error: 0.0263
# Epoch 8/50
# 8585/8585 ━━━━━━━━━━━━━━━━━━━━ 114s 13ms/step - loss: 2.3605e-04 - mean_absolute_error: 0.0096 - mean_squared_error: 2.3605e-04 - mse_x: 1.0863e-05 - mse_y: 3.4732e-04 - mse_z: 3.4998e-04 - root_mean_squared_error: 0.0154 - val_loss: 5.4384e-04 - val_mean_absolute_error: 0.0184 - val_mean_squared_error: 5.4384e-04 - val_mse_x: 2.9729e-04 - val_mse_y: 8.3423e-04 - val_mse_z: 5.0009e-04 - val_root_mean_squared_error: 0.0233
# Epoch 9/50
# 8585/8585 ━━━━━━━━━━━━━━━━━━━━ 115s 13ms/step - loss: 2.3834e-04 - mean_absolute_error: 0.0096 - mean_squared_error: 2.3834e-04 - mse_x: 1.0634e-05 - mse_y: 3.5687e-04 - mse_z: 3.4752e-04 - root_mean_squared_error: 0.0154 - val_loss: 4.1113e-04 - val_mean_absolute_error: 0.0159 - val_mean_squared_error: 4.1113e-04 - val_mse_x: 3.0102e-04 - val_mse_y: 6.0700e-04 - val_mse_z: 3.2539e-04 - val_root_mean_squared_error: 0.0203
# Epoch 10/50
# 8585/8585 ━━━━━━━━━━━━━━━━━━━━ 114s 13ms/step - loss: 2.3429e-04 - mean_absolute_error: 0.0095 - mean_squared_error: 2.3429e-04 - mse_x: 1.0414e-05 - mse_y: 3.4615e-04 - mse_z: 3.4631e-04 - root_mean_squared_error: 0.0153 - val_loss: 7.3179e-04 - val_mean_absolute_error: 0.0223 - val_mean_squared_error: 7.3179e-04 - val_mse_x: 3.8423e-04 - val_mse_y: 0.0011 - val_mse_z: 7.6096e-04 - val_root_mean_squared_error: 0.0271
# Epoch 11/50
# 8585/8585 ━━━━━━━━━━━━━━━━━━━━ 115s 13ms/step - loss: 2.3490e-04 - mean_absolute_error: 0.0095 - mean_squared_error: 2.3490e-04 - mse_x: 1.0400e-05 - mse_y: 3.5060e-04 - mse_z: 3.4371e-04 - root_mean_squared_error: 0.0153 - val_loss: 5.9641e-04 - val_mean_absolute_error: 0.0196 - val_mean_squared_error: 5.9641e-04 - val_mse_x: 3.5544e-04 - val_mse_y: 0.0011 - val_mse_z: 3.2038e-04 - val_root_mean_squared_error: 0.0244
# Epoch 12/50
# 8585/8585 ━━━━━━━━━━━━━━━━━━━━ 116s 14ms/step - loss: 2.3329e-04 - mean_absolute_error: 0.0095 - mean_squared_error: 2.3329e-04 - mse_x: 1.0412e-05 - mse_y: 3.4880e-04 - mse_z: 3.4066e-04 - root_mean_squared_error: 0.0153 - val_loss: 6.1767e-04 - val_mean_absolute_error: 0.0199 - val_mean_squared_error: 6.1767e-04 - val_mse_x: 5.4573e-04 - val_mse_y: 9.6907e-04 - val_mse_z: 3.3819e-04 - val_root_mean_squared_error: 0.0249
# Epoch 13/50
# 8585/8585 ━━━━━━━━━━━━━━━━━━━━ 116s 14ms/step - loss: 2.3026e-04 - mean_absolute_error: 0.0094 - mean_squared_error: 2.3026e-04 - mse_x: 9.9647e-06 - mse_y: 3.4171e-04 - mse_z: 3.3911e-04 - root_mean_squared_error: 0.0152 - val_loss: 6.1270e-04 - val_mean_absolute_error: 0.0194 - val_mean_squared_error: 6.1270e-04 - val_mse_x: 5.4888e-04 - val_mse_y: 0.0010 - val_mse_z: 2.6945e-04 - val_root_mean_squared_error: 0.0248
# Epoch 14/50
# 8585/8585 ━━━━━━━━━━━━━━━━━━━━ 117s 14ms/step - loss: 2.3151e-04 - mean_absolute_error: 0.0094 - mean_squared_error: 2.3151e-04 - mse_x: 1.0436e-05 - mse_y: 3.4483e-04 - mse_z: 3.3928e-04 - root_mean_squared_error: 0.0152 - val_loss: 6.7902e-04 - val_mean_absolute_error: 0.0198 - val_mean_squared_error: 6.7902e-04 - val_mse_x: 0.0010 - val_mse_y: 6.9381e-04 - val_mse_z: 3.2336e-04 - val_root_mean_squared_error: 0.0261
# Epoch 15/50
# 8585/8585 ━━━━━━━━━━━━━━━━━━━━ 117s 14ms/step - loss: 2.2976e-04 - mean_absolute_error: 0.0094 - mean_squared_error: 2.2976e-04 - mse_x: 1.0112e-05 - mse_y: 3.4144e-04 - mse_z: 3.3772e-04 - root_mean_squared_error: 0.0152 - val_loss: 7.6960e-04 - val_mean_absolute_error: 0.0222 - val_mean_squared_error: 7.6960e-04 - val_mse_x: 8.4050e-04 - val_mse_y: 0.0010 - val_mse_z: 4.2450e-04 - val_root_mean_squared_error: 0.0277
# Epoch 16/50
# 8585/8585 ━━━━━━━━━━━━━━━━━━━━ 117s 14ms/step - loss: 2.2910e-04 - mean_absolute_error: 0.0094 - mean_squared_error: 2.2910e-04 - mse_x: 1.0287e-05 - mse_y: 3.4095e-04 - mse_z: 3.3605e-04 - root_mean_squared_error: 0.0151 - val_loss: 9.5053e-04 - val_mean_absolute_error: 0.0236 - val_mean_squared_error: 9.5053e-04 - val_mse_x: 0.0018 - val_mse_y: 7.2667e-04 - val_mse_z: 3.6737e-04 - val_root_mean_squared_error: 0.0308
# Epoch 16: early stopping
# Modelo do split 4 salvo em models_GY87/lstm_split_4.keras

# %% [markdown]
# ### Salvar o Histórico do Treinamento (history.json)

# %%
import json

# Criar uma pasta para salvar os modelos
model_folder = "models_GY87"
config_path = os.path.join(model_folder, "history.json")
# Salvar o histórico do treinamento em um arquivo JSON
with open(config_path, "w") as f:
    json.dump(history.history, f)

# %% [markdown]
# ### Carregar o Histórico (history.json)

# %%
import json

model_folder = "models_GY87"
config_path = os.path.join(model_folder, "history.json")
# Carregar o histórico salvo
with open(config_path, "r") as f:
    loaded_history = json.load(f)

# Exemplo de acesso aos dados carregados
print("Chaves do histórico:", loaded_history.keys())
print("Perda final:", loaded_history["loss"][-1])
print("Validação final:", loaded_history["val_loss"][-1])
# Out:
# Chaves do histórico: dict_keys(['loss', 'mean_absolute_error', 'mean_squared_error', 'mse_x', 'mse_y', 'mse_z', 'root_mean_squared_error', 'val_loss', 'val_mean_absolute_error', 'val_mean_squared_error', 'val_mse_x', 'val_mse_y', 'val_mse_z', 'val_root_mean_squared_error'])
# Perda final: 0.0002291762357344851
# Validação final: 0.0009505306952632964

# %% [markdown]
# ### Visualizar o Histórico de Treinamento

# %%
import matplotlib.pyplot as plt

# Plotando a perda de treino e validação
plt.figure(figsize=(10,1))
plt.plot(loaded_history["loss"], label="loss")
plt.plot(loaded_history["val_loss"], label="val_loss")
plt.xlabel("Épocas")
plt.ylabel("Perda (Loss)")
plt.title("Evolução da Perda durante o Treinamento")
plt.legend()
plt.show()

# %% [markdown]
# # Avaliar o Modelo ******************************
# #### Após o treinamento de cada split, é avaliado o desempenho do modelo no conjunto de teste.

# %%
import sys
import os
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import load_model
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import TimeSeriesSplit
from sklearn.preprocessing import MinMaxScaler
import pickle

# Função para criar sequências
def create_sequences(data, n_timesteps):
    X, y = [], []
    for i in range(len(data) - n_timesteps):
        X.append(data[i:(i + n_timesteps)])
        y.append(data[i + n_timesteps])
    return np.array(X), np.array(y)

# Classe Tee para duplicar a saída (console e arquivo)
class Tee:
    def __init__(self, *files):
        self.files = files
        self.encoding = getattr(files[0], 'encoding', 'utf-8')
    def write(self, obj):
        for f in self.files:
            f.write(obj)
    def flush(self):
        for f in self.files:
            f.flush()

# Carregar dados e scaler
# print("Carregando dados...")
# file_path = './Dados/dados.txt'
# df = pd.read_csv(file_path, header=None, names=['X', 'Y', 'Z'])
# df = df[1300:1001300]

# Carregar o scaler
# with open('scaler.pkl', 'rb') as f:
#     scaler = pickle.load(f)

# Diretório onde salvar os resultados
model_folder = "models_GY87"
os.makedirs(model_folder, exist_ok=True)

# Arquivo de log para salvar o output com a mesma estrutura
log_path = os.path.join(model_folder, "evaluation.log")

# Abrir o arquivo com encoding 'utf-8' para evitar erros de caracteres
with open(log_path, "w", encoding="utf-8") as log_file:
    # Redireciona a saída padrão para imprimir tanto no console quanto no arquivo
    original_stdout = sys.stdout
    sys.stdout = Tee(original_stdout, log_file)
    
    print("Iniciando avaliação dos modelos...")
    
    # Inicializar lista para métricas
    results = []
    
    # Avaliar os modelos salvos
    for split_idx, (train_index, test_index) in enumerate(tscv.split(df_scaled.values), start=1):
        print(f"\n=== Avaliando Split {split_idx} ===")
        
        # Carregar o modelo salvo
        model_path = os.path.join(model_folder, f"lstm_split_{split_idx}.keras")
        
        if not os.path.exists(model_path):
            print(f"Modelo {model_path} não encontrado. Pulando...")
            continue
            
        try:
            model = load_model(model_path, custom_objects={
                "weighted_mse": weighted_mse,
                "mse_x": mse_x,
                "mse_y": mse_y,
                "mse_z": mse_z
            })
            print(f"Modelo carregado: {model_path}")
        except Exception as e:
            print(f"Erro ao carregar modelo {model_path}: {e}")
            continue
        
        # Criar os dados de teste
        test_data = df_scaled.values[test_index]
        X_test, y_test = create_sequences(test_data, n_timesteps)
        
        print(f"Dados de teste - X_test shape: {X_test.shape}, y_test shape: {y_test.shape}")
        
        # Validar shapes dos dados
        assert X_test.shape[0] == y_test.shape[0], "Número de exemplos em X_test e y_test não coincidem!"
        assert X_test.shape[1] == n_timesteps, "Número de timesteps em X_test está incorreto!"
        assert X_test.shape[2] == n_features, "Número de features em X_test está incorreto!"
        
        # Temporariamente restaura a saída padrão para evitar que o progress bar seja capturado no log
        temp_stdout = sys.stdout
        sys.stdout = original_stdout
        
        print(f"Fazendo predições para o split {split_idx}...")
        # Fazer previsões (verbose=1 para exibir o progress bar no console)
        y_pred = model.predict(X_test, verbose=1)
        
        # Após a predição, volta a redirecionar a saída para o nosso Tee
        sys.stdout = temp_stdout
        
        print(f"Predições concluídas - shape: {y_pred.shape}")
        
        # Cálculo das métricas
        mse_total = mean_squared_error(y_test, y_pred)
        r2_total = r2_score(y_test, y_pred)
        mse_x_val = mean_squared_error(y_test[:, 0], y_pred[:, 0])
        r2_x = r2_score(y_test[:, 0], y_pred[:, 0])
        mse_y_val = mean_squared_error(y_test[:, 1], y_pred[:, 1])
        r2_y = r2_score(y_test[:, 1], y_pred[:, 1])
        mse_z_val = mean_squared_error(y_test[:, 2], y_pred[:, 2])
        r2_z = r2_score(y_test[:, 2], y_pred[:, 2])
        
        # Salvando métricas
        results.append({
            'split': split_idx,
            'mse_total': mse_total, 'r2_total': r2_total,
            'mse_x': mse_x_val, 'r2_x': r2_x,
            'mse_y': mse_y_val, 'r2_y': r2_y,
            'mse_z': mse_z_val, 'r2_z': r2_z
        })
        
        # Imprimir output no formato desejado (sem os updates do progress bar)
        print(f"Split {split_idx} - MSE Total: {mse_total:.6f}, R² Total: {r2_total:.6f}")
        print(f"Split {split_idx} - MSE X: {mse_x_val:.6f}, R² X: {r2_x:.6f}")
        print(f"Split {split_idx} - MSE Y: {mse_y_val:.6f}, R² Y: {r2_y:.6f}")
        print(f"Split {split_idx} - MSE Z: {mse_z_val:.6f}, R² Z: {r2_z:.6f}")
    
    # Consolidar os resultados em um DataFrame
    if results:
        df_results = pd.DataFrame(results)
        
        # Salvar os resultados em CSV
        csv_path = os.path.join(model_folder, "evaluation_results.csv")
        df_results.to_csv(csv_path, index=False)
        print(f"\nResultados salvos em {csv_path}")
        
        # Calcular e exibir estatísticas resumidas
        print("\n=== RESUMO DOS RESULTADOS ===")
        print("Médias das métricas:")
        for col in df_results.columns:
            if col != 'split':
                print(f"{col}: {df_results[col].mean():.6f} ± {df_results[col].std():.6f}")
    else:
        print("Nenhum modelo foi avaliado com sucesso.")
    
    # Restaurar a saída padrão
    sys.stdout = original_stdout

print("Avaliação concluída!")
# Out:
# Iniciando avaliação dos modelos...
#
# === Avaliando Split 1 ===
# Modelo carregado: models_GY87/lstm_split_1.keras
# Dados de teste - X_test shape: (257466, 80, 3), y_test shape: (257466, 3)
# Fazendo predições para o split 1...
# 8046/8046 ━━━━━━━━━━━━━━━━━━━━ 19s 2ms/step
# Predições concluídas - shape: (257466, 3)
# Split 1 - MSE Total: 0.021113, R² Total: -3.577661
# Split 1 - MSE X: 0.009007, R² X: -11.984441
# Split 1 - MSE Y: 0.029016, R² Y: 0.471606
# Split 1 - MSE Z: 0.025315, R² Z: 0.779852
#
# === Avaliando Split 2 ===
# Modelo carregado: models_GY87/lstm_split_2.keras
# Dados de teste - X_test shape: (257466, 80, 3), y_test shape: (257466, 3)
# Fazendo predições para o split 2...
# 8046/8046 ━━━━━━━━━━━━━━━━━━━━ 19s 2ms/step
# Predições concluídas - shape: (257466, 3)
# Split 2 - MSE Total: 0.058359, R² Total: -0.900572
# Split 2 - MSE X: 0.007443, R² X: 0.987570
# Split 2 - MSE Y: 0.129664, R² Y: -4.365834
# Split 2 - MSE Z: 0.037970, R² Z: 0.676548
#
# === Avaliando Split 3 ===
# Modelo carregado: models_GY87/lstm_split_3.keras
# Dados de teste - X_test shape: (257466, 80, 3), y_test shape: (257466, 3)
# Fazendo predições para o split 3...
# 8046/8046 ━━━━━━━━━━━━━━━━━━━━ 20s 2ms/step
# Predições concluídas - shape: (257466, 3)
# Split 3 - MSE Total: 0.025161, R² Total: 0.268717
# Split 3 - MSE X: 0.001971, R² X: 0.796020
# Split 3 - MSE Y: 0.002315, R² Y: 0.907840
# Split 3 - MSE Z: 0.071197, R² Z: -0.897708
#
# === Avaliando Split 4 ===
# Modelo carregado: models_GY87/lstm_split_4.keras
# Dados de teste - X_test shape: (257466, 80, 3), y_test shape: (257466, 3)
# Fazendo predições para o split 4...
# 8046/8046 ━━━━━━━━━━━━━━━━━━━━ 20s 2ms/step
# Predições concluídas - shape: (257466, 3)
# Split 4 - MSE Total: 0.000951, R² Total: 0.960563
# Split 4 - MSE X: 0.001758, R² X: 0.946996
# Split 4 - MSE Y: 0.000726, R² Y: 0.964563
# Split 4 - MSE Z: 0.000367, R² Z: 0.970131
#
# Resultados salvos em models_GY87/evaluation_results.csv
#
# === RESUMO DOS RESULTADOS ===
# Médias das métricas:
# mse_total: 0.026396 ± 0.023794
# r2_total: -0.812238 ± 1.997219
# mse_x: 0.005045 ± 0.003728
# r2_x: -2.313464 ± 6.447845
# mse_y: 0.040430 ± 0.060888
# r2_y: -0.505457 ± 2.582991
# mse_z: 0.033712 ± 0.029471
# r2_z: 0.382206 ± 0.861896
# Avaliação concluída!

# %% [markdown]
# # Carregando o modelo desejado pelo split

# %%
import os
import tensorflow as tf
from tensorflow.keras.models import load_model
from tensorflow.keras import backend as K

# Definindo o diretório onde o modelo está salvo
model_folder = "models_GY87"
model_path = os.path.join(model_folder, 'lstm_split_4.keras')

# Carregando o modelo com todas as funções customizadas
modelo_carregado = load_model(
    model_path, 
    custom_objects={
        "weighted_mse": weighted_mse,
        "mse_x": mse_x,
        "mse_y": mse_y,
        "mse_z": mse_z
    }
)

print(modelo_carregado.summary())
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 100)            │        41,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 3)              │           303 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 125,712 (491.07 KB)
#  Trainable params: 41,903 (163.68 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 83,809 (327.38 KB)
# None

# %% [markdown]
# Fazendo previsões

# %%
predicted = modelo_carregado.predict(X_test)
# predicted = y_pred
# Out:
# 8046/8046 ━━━━━━━━━━━━━━━━━━━━ 20s 2ms/step

# %% [markdown]
# Plotando os Resultados

# %%
epochs = range(1, len(history.history['loss']) + 1)

plt.plot(epochs, history.history['loss'], label='Train Loss')
plt.plot(epochs, history.history['val_loss'], label='Validation Loss')
plt.plot(epochs, history.history['mean_squared_error'], label='MSE')
plt.plot(epochs, history.history['mean_absolute_error'], label='MAE')
plt.plot(epochs, history.history['root_mean_squared_error'], label='RMSE')
plt.title('Training and Validation Metrics')
plt.xlabel('Epochs')
plt.ylabel('Value')
plt.legend()
plt.show()

# %%
# Definindo as dimensões
dims = ['X', 'Y', 'Z']

plt.figure(figsize=(15, 15))

# Criando um gráfico para cada dimensão
for i, dim in enumerate(dims):
    plt.subplot(3, 1, i+1)
    plt.plot(X_test[:, -1, i], label='Real')
    plt.plot(predicted[:, i], label='Previsto')
    plt.title(f'Comparação {dim}')
    plt.xlabel('Tempo')
    plt.ylabel(f'Valor {dim}')
    plt.legend()

plt.tight_layout()
plt.show()

# %%
# Criando a figura
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

# Plotando os valores reais
ax.scatter(X_test[:, -1, 0], X_test[:, -1, 1], X_test[:, -1, 2], color='blue', label='Real')

# Plotando os valores previstos
ax.scatter(predicted[:, 0], predicted[:, 1], predicted[:, 2], color='red', label='Previsto')

ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
plt.title('Comparação 3D entre Valores Reais e Previstos')
plt.legend()
plt.show()

# %% [markdown]
# ## Mean Squared Error e $R^2$

# %%
mse = mean_squared_error(y_test, predicted)
r2 = r2_score(y_test, predicted)

MSE_R2 = {
    "MSE: ":mse,
    "R2: ": r2
}
# Salvar os hiperparâmetros em um arquivo JSON
model_folder = "models_GY87"
config_path = os.path.join(model_folder, "1.Mean Squared Error e R2.Teste.json")
with open(config_path, "w") as f:
    json.dump(MSE_R2, f, indent=4)

print(f"Hiperparâmetros salvos em {config_path}")

print("MSE:", mse)
print("R²:", r2)
# Out:
# Hiperparâmetros salvos em models_GY87/1.Mean Squared Error e R2.Teste.json
# MSE: 0.0009507070202422955
# R²: 0.9605631523825605

# %% [markdown]
# # _________________________________________________________________________________________________
# # Teste em um NOVO conjunto de dados do mesmo sensor, o Sensor 1

# %% [markdown]
# Carregando Dados Sensor 1

# %%
# Carregar os dados do arquivo
file_path1 = './Dados/sensor_data GY-87_1.1.txt'
df1_1 = pd.read_csv(file_path1, header=None, names=['X', 'Y', 'Z'])
print(len(df1_1))
print(df1_1.head())
# Out:
# 375151
#           X          Y           Z
# 0 -8.789435  -8.031115 -131.726822
# 1 -2.515755   9.834208  -65.708527
# 2  0.286306  28.450745  113.858810
# 3 -8.749084  32.791618  172.558365
# 4 -7.755535  26.062883  176.409973

# %% [markdown]
# ### Retirando Outliers

# %%
df_cleaned1_1 = remove_outliers_rolling_mad(df1_1, ['X','Y','Z'], window=5000, k=15)
# Exibir as primeiras linhas do DataFrame limpo
print(df_cleaned1_1.head())
df1_1=df_cleaned1_1
# Out:
#              X         Y          Z
# 5000  1.051740 -1.874325 -12.327733
# 5001  1.063928 -1.864345 -12.292420
# 5002  1.122944 -1.909463 -12.261428
# 5003  1.090499 -1.852442 -12.184809
# 5004  1.059289 -1.850853 -12.112368

# %% [markdown]
# Normalizando os dados

# %%
df1_1_scaled = normalizar_eixos_independente(df1_1)[0]

print(df1_1_scaled.head())
# Out:
#           X         Y         Z
# 0 -0.942440  0.065874 -0.680443
# 1 -0.941156  0.070952 -0.679672
# 2 -0.934941  0.047994 -0.678995
# 3 -0.938358  0.077009 -0.677323
# 4 -0.941645  0.077817 -0.675741

# %% [markdown]
# Preparando os dados de Teste do Sensor 1

# %%
# Supondo que test_data seja seu DataFrame de teste normalizado
# Convertendo para numpy array
values_test1 = df1_1_scaled.values

# Reformatando os dados para a entrada LSTM
X_test1_1, y_test1_1 = [], []
for i in range(len(values_test1) - n_timesteps):
    X_test1_1.append(values_test1[i:(i + n_timesteps), :])
    y_test1_1.append(values_test1[i + n_timesteps, :])
X_test1_1, y_test1_1 = np.array(X_test1_1), np.array(y_test1_1)

# Agora X_test e y_test estão prontos para serem usados para testar o modelo

# %% [markdown]
# Fazendo a predição

# %%
predicted1_1 = modelo_carregado.predict(X_test1_1)
# Out:
# 11407/11407 ━━━━━━━━━━━━━━━━━━━━ 28s 2ms/step

# %% [markdown]
# Plotando os resultados

# %%
# Definindo as dimensões
dims = ['X', 'Y', 'Z']

plt.figure(figsize=(15, 15))

# Criando um gráfico para cada dimensão
for i, dim in enumerate(dims):
    plt.subplot(3, 1, i+1)
    plt.plot(X_test1_1[:, -1, i], label='Real')
    plt.plot(predicted1_1[:, i], label='Previsto')
    plt.title(f'Comparação {dim}')
    plt.xlabel('Tempo')
    plt.ylabel(f'Valor {dim}')
    plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Mean Squared Error e $R^2$ nos novos dados do Sensor 1 ******************

# %%
mse = mean_squared_error(y_test1_1, predicted1_1)
r2 = r2_score(y_test1_1, predicted1_1)

MSE_R2 = {
    "MSE: ":mse,
    "R2: ": r2
}
# Salvar os hiperparâmetros em um arquivo JSON
model_folder = "models_GY87"
config_path = os.path.join(model_folder, "2.Mean Squared Error e R2.NewData.json")
with open(config_path, "w") as f:
    json.dump(MSE_R2, f, indent=4)

print(f"Hiperparâmetros salvos em {config_path}")

print("MSE:", mse)
print("R²:", r2)
# Out:
# Hiperparâmetros salvos em models_GY87/2.Mean Squared Error e R2.NewData.json
# MSE: 0.07200807885281059
# R²: 0.6140607248443738

# %% [markdown]
# ### Estabilizando o dados estaticos (POC)

# %%
# Suponha que df_novos_dados seja o DataFrame com os novos dados do sensor
# e que o modelo já tenha sido carregado e esteja pronto para uso
# Carregar os novos dados do sensor
file_path = './Dados/sensor_data GY-87_2.txt'  # Substitua pelo caminho correto do arquivo
df_novos_dados = pd.read_csv(file_path, header=None, names=['X', 'Y', 'Z'])

df_novos_dados_cleaned = remove_outliers_rolling_mad(df_novos_dados, ['X', 'Y', 'Z'], window=5000, k=15)
# Normalizar os novos dados
df_novos_dados_scaled = pd.DataFrame(normalizar_eixos_independente(df_novos_dados_cleaned)[0], columns=df_novos_dados_cleaned.columns)

# Preparar os dados para o modelo
values_novos_dados = df_novos_dados_scaled.values
X_novos_dados = []
for i in range(len(values_novos_dados) - n_timesteps):
    X_novos_dados.append(values_novos_dados[i:(i + n_timesteps)])
X_novos_dados = np.array(X_novos_dados)

# Fazer previsões com o modelo para cada sequência
predicted_novos_dados = modelo_carregado.predict(X_novos_dados)
# Out:
# 20904/20904 ━━━━━━━━━━━━━━━━━━━━ 51s 2ms/step

# %%
# Plotar comparações entre os dados originais e preditos para cada eixo
def plot_comparacao_original_predito(values_novos_dados, predicted_novos_dados, n_timesteps):
    valores_originais = values_novos_dados[n_timesteps:]  # alinhar com predição

    plt.figure(figsize=(15, 10))

    # Eixo X
    plt.subplot(3, 1, 1)
    plt.plot(valores_originais[:, 0], label='Original X', alpha=0.5)
    plt.plot(predicted_novos_dados[:, 0], label='Predito X', linestyle='--')
    plt.title('Comparação dos Dados - Eixo X')
    plt.ylabel('X')
    plt.legend()

    # Eixo Y
    plt.subplot(3, 1, 2)
    plt.plot(valores_originais[:, 1], label='Original Y', alpha=0.5)
    plt.plot(predicted_novos_dados[:, 1], label='Predito Y', linestyle='--')
    plt.title('Comparação dos Dados - Eixo Y')
    plt.ylabel('Y')
    plt.legend()

    # Eixo Z
    plt.subplot(3, 1, 3)
    plt.plot(valores_originais[:, 2], label='Original Z', alpha=0.5)
    plt.plot(predicted_novos_dados[:, 2], label='Predito Z', linestyle='--')
    plt.title('Comparação dos Dados - Eixo Z')
    plt.ylabel('Z')
    plt.legend()

    plt.tight_layout()
    plt.show()

plot_comparacao_original_predito(values_novos_dados, predicted_novos_dados, n_timesteps)

# %% [markdown]
# Encontrar a Correção do Original com o Predito

# %%
import numpy as np
from scipy.signal import correlate

# Função para encontrar o melhor shift por correlação cruzada
def encontrar_melhor_shift(original, predito, max_shift=100):
    """Retorna o melhor deslocamento (positivo ou negativo)"""
    correlation = correlate(original, predito, mode='full')
    lags = np.arange(-len(predito)+1, len(original))
    best_shift = lags[np.argmax(correlation)]
    
    # Limitar o shift ao intervalo desejado
    best_shift = int(np.clip(best_shift, -max_shift, max_shift))
    return best_shift

# Determinar os melhores shifts para cada eixo
shifts = {}
for i, eixo in enumerate(['X', 'Y', 'Z']):
    original = values_novos_dados[n_timesteps:, i]
    predito = predicted_novos_dados[:, i]
    shifts[eixo] = encontrar_melhor_shift(original, predito)

print("Melhores shifts encontrados por eixo:", shifts)
# Out:
# Melhores shifts encontrados por eixo: {'X': -1, 'Y': -100, 'Z': -1}

# %% [markdown]
# #### Estabilização Normal com Ponderação Estática

# %%
# Inverter a normalização das previsões
# predicted_novos_dados_inverse = scaler.inverse_transform(predicted_novos_dados)

## Calcular a diferença entre os dados originais e as previsões
# diference = values_novos_dados[n_timesteps:] - predicted_novos_dados_inverse
# diference = values_novos_dados[n_timesteps:] -  predicted_novos_dados

# Fator de correcao
fator_correcao = 0.9  # Ajuste este valor conforme necessário
Shift = -100  # Valor negativo adianta a predição

# Aplicar o deslocamento (shift) nas previsões
predicted_shifted = np.roll(predicted_novos_dados, shift=Shift, axis=0)

# Corrigir os arrays para terem o mesmo comprimento
if Shift < 0:
    predicted_shifted = predicted_shifted[:Shift]
    values_base = values_novos_dados[n_timesteps:Shift]
else:
    predicted_shifted = predicted_shifted[Shift:]
    values_base = values_novos_dados[n_timesteps + Shift:]

# Correção suavizada (interpolação entre valor real e previsto)
dados_corrigidos = (1 - fator_correcao) * values_base + fator_correcao * predicted_shifted

# Criar um DataFrame com os dados corrigidos
df_corrigido = pd.DataFrame(dados_corrigidos, columns=df_novos_dados_scaled.columns)

# Exibir os dados corrigidos
print(df_corrigido.head())

# Plotar os dados originais e corrigidos para comparação
plt.figure(figsize=(15, 10))

# Plot para X
plt.subplot(3, 1, 1)
plt.plot(df_novos_dados_scaled['X'][n_timesteps:], label='Original X', alpha=0.5)
plt.plot(df_corrigido['X'], label='Corrigido X', linestyle='--')
plt.title('Comparação dos Dados - X')
plt.ylabel('X')
plt.legend()

# Plot para Y
plt.subplot(3, 1, 2)
plt.plot(df_novos_dados_scaled['Y'][n_timesteps:], label='Original Y', alpha=0.5)
plt.plot(df_corrigido['Y'], label='Corrigido Y', linestyle='--')
plt.title('Comparação dos Dados - Y')
plt.ylabel('Y')
plt.legend()

# Plot para Z
plt.subplot(3, 1, 3)
plt.plot(df_novos_dados_scaled['Z'][n_timesteps:], label='Original Z', alpha=0.5)
plt.plot(df_corrigido['Z'], label='Corrigido Z', linestyle='--')
plt.title('Comparação dos Dados - Z')
plt.ylabel('Z')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
#           X         Y         Z
# 0  0.293399  0.156719 -0.886068
# 1  0.299290  0.091952 -0.896574
# 2  0.306180  0.146321 -0.892560
# 3  0.306275  0.189893 -0.889135
# 4  0.302460  0.099855 -0.904771

# %% [markdown]
# #### Estabilização Normal com Ponderação Dinâmica com base no erro RMS (Root Mean Square)

# %% [markdown]
# Código

# %%
# Função para calcular o RMS entre dados corrigidos e predição
def calcular_rms(fator_correcao, original, previsto):
    corrigido = (1 - fator_correcao) * original + fator_correcao * previsto
    rms = np.sqrt(mean_squared_error(previsto, corrigido))
    return rms

# Intervalo de teste para o fator de correção
valores_fator = np.linspace(0.0, 1.0, num=101)
rms_valores = []

# Avaliar todos os fatores
for fator in valores_fator:
    erro = calcular_rms(fator, values_novos_dados[n_timesteps:], predicted_novos_dados)
    rms_valores.append(erro)

# Encontrar o fator ótimo
melhor_indice = np.argmin(rms_valores)
fator_ideal = valores_fator[melhor_indice]

print(f"Melhor fator de correção encontrado: {fator_ideal:.4f}")
# Out:
# Melhor fator de correção encontrado: 1.0000

# %% [markdown]
# Aplicar correção com o melhor fator

# %%
# Corrigir os dados com o fator ótimo
dados_corrigidos = (1 - fator_ideal) * values_novos_dados[n_timesteps:] + fator_ideal * predicted_novos_dados

# Gerar DataFrame corrigido
df_corrigido = pd.DataFrame(dados_corrigidos, columns=df_novos_dados_scaled.columns)

# %% [markdown]
# Visualizar

# %%
plt.plot(valores_fator, rms_valores)
plt.axvline(fator_ideal, color='r', linestyle='--', label=f'Ótimo = {fator_ideal:.4f}')
plt.title('RMS em função do fator de correção')
plt.xlabel('Fator de Correção')
plt.ylabel('Erro RMS')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # _________________________________________________________________________________________________
# # Teste em um conjunto de dados do Sensor 2

# %% [markdown]
# Carregando Dados Sensor 2

# %%
# Carregar os dados do arquivo
file_path2 = './Dados/sensor_data GY-87_2.txt'
df2 = pd.read_csv(file_path2, header=None, names=['X', 'Y', 'Z'])
print(len(df2))
print(df2.head())
# Out:
# 679677
#           X         Y           Z
# 0  2.074969 -1.760471 -156.014709
# 1  2.016577 -1.740992 -155.957504
# 2  2.081915 -1.768907 -155.949951
# 3  1.988364 -1.707933 -155.927551
# 4  2.007283 -1.757901 -155.936005

# %% [markdown]
# #### Retirando Outliers

# %%
# se k menor = mais agressivo
df2_cleaned = remove_outliers_rolling_mad(df2, ['X','Y','Z'], window=5000, k=15)
# Exibir as primeiras linhas do DataFrame limpo
print(df2_cleaned.head())
df2=df2_cleaned
# Out:
#              X         Y           Z
# 5000  2.035090 -1.797416 -156.061478
# 5001  2.024974 -1.734467 -156.017868
# 5002  2.006305 -1.769469 -156.019836
# 5003  2.073869 -1.777356 -155.961670
# 5004  2.072165 -1.784499 -155.941757

# %% [markdown]
# Normalizando os dados

# %%
df2_scaled = pd.DataFrame(normalizar_eixos_independente(df2_cleaned)[0], columns=df2_cleaned.columns)

print(df2_scaled.head())
# Out:
#           X         Y         Z
# 0  0.361364 -0.242292 -0.998610
# 1  0.360581 -0.173196 -0.998367
# 2  0.359135 -0.211616 -0.998378
# 3  0.364367 -0.220274 -0.998054
# 4  0.364235 -0.228114 -0.997943

# %% [markdown]
# Preparando os dados de Teste do Sensor 2

# %%
# Supondo que test_data seja seu DataFrame de teste normalizado
# Convertendo para numpy array
values_test2 = df2_scaled.values

# Reformatando os dados para a entrada LSTM
X_test2, y_test2 = [], []
for i in range(len(values_test2) - n_timesteps):
    X_test2.append(values_test2[i:(i + n_timesteps), :])
    y_test2.append(values_test2[i + n_timesteps, :])
X_test2, y_test2 = np.array(X_test2), np.array(y_test2)

# Agora X_test e y_test estão prontos para serem usados para testar o modelo

# %% [markdown]
# Fazendo a predição

# %%
predicted2 = modelo_carregado.predict(X_test2)
# Out:
# 20904/20904 ━━━━━━━━━━━━━━━━━━━━ 51s 2ms/step

# %% [markdown]
# Plotando os resultados

# %%
# Definindo as dimensões
dims = ['X', 'Y', 'Z']

plt.figure(figsize=(15, 15))

# Criando um gráfico para cada dimensão
for i, dim in enumerate(dims):
    plt.subplot(3, 1, i+1)
    plt.plot(X_test2[:, -1, i], label='Real')
    plt.plot(predicted2[:, i], label='Previsto')
    plt.title(f'Comparação {dim}')
    plt.xlabel('Tempo')
    plt.ylabel(f'Valor {dim}')
    plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Mean Squared Error e $R^2$ no Sensor 2

# %%
mse = mean_squared_error(y_test2, predicted2)
r2 = r2_score(y_test2, predicted2)

MSE_R2 = {
    "MSE: ":mse,
    "R2: ": r2
}
# Salvar os hiperparâmetros em um arquivo JSON
model_folder = "models_GY87"
config_path = os.path.join(model_folder, "3.Mean Squared Error e R2.Sensor2.json")
with open(config_path, "w") as f:
    json.dump(MSE_R2, f, indent=4)

print(f"Hiperparâmetros salvos em {config_path}")

print("MSE:", mse)
print("R²:", r2)
# Out:
# Hiperparâmetros salvos em models_GY87/3.Mean Squared Error e R2.Sensor2.json
# MSE: 0.044644837698038654
# R²: -0.704358711882714

# %% [markdown]
# # ________________________________________________________________________________________________
# # Teste em um conjunto de dados do Sensor 3

# %% [markdown]
# Carregando Dados Sensor 2

# %%
# Carregar os dados do arquivo
file_path3 = './Dados/sensor_data GY-87_3.txt'
df3 = pd.read_csv(file_path3, header=None, names=['X', 'Y', 'Z'])
print(len(df3))
print(df3.head())
# Out:
# 326874
#           X         Y           Z
# 0  0.224601  0.665587 -152.545502
# 1  0.197612  0.691833 -152.660934
# 2  0.253607  0.761412 -152.565216
# 3  0.168086  0.728715 -152.653824
# 4  0.161009  0.711798 -152.691010

# %% [markdown]
# ### Retirando Outliers

# %%
# se k menor = mais agressivo
df3_cleaned = remove_outliers_rolling_mad(df3, ['X','Y','Z'], window=5000, k=15)
# Exibir as primeiras linhas do DataFrame limpo
print(df3_cleaned.head())
df3=df3_cleaned
# Out:
#              X         Y           Z
# 5000  0.111091  0.784004 -152.576538
# 5001  0.165380  0.739138 -152.526550
# 5002  0.093191  0.683545 -152.524918
# 5003  0.142345  0.733310 -152.680298
# 5004  0.105950  0.713201 -152.757645

# %% [markdown]
# Normalizando os dados

# %%
df3_scaled = pd.DataFrame(normalizar_eixos_independente(df3)[0], columns=df3.columns)

print(df3_scaled.head())
# Out:
#           X         Y         Z
# 0  0.214491  0.000951 -0.998056
# 1  0.217768 -0.035768 -0.997778
# 2  0.213410 -0.081267 -0.997769
# 3  0.216378 -0.040538 -0.998633
# 4  0.214181 -0.056996 -0.999063

# %% [markdown]
# Preparando os dados de Teste do Sensor 3

# %%
# Supondo que test_data seja seu DataFrame de teste normalizado
# Convertendo para numpy array
values_test3 = df3_scaled.values

# Reformatando os dados para a entrada LSTM
X_test3, y_test3 = [], []
for i in range(len(values_test3) - n_timesteps):
    X_test3.append(values_test3[i:(i + n_timesteps), :])
    y_test3.append(values_test3[i + n_timesteps, :])
X_test3, y_test3 = np.array(X_test3), np.array(y_test3)

# Agora X_test e y_test estão prontos para serem usados para testar o modelo

# %% [markdown]
# Fazendo a predição

# %%
predicted3 = modelo_carregado.predict(X_test3)
# Out:
# 9879/9879 ━━━━━━━━━━━━━━━━━━━━ 24s 2ms/step

# %% [markdown]
# Plotando os resultados

# %%
# Definindo as dimensões
dims = ['X', 'Y', 'Z']

plt.figure(figsize=(15, 15))

# Criando um gráfico para cada dimensão
for i, dim in enumerate(dims):
    plt.subplot(3, 1, i+1)
    plt.plot(X_test3[:, -1, i], label='Real')
    plt.plot(predicted3[:, i], label='Previsto')
    plt.title(f'Comparação {dim}')
    plt.xlabel('Tempo')
    plt.ylabel(f'Valor {dim}')
    plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Mean Squared Error e $R^2$ no Sensor 3

# %%
mse = mean_squared_error(y_test3, predicted3)
r2 = r2_score(y_test3, predicted3)

MSE_R2 = {
    "MSE: ":mse,
    "R2: ": r2
}
# Salvar os hiperparâmetros em um arquivo JSON
model_folder = "models_GY87"
config_path = os.path.join(model_folder, "4.Mean Squared Error e R2.Sensor3.json")
with open(config_path, "w") as f:
    json.dump(MSE_R2, f, indent=4)

print(f"Hiperparâmetros salvos em {config_path}")

print("MSE:", mse)
print("R²:", r2)
# Out:
# Hiperparâmetros salvos em models_GY87/4.Mean Squared Error e R2.Sensor3.json
# MSE: 0.030845539948827633
# R²: 0.7745082990099467
