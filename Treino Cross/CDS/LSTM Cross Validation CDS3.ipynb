# %%
# %pip install --upgrade pip
# %pip install pandas
# %pip install scikit-learn
# %pip install tensorflow
# %pip install keras
# %pip install matplotlib
# %pip install ipympl

# %%
import os
import tensorflow as tf 
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Input
from tensorflow.keras.models import load_model
from keras.callbacks import EarlyStopping
from keras import metrics
from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from tensorflow.keras import backend as K
from tensorflow.keras.optimizers import Nadam
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.regularizers import l2
import gc
import pickle
import pandas as pd
import numpy as np
# %matplotlib inline
# %matplotlib widget
import matplotlib.pyplot as plt

# %% [markdown]
# ## Lista de hardware para IA

# %%
from tensorflow.python.client import device_lib

print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 17196484224123029159
# xla_global_id: -1
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 10182721536
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 7636816437871465211
# physical_device_desc: "device: 0, name: NVIDIA GeForce RTX 3060, pci bus id: 0000:01:00.0, compute capability: 8.6"
# xla_global_id: 416903419
# ]
# I0000 00:00:1758405998.839278    1945 gpu_device.cc:2019] Created device /device:GPU:0 with 9711 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060, pci bus id: 0000:01:00.0, compute capability: 8.6

# %% [markdown]
# Carregando os dados do sensor 1

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.19.0

# %%
# Carregar os dados do arquivo
file_path = './Dados/dados.txt'
df = pd.read_csv(file_path, header=None, names=['X', 'Y', 'Z'])
# df = df[1300:700000]
df = df[1300:1300000]
print(len(df))
print(df[:10])
# Out:
# 1298700
#              X         Y          Z
# 1300 -1.781370  0.741914 -64.231506
# 1301 -1.694854  0.759592 -64.239250
# 1302 -1.597467  0.700346 -64.256279
# 1303 -1.739162  0.631860 -64.236961
# 1304 -1.736698  0.634045 -64.259636
# 1305 -1.734998  0.728971 -64.111877
# 1306 -1.678491  0.770313 -64.238266
# 1307 -1.692173  0.711976 -64.377014
# 1308 -1.698621  0.677731 -64.420242
# 1309 -1.707504  0.719441 -64.463936

# %%
print(f"Intervalo X: {df['X'].min()} a {df['X'].max()}")
print(f"Intervalo Y: {df['Y'].min()} a {df['Y'].max()}")
print(f"Intervalo Z: {df['Z'].min()} a {df['Z'].max()}")


# Supondo que 'df' é seu DataFrame original com as colunas 'X', 'Y', 'Z'
plt.figure(figsize=(12, 6))

# Plotando cada coluna
plt.subplot(3, 1, 1)  # 3 linhas, 1 coluna, posição 1
plt.plot(df['X'], label='X')
plt.title('Sensor Data - X')
plt.ylabel('X')

plt.subplot(3, 1, 2)  # 3 linhas, 1 coluna, posição 2
plt.plot(df['Y'], label='Y')
plt.title('Sensor Data - Y')
plt.ylabel('Y')

plt.subplot(3, 1, 3)  # 3 linhas, 1 coluna, posição 3
plt.plot(df['Z'], label='Z')
plt.title('Sensor Data - Z')
plt.ylabel('Z')
plt.xlabel('Sample Number')

# Mostrando o gráfico
plt.tight_layout()
plt.show()
# Out:
# Intervalo X: -16.6888427734375 a 34.93269729614258
# Intervalo Y: -7.707679748535156 a 5.511822700500488
# Intervalo Z: -72.52067565917969 a -27.74943351745605

# %% [markdown]
# ### Retirando os outliers

# %%
def remove_outliers_rolling_mad(df, columns, window=2000, k=5):
    mask_all = pd.Series(True, index=df.index)
    for col in columns:
        med = df[col].rolling(window, center=True).median()
        mad = (df[col] - med).abs().rolling(window, center=True).median() * 1.4826
        mask = ((df[col] - med).abs() <= k*mad).fillna(True)
        mask_all &= mask
    return df[mask_all]
# se k menor = mais agressivo
df_cleaned = remove_outliers_rolling_mad(df, ['X','Y','Z'], window=5000, k=5)
# Exibir as primeiras linhas do DataFrame limpo
print(df_cleaned.head())
# Out:
#              X         Y          Z
# 6300 -1.728978  0.804295 -64.236565
# 6301 -1.727947  0.823530 -64.243980
# 6302 -1.688770  0.835619 -64.357346
# 6303 -1.690171  0.833158 -64.411293
# 6304 -1.710678  0.793233 -64.402336

# %%
print(f"Intervalo X: {df_cleaned['X'].min()} a {df_cleaned['X'].max()}")
print(f"Intervalo Y: {df_cleaned['Y'].min()} a {df_cleaned['Y'].max()}")
print(f"Intervalo Z: {df_cleaned['Z'].min()} a {df_cleaned['Z'].max()}")

plt.figure(figsize=(12, 6))

# Plotar os dados após a remoção de outliers
plt.subplot(3, 1, 1)
plt.plot(df_cleaned['X'], label='X')
plt.title('Sensor Data - X (Sem Outliers)')
plt.ylabel('X')

plt.subplot(3, 1, 2)
plt.plot(df_cleaned['Y'], label='Y')
plt.title('Sensor Data - Y (Sem Outliers)')
plt.ylabel('Y')

plt.subplot(3, 1, 3)
plt.plot(df_cleaned['Z'], label='Z')
plt.title('Sensor Data - Z (Sem Outliers)')
plt.ylabel('Z')
plt.xlabel('Sample Number')

plt.tight_layout()
plt.show()
# Out:
# Intervalo X: -10.7301025390625 a 33.67879867553711
# Intervalo Y: -2.3599417209625244 a 2.3370561599731445
# Intervalo Z: -72.52067565917969 a -59.457645416259766

# %% [markdown]
# # POR ENQUANDO IGNORE A RETIRADA DOS OUTLIERS

# %%
# COMENTEQUE QUISER QUE IGNORE A RETIRADA DOS OUTLIERS
df=df_cleaned

# %% [markdown]
# ## Normalizando os dados para uso do LSTM

# %%
# Definindo o range para -1 a 1, apropriado para sensores com valores entre -180 e 180
# scaler = MinMaxScaler(feature_range=(-1, 1))
# scaler = StandardScaler()

# Normalizando os dados
# df_scaled = pd.DataFrame(scaler.fit_transform(df), columns=df.columns)

# Salvando o scaler ajustado
# with open('scaler.pkl', 'wb') as f:
#     pickle.dump(scaler, f)

# Visualizando os primeiros dados normalizados
# print(df_scaled.head())
def normalizar_eixos_independente(dataframe):
    """
    Normaliza as colunas 'X', 'Y' e 'Z' de um DataFrame individualmente 
    com MinMaxScaler no intervalo (-1, 1).

    Retorna:
        df_scaled: DataFrame normalizado
        scalers: dicionário com os scalers {'X': scaler_X, 'Y': scaler_Y, 'Z': scaler_Z}
    """
    scaler_X = MinMaxScaler(feature_range=(-1, 1))
    scaler_Y = MinMaxScaler(feature_range=(-1, 1))
    scaler_Z = MinMaxScaler(feature_range=(-1, 1))

    df_scaled = pd.DataFrame()
    df_scaled['X'] = scaler_X.fit_transform(dataframe[['X']]).flatten()
    df_scaled['Y'] = scaler_Y.fit_transform(dataframe[['Y']]).flatten()
    df_scaled['Z'] = scaler_Z.fit_transform(dataframe[['Z']]).flatten()

    scalers = {'X': scaler_X, 'Y': scaler_Y, 'Z': scaler_Z}
    return df_scaled, scalers

df_scaled, scalers_tuple = normalizar_eixos_independente(df)


# # Salvar os scalers em um único arquivo (como uma tupla)
with open('scalers.pkl', 'wb') as f:
    pickle.dump(scalers_tuple, f)

# # Visualizando os primeiros dados normalizados
print(df_scaled.head())
# Out:
#           X         Y         Z
# 0 -0.594625  0.347344  0.268329
# 1 -0.594579  0.355535  0.267194
# 2 -0.592814  0.360682  0.249837
# 3 -0.592877  0.359634  0.241578
# 4 -0.593801  0.342634  0.242949

# %%
# Histogramas dos valores normalizados

df_scaled.hist(bins=50, figsize=(12, 4), layout=(1, 3))
plt.suptitle("Distribuição Normalizada dos Eixos X, Y e Z")
plt.show()

# %%
print(f"Intervalo X: {df_scaled['X'].min()} a {df_scaled['X'].max()}")
print(f"Intervalo Y: {df_scaled['Y'].min()} a {df_scaled['Y'].max()}")
print(f"Intervalo Z: {df_scaled['Z'].min()} a {df_scaled['Z'].max()}")


# Supondo que 'df' é seu DataFrame original com as colunas 'X', 'Y', 'Z'
plt.figure(figsize=(12, 6))

# Plotando cada coluna
plt.subplot(3, 1, 1)  # 3 linhas, 1 coluna, posição 1
plt.plot(df_scaled['X'], label='X')
plt.title('Sensor Data - X')
plt.ylabel('X')

plt.subplot(3, 1, 2)  # 3 linhas, 1 coluna, posição 2
plt.plot(df_scaled['Y'], label='Y')
plt.title('Sensor Data - Y')
plt.ylabel('Y')

plt.subplot(3, 1, 3)  # 3 linhas, 1 coluna, posição 3
plt.plot(df_scaled['Z'], label='Z')
plt.title('Sensor Data - Z')
plt.ylabel('Z')
plt.xlabel('Sample Number')

# Mostrando o gráfico
plt.tight_layout()
plt.show()
# Out:
# Intervalo X: -1.0 a 0.9999999999999999
# Intervalo Y: -1.0 a 1.0
# Intervalo Z: -1.0 a 1.0

# %% [markdown]
# # ******************************************************
# # HIPERPARAMETROS

# %%
# Valores dos hiperparâmetros
n_splits=4 # 4
timestepsValue = 64 # 10
pesosValue = tf.constant([1.0, 1.0, 1.0]) # ([1.0, 0.1, 1.0])
neuroniosValue = 324 # 380                                                                                                                                                                                                                                 # 25
dropoutValue = 0.14512369139123038
ativacaoType = 'tanh'
best_lr = 0.0019702991167906115
epocasValue = 50 # 50
batchValue = 608 # 600
pacienciaValue = 10 # 10

# Criar uma pasta para salvar os modelos
model_folder = "models_GY87"
os.makedirs(model_folder, exist_ok=True)

# Dicionário com os hiperparâmetros
experiment_config = {
    "Splits": n_splits,
    "timesteps": timestepsValue,
    "wights": pesosValue.numpy().tolist(),
    "neuronios": neuroniosValue,
    "dropout": dropoutValue,
    "ativacao": ativacaoType,
    "learning_rate": best_lr,
    "epocas": epocasValue,
    "batch": batchValue,
    "paciencia": pacienciaValue
}

# Salvar os hiperparâmetros em um arquivo JSON
import json
config_path = os.path.join(model_folder, "hiperparametros.json")
with open(config_path, "w") as f:
    json.dump(experiment_config, f, indent=4)

print(f"Hiperparâmetros salvos em {config_path}")
# Out:
# Hiperparâmetros salvos em models_GY87/hiperparametros.json

# %% [markdown]
# ## Definindo Cross Validation TimeSeriesSplit e Variáveis

# %%
# Função de perda ponderada (se quiser usar)
def weighted_mse_with_bias(y_true, y_pred):
    weights = pesosValue  # Tensor com shape (3,)
    mse = K.mean(weights * K.square(y_pred - y_true), axis=-1)
    bias = K.square(K.mean(y_true - y_pred, axis=0)) * weights # penaliza viés médio
    return mse + 0.1 * K.sum(bias)  # Ajuste o fator conforme a sensibilidade


# Função para monitorar o erro em cada eixo separadamente durante o treinamento.
# Assim, você pode ver se o modelo está realmente aprendendo em todos os eixos.
def mse_x(y_true, y_pred):
    return K.mean(K.square(y_pred[:, 0] - y_true[:, 0]))

def mse_y(y_true, y_pred):
    return K.mean(K.square(y_pred[:, 1] - y_true[:, 1]))

def mse_z(y_true, y_pred):
    return K.mean(K.square(y_pred[:, 2] - y_true[:, 2]))


tscv = TimeSeriesSplit(n_splits)
print(tscv)
# Out:
# TimeSeriesSplit(gap=0, max_train_size=None, n_splits=4, test_size=None)

# %% [markdown]
# ## Criar Sequências para Treino e Teste
# ### Transformando os dados de treino e teste em sequências temporais para serem usados como entrada no modelo LSTM.

# %%
# # Função para criar sequências
def create_sequences(data, n_timesteps):
    X, y = [], []
    for i in range(len(data) - n_timesteps):
        X.append(data[i:i+n_timesteps, :])  # Sequência de entrada
        y.append(data[i+n_timesteps, :])   # Próxima linha como saída
    return np.array(X), np.array(y)

# Definir o número de timesteps (janelas de tempo)
n_timesteps = timestepsValue  # Exemplo: 80 passos no tempo
n_features = df_scaled.shape[1]  # Número de colunas (X, Y, Z)

# %%
# Visualizar os splits gerados
for train_index, test_index in tscv.split(df_scaled):
    print(f"Treino: {len(train_index)} amostras, Teste: {len(test_index)} amostras")
    print(f"Treino: {train_index[:5]}...{train_index[-5:]}, Teste: {test_index[:5]}...{test_index[-5:]}")
# Out:
# Treino: 256816 amostras, Teste: 256815 amostras
# Treino: [0 1 2 3 4]...[256811 256812 256813 256814 256815], Teste: [256816 256817 256818 256819 256820]...[513626 513627 513628 513629 513630]
# Treino: 513631 amostras, Teste: 256815 amostras
# Treino: [0 1 2 3 4]...[513626 513627 513628 513629 513630], Teste: [513631 513632 513633 513634 513635]...[770441 770442 770443 770444 770445]
# Treino: 770446 amostras, Teste: 256815 amostras
# Treino: [0 1 2 3 4]...[770441 770442 770443 770444 770445], Teste: [770446 770447 770448 770449 770450]...[1027256 1027257 1027258 1027259 1027260]
# Treino: 1027261 amostras, Teste: 256815 amostras
# Treino: [0 1 2 3 4]...[1027256 1027257 1027258 1027259 1027260], Teste: [1027261 1027262 1027263 1027264 1027265]...[1284071 1284072 1284073 1284074 1284075]

# %% [markdown]
# ### Caso não queira treinar novamente, mas apenas executar a predição do modelo, descomente!

# %%
# Loop de treinamento para cada split
# for split_idx, (train_index, test_index) in enumerate(tscv.split(df_scaled.values), start=1):
#     # Criar os dados de treino e teste
#     train_data, test_data = df_scaled.values[train_index], df_scaled.values[test_index]
#     X_train, y_train = create_sequences(train_data, n_timesteps)
#     X_test, y_test = create_sequences(test_data, n_timesteps)
    
#     print(f"Split {split_idx}:")
#     print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
#     print(f"X_test shape: {X_test.shape}, y_test shape: {y_test.shape}")

# %% [markdown]
# # LSTM

# %% [markdown]
# ### Treinar o Modelo em Cada Split usando o Early Stopping e Salvando .keras
# Para cada split será treinado o modelo usando os dados de treino e será avaliado nos dados de teste. O EarlyStopping será usado para evitar overfitting.

# %%
# Loop de treinamento para cada split
for split_idx, (train_index, test_index) in enumerate(tscv.split(df_scaled.values), start=1):
    # Limpeza de memória antes de iniciar o próximo modelo
    K.clear_session()
    gc.collect()
    # Criar os dados de treino e teste
    train_data, test_data = df_scaled.values[train_index], df_scaled.values[test_index]
    X_train, y_train = create_sequences(train_data, n_timesteps)
    X_test, y_test = create_sequences(test_data, n_timesteps)
    
    print(f"Split {split_idx}:")
    print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
    print(f"X_test shape: {X_test.shape}, y_test shape: {y_test.shape}")

    # Configurar o modelo LSTM
    model = Sequential()
    model.add(Input(shape=(n_timesteps, n_features)))
    # Se quiser 4 camadas LSTM, descomente as linhas abaixo:
    # model.add(LSTM(units=270, activation='tanh', return_sequences=True))
    # model.add(LSTM(units=150, activation='tanh', return_sequences=True))
    # model.add(LSTM(units=175, activation='tanh', return_sequences=True))
    # model.add(LSTM(units=175, activation=ativacaoType))
    # Se quiser só 1 camada LSTM, use apenas a linha abaixo:
    # model.add(LSTM(units=neuroniosValue, activation=ativacaoType, kernel_regularizer=l2(0.001)))
    model.add(LSTM(units=324, activation=ativacaoType))
    # model.add(Dropout(dropoutValue))
    model.add(Dense(608, activation = 'relu')) # camada densa intermediária
    model.add(Dense(n_features))
    
    model.compile(
        optimizer = 'Nadam', # Nadam(learning_rate=best_lr),
        # optimizer = SGD(learning_rate=0.01, momentum=0.9),
        loss = 'mse',
        # loss = weighted_mse_with_bias,
        metrics=[
            metrics.MeanSquaredError(),
            metrics.MeanAbsoluteError(),
            metrics.RootMeanSquaredError(),
            mse_x, mse_y, mse_z  # métricas customizadas
        ]
    )

    # Treinar o modelo
    print(f"Treinando o modelo para o split {split_idx}...")
    history = model.fit(
        X_train, y_train,
        epochs=epocasValue,
        batch_size=batchValue,
        validation_data=(X_test, y_test),
        callbacks=[EarlyStopping(monitor='val_loss', patience=pacienciaValue, verbose=1, mode='min')],
        verbose=1
    )

    # Salvar o modelo no formato .keras
    model_path = os.path.join(model_folder, f"lstm_split_{split_idx}.keras")
    model.save(model_path)
    print(f"Modelo do split {split_idx} salvo em {model_path}")
# Out:
# Split 1:
# X_train shape: (256752, 64, 3), y_train shape: (256752, 3)
# X_test shape: (256751, 64, 3), y_test shape: (256751, 3)
# Treinando o modelo para o split 1...
# Epoch 1/50
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 67s 116ms/step - loss: 0.0081 - mean_absolute_error: 0.0336 - mean_squared_error: 0.0081 - mse_x: 0.0104 - mse_y: 0.0053 - mse_z: 0.0084 - root_mean_squared_error: 0.0726 - val_loss: 0.0171 - val_mean_absolute_error: 0.1026 - val_mean_squared_error: 0.0171 - val_mse_x: 0.0269 - val_mse_y: 0.0092 - val_mse_z: 0.0153 - val_root_mean_squared_error: 0.1308
# Epoch 2/50
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 21s 49ms/step - loss: 3.5924e-04 - mean_absolute_error: 0.0134 - mean_squared_error: 3.5924e-04 - mse_x: 3.6957e-05 - mse_y: 5.5267e-04 - mse_z: 4.8810e-04 - root_mean_squared_error: 0.0190 - val_loss: 0.0175 - val_mean_absolute_error: 0.1067 - val_mean_squared_error: 0.0175 - val_mse_x: 0.0283 - val_mse_y: 0.0077 - val_mse_z: 0.0167 - val_root_mean_squared_error: 0.1324
# Epoch 3/50
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 20s 46ms/step - loss: 3.4887e-04 - mean_absolute_error: 0.0131 - mean_squared_error: 3.4887e-04 - mse_x: 2.9997e-05 - mse_y: 5.3968e-04 - mse_z: 4.7694e-04 - root_mean_squared_error: 0.0187 - val_loss: 0.0224 - val_mean_absolute_error: 0.1192 - val_mean_squared_error: 0.0224 - val_mse_x: 0.0256 - val_mse_y: 0.0135 - val_mse_z: 0.0282 - val_root_mean_squared_error: 0.1496
# Epoch 4/50
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 20s 46ms/step - loss: 3.4618e-04 - mean_absolute_error: 0.0133 - mean_squared_error: 3.4618e-04 - mse_x: 4.9969e-05 - mse_y: 5.3157e-04 - mse_z: 4.5699e-04 - root_mean_squared_error: 0.0186 - val_loss: 0.0259 - val_mean_absolute_error: 0.1315 - val_mean_squared_error: 0.0259 - val_mse_x: 0.0209 - val_mse_y: 0.0272 - val_mse_z: 0.0299 - val_root_mean_squared_error: 0.1610
# Epoch 5/50
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 19s 46ms/step - loss: 3.2979e-04 - mean_absolute_error: 0.0127 - mean_squared_error: 3.2979e-04 - mse_x: 2.9543e-05 - mse_y: 5.3216e-04 - mse_z: 4.2765e-04 - root_mean_squared_error: 0.0182 - val_loss: 0.0207 - val_mean_absolute_error: 0.1151 - val_mean_squared_error: 0.0207 - val_mse_x: 0.0224 - val_mse_y: 0.0135 - val_mse_z: 0.0262 - val_root_mean_squared_error: 0.1438
# Epoch 6/50
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 19s 46ms/step - loss: 3.1385e-04 - mean_absolute_error: 0.0124 - mean_squared_error: 3.1385e-04 - mse_x: 2.5678e-05 - mse_y: 5.1389e-04 - mse_z: 4.0198e-04 - root_mean_squared_error: 0.0177 - val_loss: 0.0207 - val_mean_absolute_error: 0.1094 - val_mean_squared_error: 0.0207 - val_mse_x: 0.0224 - val_mse_y: 0.0169 - val_mse_z: 0.0229 - val_root_mean_squared_error: 0.1439
# Epoch 7/50
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 19s 45ms/step - loss: 3.0201e-04 - mean_absolute_error: 0.0120 - mean_squared_error: 3.0201e-04 - mse_x: 2.1719e-05 - mse_y: 5.1264e-04 - mse_z: 3.7166e-04 - root_mean_squared_error: 0.0174 - val_loss: 0.0249 - val_mean_absolute_error: 0.1208 - val_mean_squared_error: 0.0249 - val_mse_x: 0.0235 - val_mse_y: 0.0210 - val_mse_z: 0.0304 - val_root_mean_squared_error: 0.1579
# Epoch 8/50
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 19s 45ms/step - loss: 2.9920e-04 - mean_absolute_error: 0.0121 - mean_squared_error: 2.9920e-04 - mse_x: 2.9735e-05 - mse_y: 5.0766e-04 - mse_z: 3.6021e-04 - root_mean_squared_error: 0.0173 - val_loss: 0.0239 - val_mean_absolute_error: 0.1196 - val_mean_squared_error: 0.0239 - val_mse_x: 0.0230 - val_mse_y: 0.0203 - val_mse_z: 0.0286 - val_root_mean_squared_error: 0.1546
# Epoch 9/50
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 19s 45ms/step - loss: 2.9637e-04 - mean_absolute_error: 0.0121 - mean_squared_error: 2.9637e-04 - mse_x: 2.8131e-05 - mse_y: 5.0762e-04 - mse_z: 3.5337e-04 - root_mean_squared_error: 0.0172 - val_loss: 0.0242 - val_mean_absolute_error: 0.1200 - val_mean_squared_error: 0.0242 - val_mse_x: 0.0217 - val_mse_y: 0.0243 - val_mse_z: 0.0269 - val_root_mean_squared_error: 0.1557
# Epoch 10/50
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 19s 45ms/step - loss: 3.0116e-04 - mean_absolute_error: 0.0124 - mean_squared_error: 3.0116e-04 - mse_x: 3.8074e-05 - mse_y: 5.0490e-04 - mse_z: 3.6051e-04 - root_mean_squared_error: 0.0174 - val_loss: 0.0232 - val_mean_absolute_error: 0.1154 - val_mean_squared_error: 0.0232 - val_mse_x: 0.0156 - val_mse_y: 0.0265 - val_mse_z: 0.0276 - val_root_mean_squared_error: 0.1523
# Epoch 11/50
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 19s 45ms/step - loss: 2.9472e-04 - mean_absolute_error: 0.0122 - mean_squared_error: 2.9472e-04 - mse_x: 3.1766e-05 - mse_y: 5.0135e-04 - mse_z: 3.5106e-04 - root_mean_squared_error: 0.0172 - val_loss: 0.0270 - val_mean_absolute_error: 0.1331 - val_mean_squared_error: 0.0270 - val_mse_x: 0.0232 - val_mse_y: 0.0272 - val_mse_z: 0.0308 - val_root_mean_squared_error: 0.1644
# Epoch 11: early stopping
# Modelo do split 1 salvo em models_GY87/lstm_split_1.keras
# Split 2:
# X_train shape: (513567, 64, 3), y_train shape: (513567, 3)
# X_test shape: (256751, 64, 3), y_test shape: (256751, 3)
# Treinando o modelo para o split 2...
# Epoch 1/50
# 845/845 ━━━━━━━━━━━━━━━━━━━━ 49s 49ms/step - loss: 0.0068 - mean_absolute_error: 0.0291 - mean_squared_error: 0.0068 - mse_x: 0.0102 - mse_y: 0.0043 - mse_z: 0.0059 - root_mean_squared_error: 0.0656 - val_loss: 0.1021 - val_mean_absolute_error: 0.2566 - val_mean_squared_error: 0.1021 - val_mse_x: 0.0039 - val_mse_y: 0.1576 - val_mse_z: 0.1445 - val_root_mean_squared_error: 0.3195
# Epoch 2/50
# 845/845 ━━━━━━━━━━━━━━━━━━━━ 34s 40ms/step - loss: 5.0640e-04 - mean_absolute_error: 0.0157 - mean_squared_error: 5.0640e-04 - mse_x: 5.8929e-05 - mse_y: 5.7801e-04 - mse_z: 8.8224e-04 - root_mean_squared_error: 0.0225 - val_loss: 0.0955 - val_mean_absolute_error: 0.2551 - val_mean_squared_error: 0.0955 - val_mse_x: 0.0053 - val_mse_y: 0.1548 - val_mse_z: 0.1261 - val_root_mean_squared_error: 0.3090
# Epoch 3/50
# 845/845 ━━━━━━━━━━━━━━━━━━━━ 33s 39ms/step - loss: 4.2083e-04 - mean_absolute_error: 0.0144 - mean_squared_error: 4.2083e-04 - mse_x: 6.8346e-05 - mse_y: 5.5891e-04 - mse_z: 6.3522e-04 - root_mean_squared_error: 0.0205 - val_loss: 0.0883 - val_mean_absolute_error: 0.2528 - val_mean_squared_error: 0.0883 - val_mse_x: 0.0101 - val_mse_y: 0.1308 - val_mse_z: 0.1236 - val_root_mean_squared_error: 0.2971
# Epoch 4/50
# 845/845 ━━━━━━━━━━━━━━━━━━━━ 33s 39ms/step - loss: 4.0989e-04 - mean_absolute_error: 0.0143 - mean_squared_error: 4.0989e-04 - mse_x: 6.5529e-05 - mse_y: 5.5691e-04 - mse_z: 6.0723e-04 - root_mean_squared_error: 0.0202 - val_loss: 0.0791 - val_mean_absolute_error: 0.2449 - val_mean_squared_error: 0.0791 - val_mse_x: 0.0150 - val_mse_y: 0.1207 - val_mse_z: 0.1015 - val_root_mean_squared_error: 0.2813
# Epoch 5/50
# 845/845 ━━━━━━━━━━━━━━━━━━━━ 33s 40ms/step - loss: 3.9552e-04 - mean_absolute_error: 0.0139 - mean_squared_error: 3.9552e-04 - mse_x: 5.3423e-05 - mse_y: 5.3922e-04 - mse_z: 5.9393e-04 - root_mean_squared_error: 0.0199 - val_loss: 0.0572 - val_mean_absolute_error: 0.2164 - val_mean_squared_error: 0.0572 - val_mse_x: 0.0255 - val_mse_y: 0.0749 - val_mse_z: 0.0710 - val_root_mean_squared_error: 0.2391
# Epoch 6/50
# 845/845 ━━━━━━━━━━━━━━━━━━━━ 34s 41ms/step - loss: 3.9400e-04 - mean_absolute_error: 0.0140 - mean_squared_error: 3.9400e-04 - mse_x: 6.2220e-05 - mse_y: 5.3326e-04 - mse_z: 5.8652e-04 - root_mean_squared_error: 0.0198 - val_loss: 0.0470 - val_mean_absolute_error: 0.1987 - val_mean_squared_error: 0.0470 - val_mse_x: 0.0281 - val_mse_y: 0.0529 - val_mse_z: 0.0598 - val_root_mean_squared_error: 0.2167
# Epoch 7/50
# 845/845 ━━━━━━━━━━━━━━━━━━━━ 34s 40ms/step - loss: 3.8506e-04 - mean_absolute_error: 0.0137 - mean_squared_error: 3.8506e-04 - mse_x: 4.9458e-05 - mse_y: 5.2085e-04 - mse_z: 5.8488e-04 - root_mean_squared_error: 0.0196 - val_loss: 0.0362 - val_mean_absolute_error: 0.1769 - val_mean_squared_error: 0.0362 - val_mse_x: 0.0318 - val_mse_y: 0.0324 - val_mse_z: 0.0445 - val_root_mean_squared_error: 0.1904
# Epoch 8/50
# 845/845 ━━━━━━━━━━━━━━━━━━━━ 34s 40ms/step - loss: 3.8251e-04 - mean_absolute_error: 0.0137 - mean_squared_error: 3.8251e-04 - mse_x: 4.7743e-05 - mse_y: 5.2085e-04 - mse_z: 5.7892e-04 - root_mean_squared_error: 0.0196 - val_loss: 0.0278 - val_mean_absolute_error: 0.1525 - val_mean_squared_error: 0.0278 - val_mse_x: 0.0358 - val_mse_y: 0.0155 - val_mse_z: 0.0319 - val_root_mean_squared_error: 0.1666
# Epoch 9/50
# 845/845 ━━━━━━━━━━━━━━━━━━━━ 33s 40ms/step - loss: 3.7992e-04 - mean_absolute_error: 0.0135 - mean_squared_error: 3.7992e-04 - mse_x: 4.0745e-05 - mse_y: 5.2121e-04 - mse_z: 5.7780e-04 - root_mean_squared_error: 0.0195 - val_loss: 0.0234 - val_mean_absolute_error: 0.1396 - val_mean_squared_error: 0.0234 - val_mse_x: 0.0349 - val_mse_y: 0.0124 - val_mse_z: 0.0226 - val_root_mean_squared_error: 0.1528
# Epoch 10/50
# 845/845 ━━━━━━━━━━━━━━━━━━━━ 33s 40ms/step - loss: 3.7477e-04 - mean_absolute_error: 0.0134 - mean_squared_error: 3.7477e-04 - mse_x: 3.7486e-05 - mse_y: 5.1531e-04 - mse_z: 5.7151e-04 - root_mean_squared_error: 0.0194 - val_loss: 0.0243 - val_mean_absolute_error: 0.1445 - val_mean_squared_error: 0.0243 - val_mse_x: 0.0332 - val_mse_y: 0.0151 - val_mse_z: 0.0246 - val_root_mean_squared_error: 0.1559
# Epoch 11/50
# 845/845 ━━━━━━━━━━━━━━━━━━━━ 33s 39ms/step - loss: 3.7327e-04 - mean_absolute_error: 0.0133 - mean_squared_error: 3.7327e-04 - mse_x: 3.8530e-05 - mse_y: 5.1624e-04 - mse_z: 5.6505e-04 - root_mean_squared_error: 0.0193 - val_loss: 0.0203 - val_mean_absolute_error: 0.1267 - val_mean_squared_error: 0.0203 - val_mse_x: 0.0339 - val_mse_y: 0.0075 - val_mse_z: 0.0194 - val_root_mean_squared_error: 0.1425
# Epoch 12/50
# 845/845 ━━━━━━━━━━━━━━━━━━━━ 35s 42ms/step - loss: 3.6401e-04 - mean_absolute_error: 0.0131 - mean_squared_error: 3.6401e-04 - mse_x: 2.7639e-05 - mse_y: 5.0617e-04 - mse_z: 5.5823e-04 - root_mean_squared_error: 0.0191 - val_loss: 0.0194 - val_mean_absolute_error: 0.1260 - val_mean_squared_error: 0.0194 - val_mse_x: 0.0339 - val_mse_y: 0.0093 - val_mse_z: 0.0151 - val_root_mean_squared_error: 0.1394
# Epoch 13/50
# 845/845 ━━━━━━━━━━━━━━━━━━━━ 34s 40ms/step - loss: 3.6517e-04 - mean_absolute_error: 0.0130 - mean_squared_error: 3.6517e-04 - mse_x: 2.8316e-05 - mse_y: 5.1266e-04 - mse_z: 5.5454e-04 - root_mean_squared_error: 0.0191 - val_loss: 0.0185 - val_mean_absolute_error: 0.1227 - val_mean_squared_error: 0.0185 - val_mse_x: 0.0342 - val_mse_y: 0.0109 - val_mse_z: 0.0105 - val_root_mean_squared_error: 0.1361
# Epoch 14/50
# 845/845 ━━━━━━━━━━━━━━━━━━━━ 34s 40ms/step - loss: 3.6481e-04 - mean_absolute_error: 0.0131 - mean_squared_error: 3.6481e-04 - mse_x: 2.9139e-05 - mse_y: 5.1588e-04 - mse_z: 5.4942e-04 - root_mean_squared_error: 0.0191 - val_loss: 0.0212 - val_mean_absolute_error: 0.1247 - val_mean_squared_error: 0.0212 - val_mse_x: 0.0438 - val_mse_y: 0.0091 - val_mse_z: 0.0108 - val_root_mean_squared_error: 0.1458
# Epoch 15/50
# 845/845 ━━━━━━━━━━━━━━━━━━━━ 34s 40ms/step - loss: 3.6254e-04 - mean_absolute_error: 0.0130 - mean_squared_error: 3.6254e-04 - mse_x: 3.1086e-05 - mse_y: 5.1168e-04 - mse_z: 5.4486e-04 - root_mean_squared_error: 0.0190 - val_loss: 0.0178 - val_mean_absolute_error: 0.1205 - val_mean_squared_error: 0.0178 - val_mse_x: 0.0306 - val_mse_y: 0.0150 - val_mse_z: 0.0076 - val_root_mean_squared_error: 0.1333
# Epoch 16/50
# 845/845 ━━━━━━━━━━━━━━━━━━━━ 34s 41ms/step - loss: 3.5154e-04 - mean_absolute_error: 0.0127 - mean_squared_error: 3.5154e-04 - mse_x: 2.6044e-05 - mse_y: 5.0422e-04 - mse_z: 5.2435e-04 - root_mean_squared_error: 0.0187 - val_loss: 0.0181 - val_mean_absolute_error: 0.1169 - val_mean_squared_error: 0.0181 - val_mse_x: 0.0360 - val_mse_y: 0.0092 - val_mse_z: 0.0091 - val_root_mean_squared_error: 0.1346
# Epoch 17/50
# 845/845 ━━━━━━━━━━━━━━━━━━━━ 34s 40ms/step - loss: 3.5228e-04 - mean_absolute_error: 0.0127 - mean_squared_error: 3.5228e-04 - mse_x: 2.7177e-05 - mse_y: 5.0858e-04 - mse_z: 5.2108e-04 - root_mean_squared_error: 0.0188 - val_loss: 0.0166 - val_mean_absolute_error: 0.1178 - val_mean_squared_error: 0.0166 - val_mse_x: 0.0282 - val_mse_y: 0.0123 - val_mse_z: 0.0094 - val_root_mean_squared_error: 0.1289
# Epoch 18/50
# 845/845 ━━━━━━━━━━━━━━━━━━━━ 34s 40ms/step - loss: 3.5057e-04 - mean_absolute_error: 0.0127 - mean_squared_error: 3.5057e-04 - mse_x: 2.5554e-05 - mse_y: 5.0889e-04 - mse_z: 5.1727e-04 - root_mean_squared_error: 0.0187 - val_loss: 0.0177 - val_mean_absolute_error: 0.1129 - val_mean_squared_error: 0.0177 - val_mse_x: 0.0350 - val_mse_y: 0.0101 - val_mse_z: 0.0080 - val_root_mean_squared_error: 0.1331
# Epoch 19/50
# 845/845 ━━━━━━━━━━━━━━━━━━━━ 34s 40ms/step - loss: 3.4556e-04 - mean_absolute_error: 0.0125 - mean_squared_error: 3.4556e-04 - mse_x: 2.1381e-05 - mse_y: 5.0627e-04 - mse_z: 5.0904e-04 - root_mean_squared_error: 0.0186 - val_loss: 0.0156 - val_mean_absolute_error: 0.1119 - val_mean_squared_error: 0.0156 - val_mse_x: 0.0236 - val_mse_y: 0.0197 - val_mse_z: 0.0036 - val_root_mean_squared_error: 0.1250
# Epoch 20/50
# 845/845 ━━━━━━━━━━━━━━━━━━━━ 33s 40ms/step - loss: 3.3751e-04 - mean_absolute_error: 0.0124 - mean_squared_error: 3.3751e-04 - mse_x: 2.4509e-05 - mse_y: 5.0321e-04 - mse_z: 4.8481e-04 - root_mean_squared_error: 0.0184 - val_loss: 0.0171 - val_mean_absolute_error: 0.1082 - val_mean_squared_error: 0.0171 - val_mse_x: 0.0326 - val_mse_y: 0.0172 - val_mse_z: 0.0015 - val_root_mean_squared_error: 0.1309
# Epoch 21/50
# 845/845 ━━━━━━━━━━━━━━━━━━━━ 34s 41ms/step - loss: 3.3241e-04 - mean_absolute_error: 0.0123 - mean_squared_error: 3.3241e-04 - mse_x: 2.3440e-05 - mse_y: 5.0555e-04 - mse_z: 4.6824e-04 - root_mean_squared_error: 0.0182 - val_loss: 0.0150 - val_mean_absolute_error: 0.0992 - val_mean_squared_error: 0.0150 - val_mse_x: 0.0306 - val_mse_y: 0.0132 - val_mse_z: 0.0013 - val_root_mean_squared_error: 0.1226
# Epoch 22/50
# 845/845 ━━━━━━━━━━━━━━━━━━━━ 34s 40ms/step - loss: 3.2922e-04 - mean_absolute_error: 0.0122 - mean_squared_error: 3.2922e-04 - mse_x: 2.1819e-05 - mse_y: 5.0093e-04 - mse_z: 4.6492e-04 - root_mean_squared_error: 0.0181 - val_loss: 0.0167 - val_mean_absolute_error: 0.1110 - val_mean_squared_error: 0.0167 - val_mse_x: 0.0279 - val_mse_y: 0.0198 - val_mse_z: 0.0023 - val_root_mean_squared_error: 0.1292
# Epoch 23/50
# 845/845 ━━━━━━━━━━━━━━━━━━━━ 34s 40ms/step - loss: 3.2931e-04 - mean_absolute_error: 0.0122 - mean_squared_error: 3.2931e-04 - mse_x: 2.2253e-05 - mse_y: 5.0342e-04 - mse_z: 4.6226e-04 - root_mean_squared_error: 0.0181 - val_loss: 0.0186 - val_mean_absolute_error: 0.1144 - val_mean_squared_error: 0.0186 - val_mse_x: 0.0227 - val_mse_y: 0.0321 - val_mse_z: 8.7052e-04 - val_root_mean_squared_error: 0.1362
# Epoch 24/50
# 845/845 ━━━━━━━━━━━━━━━━━━━━ 34s 40ms/step - loss: 3.2717e-04 - mean_absolute_error: 0.0122 - mean_squared_error: 3.2717e-04 - mse_x: 2.2224e-05 - mse_y: 5.0208e-04 - mse_z: 4.5721e-04 - root_mean_squared_error: 0.0181 - val_loss: 0.0233 - val_mean_absolute_error: 0.1293 - val_mean_squared_error: 0.0233 - val_mse_x: 0.0233 - val_mse_y: 0.0446 - val_mse_z: 0.0020 - val_root_mean_squared_error: 0.1527
# Epoch 25/50
# 845/845 ━━━━━━━━━━━━━━━━━━━━ 34s 40ms/step - loss: 3.2500e-04 - mean_absolute_error: 0.0121 - mean_squared_error: 3.2500e-04 - mse_x: 2.0709e-05 - mse_y: 4.9898e-04 - mse_z: 4.5532e-04 - root_mean_squared_error: 0.0180 - val_loss: 0.0208 - val_mean_absolute_error: 0.1248 - val_mean_squared_error: 0.0208 - val_mse_x: 0.0300 - val_mse_y: 0.0301 - val_mse_z: 0.0023 - val_root_mean_squared_error: 0.1441
# Epoch 26/50
# 845/845 ━━━━━━━━━━━━━━━━━━━━ 34s 41ms/step - loss: 3.2429e-04 - mean_absolute_error: 0.0120 - mean_squared_error: 3.2429e-04 - mse_x: 1.9664e-05 - mse_y: 5.0291e-04 - mse_z: 4.5029e-04 - root_mean_squared_error: 0.0180 - val_loss: 0.0313 - val_mean_absolute_error: 0.1463 - val_mean_squared_error: 0.0313 - val_mse_x: 0.0273 - val_mse_y: 0.0649 - val_mse_z: 0.0016 - val_root_mean_squared_error: 0.1768
# Epoch 27/50
# 845/845 ━━━━━━━━━━━━━━━━━━━━ 34s 40ms/step - loss: 3.2132e-04 - mean_absolute_error: 0.0120 - mean_squared_error: 3.2132e-04 - mse_x: 1.9013e-05 - mse_y: 4.9909e-04 - mse_z: 4.4586e-04 - root_mean_squared_error: 0.0179 - val_loss: 0.0493 - val_mean_absolute_error: 0.1794 - val_mean_squared_error: 0.0493 - val_mse_x: 0.0308 - val_mse_y: 0.1138 - val_mse_z: 0.0031 - val_root_mean_squared_error: 0.2219
# Epoch 28/50
# 845/845 ━━━━━━━━━━━━━━━━━━━━ 34s 40ms/step - loss: 3.2057e-04 - mean_absolute_error: 0.0120 - mean_squared_error: 3.2057e-04 - mse_x: 2.0611e-05 - mse_y: 4.9850e-04 - mse_z: 4.4261e-04 - root_mean_squared_error: 0.0179 - val_loss: 0.0364 - val_mean_absolute_error: 0.1647 - val_mean_squared_error: 0.0364 - val_mse_x: 0.0285 - val_mse_y: 0.0726 - val_mse_z: 0.0081 - val_root_mean_squared_error: 0.1907
# Epoch 29/50
# 845/845 ━━━━━━━━━━━━━━━━━━━━ 34s 40ms/step - loss: 3.2027e-04 - mean_absolute_error: 0.0119 - mean_squared_error: 3.2027e-04 - mse_x: 1.9230e-05 - mse_y: 5.0223e-04 - mse_z: 4.3935e-04 - root_mean_squared_error: 0.0179 - val_loss: 0.0587 - val_mean_absolute_error: 0.2008 - val_mean_squared_error: 0.0587 - val_mse_x: 0.0267 - val_mse_y: 0.1342 - val_mse_z: 0.0150 - val_root_mean_squared_error: 0.2422
# Epoch 30/50
# 845/845 ━━━━━━━━━━━━━━━━━━━━ 34s 40ms/step - loss: 3.1878e-04 - mean_absolute_error: 0.0119 - mean_squared_error: 3.1878e-04 - mse_x: 1.9312e-05 - mse_y: 4.9823e-04 - mse_z: 4.3879e-04 - root_mean_squared_error: 0.0179 - val_loss: 0.0484 - val_mean_absolute_error: 0.1746 - val_mean_squared_error: 0.0484 - val_mse_x: 0.0267 - val_mse_y: 0.1165 - val_mse_z: 0.0021 - val_root_mean_squared_error: 0.2201
# Epoch 31/50
# 845/845 ━━━━━━━━━━━━━━━━━━━━ 34s 40ms/step - loss: 3.1808e-04 - mean_absolute_error: 0.0119 - mean_squared_error: 3.1808e-04 - mse_x: 1.8225e-05 - mse_y: 5.0008e-04 - mse_z: 4.3595e-04 - root_mean_squared_error: 0.0178 - val_loss: 0.0453 - val_mean_absolute_error: 0.1756 - val_mean_squared_error: 0.0453 - val_mse_x: 0.0294 - val_mse_y: 0.1006 - val_mse_z: 0.0058 - val_root_mean_squared_error: 0.2128
# Epoch 31: early stopping
# Modelo do split 2 salvo em models_GY87/lstm_split_2.keras
# Split 3:
# X_train shape: (770382, 64, 3), y_train shape: (770382, 3)
# X_test shape: (256751, 64, 3), y_test shape: (256751, 3)
# Treinando o modelo para o split 3...
# Epoch 1/50
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 115s 39ms/step - loss: 0.0053 - mean_absolute_error: 0.0259 - mean_squared_error: 0.0053 - mse_x: 0.0068 - mse_y: 0.0046 - mse_z: 0.0046 - root_mean_squared_error: 0.0576 - val_loss: 0.0018 - val_mean_absolute_error: 0.0343 - val_mean_squared_error: 0.0018 - val_mse_x: 0.0041 - val_mse_y: 7.4230e-04 - val_mse_z: 5.6505e-04 - val_root_mean_squared_error: 0.0426
# Epoch 2/50
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 48s 38ms/step - loss: 4.7167e-04 - mean_absolute_error: 0.0153 - mean_squared_error: 4.7167e-04 - mse_x: 6.7411e-05 - mse_y: 5.7519e-04 - mse_z: 7.7242e-04 - root_mean_squared_error: 0.0217 - val_loss: 0.0028 - val_mean_absolute_error: 0.0413 - val_mean_squared_error: 0.0028 - val_mse_x: 0.0069 - val_mse_y: 7.4441e-04 - val_mse_z: 7.3663e-04 - val_root_mean_squared_error: 0.0529
# Epoch 3/50
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 48s 38ms/step - loss: 4.0309e-04 - mean_absolute_error: 0.0140 - mean_squared_error: 4.0309e-04 - mse_x: 6.4546e-05 - mse_y: 5.6507e-04 - mse_z: 5.7965e-04 - root_mean_squared_error: 0.0201 - val_loss: 0.0030 - val_mean_absolute_error: 0.0435 - val_mean_squared_error: 0.0030 - val_mse_x: 0.0073 - val_mse_y: 7.5650e-04 - val_mse_z: 9.3852e-04 - val_root_mean_squared_error: 0.0548
# Epoch 4/50
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 48s 38ms/step - loss: 3.9059e-04 - mean_absolute_error: 0.0138 - mean_squared_error: 3.9059e-04 - mse_x: 5.4788e-05 - mse_y: 5.5515e-04 - mse_z: 5.6184e-04 - root_mean_squared_error: 0.0198 - val_loss: 0.0039 - val_mean_absolute_error: 0.0514 - val_mean_squared_error: 0.0039 - val_mse_x: 0.0081 - val_mse_y: 0.0027 - val_mse_z: 7.8019e-04 - val_root_mean_squared_error: 0.0621
# Epoch 5/50
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 48s 38ms/step - loss: 3.8209e-04 - mean_absolute_error: 0.0137 - mean_squared_error: 3.8209e-04 - mse_x: 5.3298e-05 - mse_y: 5.4253e-04 - mse_z: 5.5043e-04 - root_mean_squared_error: 0.0195 - val_loss: 0.0053 - val_mean_absolute_error: 0.0571 - val_mean_squared_error: 0.0053 - val_mse_x: 0.0129 - val_mse_y: 0.0024 - val_mse_z: 5.6495e-04 - val_root_mean_squared_error: 0.0728
# Epoch 6/50
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 50s 39ms/step - loss: 3.7901e-04 - mean_absolute_error: 0.0136 - mean_squared_error: 3.7901e-04 - mse_x: 4.6223e-05 - mse_y: 5.4130e-04 - mse_z: 5.4951e-04 - root_mean_squared_error: 0.0195 - val_loss: 0.0053 - val_mean_absolute_error: 0.0550 - val_mean_squared_error: 0.0053 - val_mse_x: 0.0140 - val_mse_y: 8.1265e-04 - val_mse_z: 0.0011 - val_root_mean_squared_error: 0.0728
# Epoch 7/50
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 49s 39ms/step - loss: 4.6257e-04 - mean_absolute_error: 0.0139 - mean_squared_error: 4.6257e-04 - mse_x: 2.0445e-04 - mse_y: 6.0753e-04 - mse_z: 5.7574e-04 - root_mean_squared_error: 0.0214 - val_loss: 0.0020 - val_mean_absolute_error: 0.0366 - val_mean_squared_error: 0.0020 - val_mse_x: 0.0045 - val_mse_y: 0.0010 - val_mse_z: 5.2158e-04 - val_root_mean_squared_error: 0.0450
# Epoch 8/50
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 48s 38ms/step - loss: 3.6731e-04 - mean_absolute_error: 0.0131 - mean_squared_error: 3.6731e-04 - mse_x: 3.1018e-05 - mse_y: 5.3336e-04 - mse_z: 5.3756e-04 - root_mean_squared_error: 0.0192 - val_loss: 0.0025 - val_mean_absolute_error: 0.0414 - val_mean_squared_error: 0.0025 - val_mse_x: 0.0052 - val_mse_y: 0.0017 - val_mse_z: 7.2708e-04 - val_root_mean_squared_error: 0.0504
# Epoch 9/50
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 49s 39ms/step - loss: 3.6842e-04 - mean_absolute_error: 0.0133 - mean_squared_error: 3.6842e-04 - mse_x: 3.6849e-05 - mse_y: 5.2947e-04 - mse_z: 5.3894e-04 - root_mean_squared_error: 0.0192 - val_loss: 0.0030 - val_mean_absolute_error: 0.0446 - val_mean_squared_error: 0.0030 - val_mse_x: 0.0066 - val_mse_y: 0.0013 - val_mse_z: 0.0011 - val_root_mean_squared_error: 0.0550
# Epoch 10/50
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 48s 38ms/step - loss: 3.6520e-04 - mean_absolute_error: 0.0132 - mean_squared_error: 3.6520e-04 - mse_x: 3.3296e-05 - mse_y: 5.2784e-04 - mse_z: 5.3447e-04 - root_mean_squared_error: 0.0191 - val_loss: 0.0030 - val_mean_absolute_error: 0.0448 - val_mean_squared_error: 0.0030 - val_mse_x: 0.0067 - val_mse_y: 0.0012 - val_mse_z: 0.0012 - val_root_mean_squared_error: 0.0549
# Epoch 11/50
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 49s 38ms/step - loss: 3.6125e-04 - mean_absolute_error: 0.0131 - mean_squared_error: 3.6125e-04 - mse_x: 3.1250e-05 - mse_y: 5.2189e-04 - mse_z: 5.3062e-04 - root_mean_squared_error: 0.0190 - val_loss: 0.0038 - val_mean_absolute_error: 0.0511 - val_mean_squared_error: 0.0038 - val_mse_x: 0.0080 - val_mse_y: 0.0020 - val_mse_z: 0.0015 - val_root_mean_squared_error: 0.0618
# Epoch 11: early stopping
# Modelo do split 3 salvo em models_GY87/lstm_split_3.keras
# Split 4:
# X_train shape: (1027197, 64, 3), y_train shape: (1027197, 3)
# X_test shape: (256751, 64, 3), y_test shape: (256751, 3)
# Treinando o modelo para o split 4...
# Epoch 1/50
# 1690/1690 ━━━━━━━━━━━━━━━━━━━━ 68s 39ms/step - loss: 0.0048 - mean_absolute_error: 0.0238 - mean_squared_error: 0.0048 - mse_x: 0.0066 - mse_y: 0.0040 - mse_z: 0.0039 - root_mean_squared_error: 0.0540 - val_loss: 0.0012 - val_mean_absolute_error: 0.0253 - val_mean_squared_error: 0.0012 - val_mse_x: 1.0457e-04 - val_mse_y: 0.0022 - val_mse_z: 0.0012 - val_root_mean_squared_error: 0.0342
# Epoch 2/50
# 1690/1690 ━━━━━━━━━━━━━━━━━━━━ 63s 37ms/step - loss: 4.0819e-04 - mean_absolute_error: 0.0145 - mean_squared_error: 4.0819e-04 - mse_x: 8.1676e-05 - mse_y: 5.5541e-04 - mse_z: 5.8748e-04 - root_mean_squared_error: 0.0202 - val_loss: 7.2179e-04 - val_mean_absolute_error: 0.0199 - val_mean_squared_error: 7.2179e-04 - val_mse_x: 1.0906e-04 - val_mse_y: 0.0016 - val_mse_z: 4.3820e-04 - val_root_mean_squared_error: 0.0269
# Epoch 3/50
# 1690/1690 ━━━━━━━━━━━━━━━━━━━━ 63s 37ms/step - loss: 3.7194e-04 - mean_absolute_error: 0.0137 - mean_squared_error: 3.7194e-04 - mse_x: 7.2358e-05 - mse_y: 5.4011e-04 - mse_z: 5.0336e-04 - root_mean_squared_error: 0.0193 - val_loss: 8.9326e-04 - val_mean_absolute_error: 0.0245 - val_mean_squared_error: 8.9326e-04 - val_mse_x: 3.0089e-04 - val_mse_y: 0.0015 - val_mse_z: 9.0810e-04 - val_root_mean_squared_error: 0.0299
# Epoch 4/50
# 1690/1690 ━━━━━━━━━━━━━━━━━━━━ 63s 37ms/step - loss: 3.5954e-04 - mean_absolute_error: 0.0136 - mean_squared_error: 3.5954e-04 - mse_x: 6.8558e-05 - mse_y: 5.2560e-04 - mse_z: 4.8446e-04 - root_mean_squared_error: 0.0190 - val_loss: 5.7079e-04 - val_mean_absolute_error: 0.0189 - val_mean_squared_error: 5.7079e-04 - val_mse_x: 1.9182e-04 - val_mse_y: 0.0012 - val_mse_z: 3.7014e-04 - val_root_mean_squared_error: 0.0239
# Epoch 5/50
# 1690/1690 ━━━━━━━━━━━━━━━━━━━━ 63s 37ms/step - loss: 0.0013 - mean_absolute_error: 0.0143 - mean_squared_error: 0.0013 - mse_x: 0.0024 - mse_y: 7.9627e-04 - mse_z: 5.2333e-04 - root_mean_squared_error: 0.0326 - val_loss: 6.7130e-04 - val_mean_absolute_error: 0.0205 - val_mean_squared_error: 6.7130e-04 - val_mse_x: 2.4309e-04 - val_mse_y: 7.0887e-04 - val_mse_z: 0.0011 - val_root_mean_squared_error: 0.0259
# Epoch 6/50
# 1690/1690 ━━━━━━━━━━━━━━━━━━━━ 63s 37ms/step - loss: 3.4207e-04 - mean_absolute_error: 0.0126 - mean_squared_error: 3.4207e-04 - mse_x: 2.1148e-05 - mse_y: 5.1813e-04 - mse_z: 4.8694e-04 - root_mean_squared_error: 0.0185 - val_loss: 7.4602e-04 - val_mean_absolute_error: 0.0213 - val_mean_squared_error: 7.4602e-04 - val_mse_x: 1.5176e-04 - val_mse_y: 7.4367e-04 - val_mse_z: 0.0013 - val_root_mean_squared_error: 0.0273
# Epoch 7/50
# 1690/1690 ━━━━━━━━━━━━━━━━━━━━ 62s 37ms/step - loss: 3.4994e-04 - mean_absolute_error: 0.0130 - mean_squared_error: 3.4994e-04 - mse_x: 3.6716e-05 - mse_y: 5.2353e-04 - mse_z: 4.8957e-04 - root_mean_squared_error: 0.0187 - val_loss: 8.2466e-04 - val_mean_absolute_error: 0.0230 - val_mean_squared_error: 8.2466e-04 - val_mse_x: 2.1334e-04 - val_mse_y: 8.4003e-04 - val_mse_z: 0.0014 - val_root_mean_squared_error: 0.0287
# Epoch 8/50
# 1690/1690 ━━━━━━━━━━━━━━━━━━━━ 63s 37ms/step - loss: 3.5593e-04 - mean_absolute_error: 0.0133 - mean_squared_error: 3.5593e-04 - mse_x: 5.6192e-05 - mse_y: 5.2475e-04 - mse_z: 4.8685e-04 - root_mean_squared_error: 0.0189 - val_loss: 7.4559e-04 - val_mean_absolute_error: 0.0216 - val_mean_squared_error: 7.4559e-04 - val_mse_x: 1.4780e-04 - val_mse_y: 9.6996e-04 - val_mse_z: 0.0011 - val_root_mean_squared_error: 0.0273
# Epoch 9/50
# 1690/1690 ━━━━━━━━━━━━━━━━━━━━ 64s 38ms/step - loss: 3.4797e-04 - mean_absolute_error: 0.0130 - mean_squared_error: 3.4797e-04 - mse_x: 4.8012e-05 - mse_y: 5.1408e-04 - mse_z: 4.8182e-04 - root_mean_squared_error: 0.0187 - val_loss: 6.0952e-04 - val_mean_absolute_error: 0.0181 - val_mean_squared_error: 6.0952e-04 - val_mse_x: 4.6023e-05 - val_mse_y: 0.0011 - val_mse_z: 6.6494e-04 - val_root_mean_squared_error: 0.0247
# Epoch 10/50
# 1690/1690 ━━━━━━━━━━━━━━━━━━━━ 64s 38ms/step - loss: 3.4833e-04 - mean_absolute_error: 0.0132 - mean_squared_error: 3.4833e-04 - mse_x: 5.6821e-05 - mse_y: 5.1300e-04 - mse_z: 4.7518e-04 - root_mean_squared_error: 0.0187 - val_loss: 6.9898e-04 - val_mean_absolute_error: 0.0192 - val_mean_squared_error: 6.9898e-04 - val_mse_x: 1.8213e-05 - val_mse_y: 0.0011 - val_mse_z: 9.7456e-04 - val_root_mean_squared_error: 0.0264
# Epoch 11/50
# 1690/1690 ━━━━━━━━━━━━━━━━━━━━ 63s 37ms/step - loss: 3.4175e-04 - mean_absolute_error: 0.0131 - mean_squared_error: 3.4175e-04 - mse_x: 4.9410e-05 - mse_y: 5.0629e-04 - mse_z: 4.6954e-04 - root_mean_squared_error: 0.0185 - val_loss: 7.0866e-04 - val_mean_absolute_error: 0.0194 - val_mean_squared_error: 7.0866e-04 - val_mse_x: 1.8868e-05 - val_mse_y: 0.0011 - val_mse_z: 0.0010 - val_root_mean_squared_error: 0.0266
# Epoch 12/50
# 1690/1690 ━━━━━━━━━━━━━━━━━━━━ 63s 38ms/step - loss: 3.3782e-04 - mean_absolute_error: 0.0130 - mean_squared_error: 3.3782e-04 - mse_x: 4.4410e-05 - mse_y: 5.0195e-04 - mse_z: 4.6711e-04 - root_mean_squared_error: 0.0184 - val_loss: 7.3082e-04 - val_mean_absolute_error: 0.0209 - val_mean_squared_error: 7.3082e-04 - val_mse_x: 5.9700e-05 - val_mse_y: 0.0010 - val_mse_z: 0.0011 - val_root_mean_squared_error: 0.0270
# Epoch 13/50
# 1690/1690 ━━━━━━━━━━━━━━━━━━━━ 64s 38ms/step - loss: 3.3175e-04 - mean_absolute_error: 0.0127 - mean_squared_error: 3.3175e-04 - mse_x: 3.5643e-05 - mse_y: 4.9895e-04 - mse_z: 4.6066e-04 - root_mean_squared_error: 0.0182 - val_loss: 7.7893e-04 - val_mean_absolute_error: 0.0232 - val_mean_squared_error: 7.7893e-04 - val_mse_x: 2.8412e-04 - val_mse_y: 0.0011 - val_mse_z: 9.8621e-04 - val_root_mean_squared_error: 0.0279
# Epoch 14/50
# 1690/1690 ━━━━━━━━━━━━━━━━━━━━ 63s 37ms/step - loss: 3.2766e-04 - mean_absolute_error: 0.0126 - mean_squared_error: 3.2766e-04 - mse_x: 3.0477e-05 - mse_y: 4.9607e-04 - mse_z: 4.5643e-04 - root_mean_squared_error: 0.0181 - val_loss: 6.6730e-04 - val_mean_absolute_error: 0.0215 - val_mean_squared_error: 6.6730e-04 - val_mse_x: 4.0487e-04 - val_mse_y: 9.0321e-04 - val_mse_z: 6.9393e-04 - val_root_mean_squared_error: 0.0258
# Epoch 14: early stopping
# Modelo do split 4 salvo em models_GY87/lstm_split_4.keras

# %% [markdown]
# ### Salvar o Histórico do Treinamento (history.json)

# %%
import json

# Criar uma pasta para salvar os modelos
model_folder = "models_GY87"
config_path = os.path.join(model_folder, "history.json")
# Salvar o histórico do treinamento em um arquivo JSON
with open(config_path, "w") as f:
    json.dump(history.history, f)

# %% [markdown]
# ### Carregar o Histórico (history.json)

# %%
import json

model_folder = "models_GY87"
config_path = os.path.join(model_folder, "history.json")
# Carregar o histórico salvo
with open(config_path, "r") as f:
    loaded_history = json.load(f)

# Exemplo de acesso aos dados carregados
print("Chaves do histórico:", loaded_history.keys())
print("Perda final:", loaded_history["loss"][-1])
print("Validação final:", loaded_history["val_loss"][-1])
# Out:
# Chaves do histórico: dict_keys(['loss', 'mean_absolute_error', 'mean_squared_error', 'mse_x', 'mse_y', 'mse_z', 'root_mean_squared_error', 'val_loss', 'val_mean_absolute_error', 'val_mean_squared_error', 'val_mse_x', 'val_mse_y', 'val_mse_z', 'val_root_mean_squared_error'])
# Perda final: 0.00032616170938126743
# Validação final: 0.0006672971067018807

# %% [markdown]
# ### Visualizar o Histórico de Treinamento

# %%
import matplotlib.pyplot as plt

# Plotando a perda de treino e validação
plt.figure(figsize=(10,1))
plt.plot(loaded_history["loss"], label="loss")
plt.plot(loaded_history["val_loss"], label="val_loss")
plt.xlabel("Épocas")
plt.ylabel("Perda (Loss)")
plt.title("Evolução da Perda durante o Treinamento")
plt.legend()
plt.show()

# %% [markdown]
# # Avaliar o Modelo ******************************
# #### Após o treinamento de cada split, é avaliado o desempenho do modelo no conjunto de teste.

# %%
import sys
import os
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import load_model
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import TimeSeriesSplit
from sklearn.preprocessing import MinMaxScaler
import pickle

# Função para criar sequências
def create_sequences(data, n_timesteps):
    X, y = [], []
    for i in range(len(data) - n_timesteps):
        X.append(data[i:(i + n_timesteps)])
        y.append(data[i + n_timesteps])
    return np.array(X), np.array(y)

# Classe Tee para duplicar a saída (console e arquivo)
class Tee:
    def __init__(self, *files):
        self.files = files
        self.encoding = getattr(files[0], 'encoding', 'utf-8')
    def write(self, obj):
        for f in self.files:
            f.write(obj)
    def flush(self):
        for f in self.files:
            f.flush()

# Carregar dados e scaler
# print("Carregando dados...")
# file_path = './Dados/dados.txt'
# df = pd.read_csv(file_path, header=None, names=['X', 'Y', 'Z'])
# df = df[1300:1001300]

# Carregar o scaler
# with open('scaler.pkl', 'rb') as f:
#     scaler = pickle.load(f)

# Diretório onde salvar os resultados
model_folder = "models_GY87"
os.makedirs(model_folder, exist_ok=True)

# Arquivo de log para salvar o output com a mesma estrutura
log_path = os.path.join(model_folder, "evaluation.log")

# Abrir o arquivo com encoding 'utf-8' para evitar erros de caracteres
with open(log_path, "w", encoding="utf-8") as log_file:
    # Redireciona a saída padrão para imprimir tanto no console quanto no arquivo
    original_stdout = sys.stdout
    sys.stdout = Tee(original_stdout, log_file)
    
    print("Iniciando avaliação dos modelos...")
    
    # Inicializar lista para métricas
    results = []
    
    # Avaliar os modelos salvos
    for split_idx, (train_index, test_index) in enumerate(tscv.split(df_scaled.values), start=1):
        print(f"\n=== Avaliando Split {split_idx} ===")
        
        # Carregar o modelo salvo
        model_path = os.path.join(model_folder, f"lstm_split_{split_idx}.keras")
        
        if not os.path.exists(model_path):
            print(f"Modelo {model_path} não encontrado. Pulando...")
            continue
            
        try:
            model = load_model(model_path, custom_objects={
                "weighted_mse_with_bias": weighted_mse_with_bias,
                "mse_x": mse_x,
                "mse_y": mse_y,
                "mse_z": mse_z
            })
            print(f"Modelo carregado: {model_path}")
        except Exception as e:
            print(f"Erro ao carregar modelo {model_path}: {e}")
            continue
        
        # Criar os dados de teste
        test_data = df_scaled.values[test_index]
        X_test, y_test = create_sequences(test_data, n_timesteps)
        
        print(f"Dados de teste - X_test shape: {X_test.shape}, y_test shape: {y_test.shape}")
        
        # Validar shapes dos dados
        assert X_test.shape[0] == y_test.shape[0], "Número de exemplos em X_test e y_test não coincidem!"
        assert X_test.shape[1] == n_timesteps, "Número de timesteps em X_test está incorreto!"
        assert X_test.shape[2] == n_features, "Número de features em X_test está incorreto!"
        
        # Temporariamente restaura a saída padrão para evitar que o progress bar seja capturado no log
        temp_stdout = sys.stdout
        sys.stdout = original_stdout
        
        print(f"Fazendo predições para o split {split_idx}...")
        # Fazer previsões (verbose=1 para exibir o progress bar no console)
        y_pred = model.predict(X_test, verbose=1)
        
        # Após a predição, volta a redirecionar a saída para o nosso Tee
        sys.stdout = temp_stdout
        
        print(f"Predições concluídas - shape: {y_pred.shape}")
        
        # Cálculo das métricas
        mse_total = mean_squared_error(y_test, y_pred)
        r2_total = r2_score(y_test, y_pred)
        mse_x_val = mean_squared_error(y_test[:, 0], y_pred[:, 0])
        r2_x = r2_score(y_test[:, 0], y_pred[:, 0])
        mse_y_val = mean_squared_error(y_test[:, 1], y_pred[:, 1])
        r2_y = r2_score(y_test[:, 1], y_pred[:, 1])
        mse_z_val = mean_squared_error(y_test[:, 2], y_pred[:, 2])
        r2_z = r2_score(y_test[:, 2], y_pred[:, 2])
        
        # Salvando métricas
        results.append({
            'split': split_idx,
            'mse_total': mse_total, 'r2_total': r2_total,
            'mse_x': mse_x_val, 'r2_x': r2_x,
            'mse_y': mse_y_val, 'r2_y': r2_y,
            'mse_z': mse_z_val, 'r2_z': r2_z
        })
        
        # Imprimir output no formato desejado (sem os updates do progress bar)
        print(f"Split {split_idx} - MSE Total: {mse_total:.6f}, R² Total: {r2_total:.6f}")
        print(f"Split {split_idx} - MSE X: {mse_x_val:.6f}, R² X: {r2_x:.6f}")
        print(f"Split {split_idx} - MSE Y: {mse_y_val:.6f}, R² Y: {r2_y:.6f}")
        print(f"Split {split_idx} - MSE Z: {mse_z_val:.6f}, R² Z: {r2_z:.6f}")
    
    # Consolidar os resultados em um DataFrame
    if results:
        df_results = pd.DataFrame(results)
        
        # Salvar os resultados em CSV
        csv_path = os.path.join(model_folder, "evaluation_results.csv")
        df_results.to_csv(csv_path, index=False)
        print(f"\nResultados salvos em {csv_path}")
        
        # Calcular e exibir estatísticas resumidas
        print("\n=== RESUMO DOS RESULTADOS ===")
        print("Médias das métricas:")
        for col in df_results.columns:
            if col != 'split':
                print(f"{col}: {df_results[col].mean():.6f} ± {df_results[col].std():.6f}")
    else:
        print("Nenhum modelo foi avaliado com sucesso.")
    
    # Restaurar a saída padrão
    sys.stdout = original_stdout

print("Avaliação concluída!")
# Out:
# Iniciando avaliação dos modelos...
#
# === Avaliando Split 1 ===
# Modelo carregado: models_GY87/lstm_split_1.keras
# Dados de teste - X_test shape: (256751, 64, 3), y_test shape: (256751, 3)
# Fazendo predições para o split 1...
# 8024/8024 ━━━━━━━━━━━━━━━━━━━━ 20s 2ms/step
# Predições concluídas - shape: (256751, 3)
# Split 1 - MSE Total: 0.027036, R² Total: -10.972791
# Split 1 - MSE X: 0.023204, R² X: -34.434428
# Split 1 - MSE Y: 0.027137, R² Y: 0.754913
# Split 1 - MSE Z: 0.030768, R² Z: 0.761143
#
# === Avaliando Split 2 ===
# Modelo carregado: models_GY87/lstm_split_2.keras
# Dados de teste - X_test shape: (256751, 64, 3), y_test shape: (256751, 3)
# Fazendo predições para o split 2...
# 8024/8024 ━━━━━━━━━━━━━━━━━━━━ 20s 2ms/step
# Predições concluídas - shape: (256751, 3)
# Split 2 - MSE Total: 0.045268, R² Total: 0.278930
# Split 2 - MSE X: 0.029413, R² X: 0.953576
# Split 2 - MSE Y: 0.100603, R² Y: -1.072835
# Split 2 - MSE Z: 0.005789, R² Z: 0.956048
#
# === Avaliando Split 3 ===
# Modelo carregado: models_GY87/lstm_split_3.keras
# Dados de teste - X_test shape: (256751, 64, 3), y_test shape: (256751, 3)
# Fazendo predições para o split 3...
# 8024/8024 ━━━━━━━━━━━━━━━━━━━━ 20s 2ms/step
# Predições concluídas - shape: (256751, 3)
# Split 3 - MSE Total: 0.003814, R² Total: 0.709984
# Split 3 - MSE X: 0.007989, R² X: 0.204149
# Split 3 - MSE Y: 0.001986, R² Y: 0.960743
# Split 3 - MSE Z: 0.001468, R² Z: 0.965060
#
# === Avaliando Split 4 ===
# Modelo carregado: models_GY87/lstm_split_4.keras
# Dados de teste - X_test shape: (256751, 64, 3), y_test shape: (256751, 3)
# Fazendo predições para o split 4...
# 8024/8024 ━━━━━━━━━━━━━━━━━━━━ 20s 2ms/step
# Predições concluídas - shape: (256751, 3)
# Split 4 - MSE Total: 0.000667, R² Total: 0.971830
# Split 4 - MSE X: 0.000405, R² X: 0.988440
# Split 4 - MSE Y: 0.000902, R² Y: 0.977906
# Split 4 - MSE Z: 0.000694, R² Z: 0.949144
#
# Resultados salvos em models_GY87/evaluation_results.csv
#
# === RESUMO DOS RESULTADOS ===
# Médias das métricas:
# mse_total: 0.019197 ± 0.020985
# r2_total: -2.253012 ± 5.820201
# mse_x: 0.015253 ± 0.013378
# r2_x: -8.072066 ± 17.578631
# mse_y: 0.032657 ± 0.046890
# r2_y: 0.405182 ± 0.990540
# mse_z: 0.009680 ± 0.014236
# r2_z: 0.907849 ± 0.098020
# Avaliação concluída!

# %% [markdown]
# # Carregando o modelo desejado pelo split

# %%
import os
import tensorflow as tf
from tensorflow.keras.models import load_model
from tensorflow.keras import backend as K

# Definindo o diretório onde o modelo está salvo
model_folder = "models_GY87"
model_path = os.path.join(model_folder, 'lstm_split_4.keras')

# Carregando o modelo com todas as funções customizadas
modelo_carregado = load_model(
    model_path, 
    custom_objects={
        "weighted_mse_with_bias": weighted_mse_with_bias,
        "mse_x": mse_x,
        "mse_y": mse_y,
        "mse_z": mse_z
    }
)

print(modelo_carregado.summary())
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 324)            │       425,088 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 608)            │       197,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 3)              │         1,827 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,873,548 (7.15 MB)
#  Trainable params: 624,515 (2.38 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 1,249,033 (4.76 MB)
# None

# %% [markdown]
# Fazendo previsões

# %%
predicted = modelo_carregado.predict(X_test)
# predicted = y_pred
# Out:
# 8024/8024 ━━━━━━━━━━━━━━━━━━━━ 20s 2ms/step

# %% [markdown]
# Plotando os Resultados

# %%
epochs = range(1, len(loaded_history['loss']) + 1)

plt.plot(epochs, loaded_history['loss'], label='Train Loss')
plt.plot(epochs, loaded_history['val_loss'], label='Validation Loss')
plt.plot(epochs, loaded_history['mean_squared_error'], label='MSE')
plt.plot(epochs, loaded_history['mean_absolute_error'], label='MAE')
plt.plot(epochs, loaded_history['root_mean_squared_error'], label='RMSE')
plt.title('Training and Validation Metrics')
plt.xlabel('Epochs')
plt.ylabel('Value')
plt.legend()
plt.show()

# %%
# Definindo as dimensões
dims = ['X', 'Y', 'Z']

plt.figure(figsize=(15, 15))

# Criando um gráfico para cada dimensão
for i, dim in enumerate(dims):
    plt.subplot(3, 1, i+1)
    plt.plot(X_test[:, -1, i], label='Real')
    plt.plot(predicted[:, i], label='Previsto')
    plt.title(f'Comparação {dim}')
    plt.xlabel('Tempo')
    plt.ylabel(f'Valor {dim}')
    plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Plotando desnormalizado

# %%
dims = ['X', 'Y', 'Z']

plt.figure(figsize=(15, 15))

for i, dim in enumerate(dims):
    plt.subplot(3, 1, i+1)

    # Desnormalizando os valores reais e previstos
    real_denorm = scalers_tuple[dim].inverse_transform(X_test[:, -1, i].reshape(-1, 1)).flatten()
    pred_denorm = scalers_tuple[dim].inverse_transform(predicted[:, i].reshape(-1, 1)).flatten()

    plt.plot(real_denorm, label='Real')
    plt.plot(pred_denorm, label='Previsto')
    plt.title(f'Comparação {dim}')
    plt.xlabel('Tempo')
    plt.ylabel(f'Valor {dim}')
    plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Plotando desnormalizado e com escala da amplitude 360

# %%
dims = ['X', 'Y', 'Z']

plt.figure(figsize=(15, 15))

for i, dim in enumerate(dims):
    plt.subplot(3, 1, i+1)

    # Desnormalizando os valores reais e previstos
    real_denorm = scalers_tuple[dim].inverse_transform(X_test[:, -1, i].reshape(-1, 1)).flatten()
    pred_denorm = scalers_tuple[dim].inverse_transform(predicted[:, i].reshape(-1, 1)).flatten()

    plt.plot(real_denorm, label='Real')
    plt.plot(pred_denorm, label='Previsto')
    plt.title(f'Comparação {dim}')
    plt.xlabel('Tempo')
    plt.ylabel(f'Valor {dim}')
    plt.legend()
    plt.ylim(-100, 100)

plt.tight_layout()
plt.show()

# %%
# Criando a figura
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

# Plotando os valores reais
ax.scatter(X_test[:, -1, 0], X_test[:, -1, 1], X_test[:, -1, 2], alpha=0.3, color='blue', label='Real')

# Plotando os valores previstos
ax.scatter(predicted[:, 0], predicted[:, 1], predicted[:, 2], alpha=0.7, color='red', label='Previsto')

ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
plt.title('Comparação 3D entre Valores Reais e Previstos')
plt.legend()
plt.show()

# %% [markdown]
# ## Mean Squared Error e $R^2$

# %%
mse = mean_squared_error(y_test, predicted)
r2 = r2_score(y_test, predicted)

MSE_R2 = {
    "MSE: ":mse,
    "R2: ": r2
}
# Salvar os hiperparâmetros em um arquivo JSON
model_folder = "models_GY87"
config_path = os.path.join(model_folder, "1.Mean Squared Error e R2.Teste.json")
with open(config_path, "w") as f:
    json.dump(MSE_R2, f, indent=4)

print(f"Hiperparâmetros salvos em {config_path}")

print("MSE:", mse)
print("R²:", r2)
# Out:
# Hiperparâmetros salvos em models_GY87/1.Mean Squared Error e R2.Teste.json
# MSE: 0.0006672854595171154
# R²: 0.9718299496171195

# %%
erro = np.abs(y_test - predicted)
plt.plot(erro)
plt.title("Erro absoluto ao longo do tempo")
plt.show()

# %%
plt.plot(y_test[:1000, 0], label='Real X')
plt.plot(predicted[:1000, 0], label='Previsto X')
plt.legend()
plt.title("Zoom eixo X")
plt.show()

# %%
residuos = y_test - predicted
plt.hist(residuos[:, 0], bins=100)
plt.title("Histograma dos resíduos - eixo X")
plt.show()

# %%
bias = np.mean(y_test - predicted)
predicted_corrigido = predicted + bias

# %% [markdown]
# # _________________________________________________________________________________________________
# # Teste em um NOVO conjunto de dados do mesmo sensor, o Sensor 1

# %% [markdown]
# Carregando Dados Sensor 1

# %%
# Carregar os dados do arquivo
file_path1 = './Dados/sensor_data GY-87_1.1.txt'
df1_1 = pd.read_csv(file_path1, header=None, names=['X', 'Y', 'Z'])
print(len(df1_1))
print(df1_1.head())
# Out:
# 375151
#           X          Y           Z
# 0 -8.789435  -8.031115 -131.726822
# 1 -2.515755   9.834208  -65.708527
# 2  0.286306  28.450745  113.858810
# 3 -8.749084  32.791618  172.558365
# 4 -7.755535  26.062883  176.409973

# %% [markdown]
# ### Retirando Outliers

# %%
df_cleaned1_1 = remove_outliers_rolling_mad(df1_1, ['X','Y','Z'], window=5000, k=5)
# Exibir as primeiras linhas do DataFrame limpo
print(df_cleaned1_1.head())
df1_1=df_cleaned1_1
# Out:
#              X         Y          Z
# 5000  1.051740 -1.874325 -12.327733
# 5001  1.063928 -1.864345 -12.292420
# 5002  1.122944 -1.909463 -12.261428
# 5003  1.090499 -1.852442 -12.184809
# 5004  1.059289 -1.850853 -12.112368

# %% [markdown]
# Normalizando os dados

# %%
df1_1_scaled = normalizar_eixos_independente(df1_1)[0]

print(df1_1_scaled.head())
# Out:
#           X         Y         Z
# 0 -0.975490  0.022906 -0.680443
# 1 -0.974153  0.030384 -0.679672
# 2 -0.967684 -0.003428 -0.678995
# 3 -0.971241  0.039305 -0.677323
# 4 -0.974662  0.040496 -0.675741

# %% [markdown]
# Preparando os dados de Teste do Sensor 1

# %%
# Supondo que test_data seja seu DataFrame de teste normalizado
# Convertendo para numpy array
values_test1 = df1_1_scaled.values

# Reformatando os dados para a entrada LSTM
X_test1_1, y_test1_1 = [], []
for i in range(len(values_test1) - n_timesteps):
    X_test1_1.append(values_test1[i:(i + n_timesteps), :])
    y_test1_1.append(values_test1[i + n_timesteps, :])
X_test1_1, y_test1_1 = np.array(X_test1_1), np.array(y_test1_1)

# Agora X_test e y_test estão prontos para serem usados para testar o modelo

# %% [markdown]
# Fazendo a predição

# %%
predicted1_1 = modelo_carregado.predict(X_test1_1)
# Out:
# 11291/11291 ━━━━━━━━━━━━━━━━━━━━ 28s 2ms/step

# %% [markdown]
# Plotando os resultados

# %%
# Definindo as dimensões
dims = ['X', 'Y', 'Z']

plt.figure(figsize=(15, 15))

# Criando um gráfico para cada dimensão
for i, dim in enumerate(dims):
    plt.subplot(3, 1, i+1)
    plt.plot(X_test1_1[:, -1, i], label='Real')
    plt.plot(predicted1_1[:, i], label='Previsto')
    plt.title(f'Comparação {dim}')
    plt.xlabel('Tempo')
    plt.ylabel(f'Valor {dim}')
    plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Plotando desnormalizado

# %%
dims = ['X', 'Y', 'Z']

plt.figure(figsize=(15, 15))

for i, dim in enumerate(dims):
    plt.subplot(3, 1, i+1)

    # Desnormalizando os valores reais e previstos
    real_denorm = scalers_tuple[dim].inverse_transform(X_test1_1[:, -1, i].reshape(-1, 1)).flatten()
    pred_denorm = scalers_tuple[dim].inverse_transform(predicted1_1[:, i].reshape(-1, 1)).flatten()

    plt.plot(real_denorm, label='Real')
    plt.plot(pred_denorm, label='Previsto')
    plt.title(f'Comparação {dim}')
    plt.xlabel('Tempo')
    plt.ylabel(f'Valor {dim}')
    plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Plotando desnormalizado e com escala da amplitude 360

# %%
dims = ['X', 'Y', 'Z']

plt.figure(figsize=(15, 15))

for i, dim in enumerate(dims):
    plt.subplot(3, 1, i+1)

    # Desnormalizando os valores reais e previstos
    real_denorm = scalers_tuple[dim].inverse_transform(X_test1_1[:, -1, i].reshape(-1, 1)).flatten()
    pred_denorm = scalers_tuple[dim].inverse_transform(predicted1_1[:, i].reshape(-1, 1)).flatten()

    plt.plot(real_denorm, label='Real')
    plt.plot(pred_denorm, label='Previsto')
    plt.title(f'Comparação {dim}')
    plt.xlabel('Tempo')
    plt.ylabel(f'Valor {dim}')
    plt.legend()
    plt.ylim(-180, 180)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Mean Squared Error e $R^2$ nos novos dados do Sensor 1 ******************

# %%
mse = mean_squared_error(y_test1_1, predicted1_1)
r2 = r2_score(y_test1_1, predicted1_1)

MSE_R2 = {
    "MSE: ":mse,
    "R2: ": r2
}
# Salvar os hiperparâmetros em um arquivo JSON
model_folder = "models_GY87"
config_path = os.path.join(model_folder, "2.Mean Squared Error e R2.NewData.json")
with open(config_path, "w") as f:
    json.dump(MSE_R2, f, indent=4)

print(f"Hiperparâmetros salvos em {config_path}")

print("MSE:", mse)
print("R²:", r2)
# Out:
# Hiperparâmetros salvos em models_GY87/2.Mean Squared Error e R2.NewData.json
# MSE: 0.020757975147623314
# R²: 0.9435412217532271

# %% [markdown]
# # Estabilizando o dados estaticos (POC)

# %%
# Suponha que df_novos_dados seja o DataFrame com os novos dados do sensor
# e que o modelo já tenha sido carregado e esteja pronto para uso
# Carregar os novos dados do sensor
file_path = './Dados/sensor_data GY-87_3.txt'  # Substitua pelo caminho correto do arquivo
# file_path = './Dados/sensor_data GY-87_1.1.txt'  # Substitua pelo caminho correto do arquivo

df_novos_dados = pd.read_csv(file_path, header=None, names=['X', 'Y', 'Z'])

df_novos_dados_cleaned = remove_outliers_rolling_mad(df_novos_dados, ['X', 'Y', 'Z'], window=5000, k=5)
# Normalizar os novos dados
df_novos_dados_scaled = pd.DataFrame(normalizar_eixos_independente(df_novos_dados_cleaned)[0], columns=df_novos_dados_cleaned.columns)

# Preparar os dados para o modelo
values_novos_dados = df_novos_dados_scaled.values
X_novos_dados = []
for i in range(len(values_novos_dados) - n_timesteps):
    X_novos_dados.append(values_novos_dados[i:(i + n_timesteps)])
X_novos_dados = np.array(X_novos_dados)

# Fazer previsões com o modelo para cada sequência
predicted_novos_dados = modelo_carregado.predict(X_novos_dados)
# Out:
# 3196/3196 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step

# %%
# Plotar comparações entre os dados originais e preditos para cada eixo
def plot_comparacao_original_predito(values_novos_dados, predicted_novos_dados, n_timesteps):
    valores_originais = values_novos_dados[n_timesteps:]  # alinhar com predição

    plt.figure(figsize=(15, 10))

    # Eixo X
    plt.subplot(3, 1, 1)
    plt.plot(valores_originais[:, 0], label='Original X', color='darkblue', alpha=0.7)
    plt.plot(predicted_novos_dados[:, 0], label='Predito X', color='darkorange', alpha=0.7, linestyle='--')
    plt.title('Comparação dos Dados - Eixo X')
    plt.ylabel('X')
    plt.legend()

    # Eixo Y
    plt.subplot(3, 1, 2)
    plt.plot(valores_originais[:, 1], label='Original Y', color='darkblue', alpha=0.7)
    plt.plot(predicted_novos_dados[:, 1], label='Predito Y', color='darkorange', alpha=0.7, linestyle='--')
    plt.title('Comparação dos Dados - Eixo Y')
    plt.ylabel('Y')
    plt.legend()

    # Eixo Z
    plt.subplot(3, 1, 3)
    plt.plot(valores_originais[:, 2], label='Original Z', color='darkblue', alpha=0.7)
    plt.plot(predicted_novos_dados[:, 2], label='Predito Z', color='darkorange', alpha=0.7, linestyle='--')
    plt.title('Comparação dos Dados - Eixo Z')
    plt.ylabel('Z')
    plt.legend()

    plt.tight_layout()
    plt.show()

plot_comparacao_original_predito(values_novos_dados, predicted_novos_dados, n_timesteps)

# %%
# SIMULAÇÃO EM TEMPO REAL (nosso código, agora usando os dados corretos) ---
fator_correcao = 0.4

print("Iniciando simulação de correção em tempo real com dados consistentes...")

dados_corrigidos_tempo_real = np.copy(values_novos_dados)

for i in range(len(predicted_novos_dados)):
    # indice_real_atual = i + n_timesteps
    # valor_real_atual = values_novos_dados[indice_real_atual]
    # predicao_do_ruido_atual = predicted_novos_dados[i]
    
    # valor_corrigido = valor_real_atual - predicao_do_ruido_atual * 1.0

    # dados_corrigidos_tempo_real[indice_real_atual] = valor_corrigido
    valor_corrigido = values_novos_dados[i] - predicted_novos_dados[i] * fator_correcao
    
    dados_corrigidos_tempo_real[i] = valor_corrigido

print("Simulação concluída. Gerando gráfico...")

# --- PLOTAGEM FINAL ---

df_original_full = pd.DataFrame(values_novos_dados, columns=['X', 'Y', 'Z'])
df_corrigido_simulado = pd.DataFrame(dados_corrigidos_tempo_real, columns=['X', 'Y', 'Z'])

plt.figure(figsize=(20, 12))
for i, eixo in enumerate(['X', 'Y', 'Z']):
    plt.subplot(3, 1, i + 1)
    plt.plot(df_original_full.index, df_original_full[eixo], label=f'Original {eixo}', alpha=0.7, color='darkblue')
    plt.plot(df_corrigido_simulado.index, df_corrigido_simulado[eixo], label=f'Corrigido {eixo}', linestyle='-', alpha=0.7, color='darkorange', linewidth=0.5)
    plt.title(f'Resultado da Simulação de Correção de Execução - Eixo {eixo}', fontsize=14)
    plt.ylabel(eixo)
    plt.ylim(-1, 1)
    plt.legend()
    plt.grid(True, linestyle='--', alpha=0.6)
    plt.xlim(0, len(df_original_full))
plt.suptitle('Análise de Correção Simulada em Tempo de Execução (com Scaler Consistente)', fontsize=18, y=0.95)
plt.tight_layout(rect=[0, 0.03, 1, 0.93])
plt.show()
# Out:
# Iniciando simulação de correção em tempo real com dados consistentes...
# Simulação concluída. Gerando gráfico...

# %%
print("Iniciando simulação (Cumulativa de Erro de Variação)")

fator_correcao = 0.1

# Alinhar os dados
min_len = min(len(predicted_novos_dados), len(values_novos_dados[n_timesteps:]))
original_base = values_novos_dados[n_timesteps:][:min_len]
predicted_base = predicted_novos_dados[:min_len]

# Inicializar o array de resultados
dados_corrigidos_logica2 = np.zeros_like(original_base)

# Ponto de partida: O primeiro valor corrigido é o primeiro valor original
dados_corrigidos_logica2[0] = original_base[0]

# Loop de simulação
for i in range(1, len(original_base)):
    # Variação (delta) do sinal original no último passo
    delta_original = original_base[i] - original_base[i-1]
    
    # Variação (delta) do sinal predito no último passo
    delta_predito = predicted_base[i] - predicted_base[i-1]
    
    # O erro na variação é a diferença entre os deltas
    erro_de_variacao = delta_original - delta_predito * fator_correcao
    
    # O novo valor corrigido é o anterior mais o erro de variação
    dados_corrigidos_logica2[i] = dados_corrigidos_logica2[i-1] + erro_de_variacao

# --- Preparar para plotagem ---
dados_finais_para_plotar = np.full_like(values_novos_dados, np.nan)
inicio_plot = n_timesteps
fim_plot = inicio_plot + len(dados_corrigidos_logica2)
dados_finais_para_plotar[inicio_plot:fim_plot, :] = dados_corrigidos_logica2

df_original_full = pd.DataFrame(values_novos_dados, columns=['X', 'Y', 'Z'])
df_corrigido_simulado = pd.DataFrame(dados_finais_para_plotar, columns=['X', 'Y', 'Z'])

# --- PLOTAGEM ---
plt.figure(figsize=(20, 12))
# ... (código de plotagem idêntico ao anterior) ...
for i, eixo in enumerate(['X', 'Y', 'Z']):
    plt.subplot(3, 1, i + 1)
    plt.plot(df_original_full.index, df_original_full[eixo], label=f'Original {eixo}', alpha=0.7, color='darkblue')
    plt.plot(df_corrigido_simulado.index, df_corrigido_simulado[eixo], label=f'Corrigido {eixo}', linestyle='-', alpha=0.7, color='darkorange', linewidth=1.5)
    plt.title(f'Resultado - Eixo {eixo}', fontsize=14)
    plt.ylabel(eixo)
    plt.ylim(-1, 1)
    plt.legend()
    plt.grid(True, linestyle='--', alpha=0.6)
    plt.xlim(0, len(df_original_full))
plt.suptitle('Análise Cumulativa de Erro de Variação (Delta)', fontsize=18, y=0.95)
plt.tight_layout(rect=[0, 0.03, 1, 0.93])
plt.show()
# Out:
# Iniciando simulação (Cumulativa de Erro de Variação)

# %% [markdown]
# # _________________________________________________________________________________________________
# # Teste em um conjunto de dados do Sensor 2

# %% [markdown]
# Carregando Dados Sensor 2

# %%
# Carregar os dados do arquivo
file_path2 = './Dados/sensor_data GY-87_2.txt'
df2 = pd.read_csv(file_path2, header=None, names=['X', 'Y', 'Z'])
print(len(df2))
print(df2.head())
# Out:
# 162998
#           X         Y         Z
# 0  0.036700  0.069398  0.073681
# 1 -0.023185 -0.034335  0.076153
# 2  0.023310  0.002150  0.112774
# 3 -0.002545  0.026944  0.119305
# 4  0.002740  0.010308  0.115215

# %% [markdown]
# #### Retirando Outliers

# %%
# se k menor = mais agressivo
df2_cleaned = remove_outliers_rolling_mad(df2, ['X','Y','Z'], window=5000, k=5)
# Exibir as primeiras linhas do DataFrame limpo
print(df2_cleaned.head())
df2=df2_cleaned
# Out:
#              X         Y         Z
# 5000  0.017136  0.017500  0.025494
# 5001 -0.001926 -0.000286  0.072124
# 5002 -0.020323  0.034991  0.075680
# 5003 -0.004095  0.103360  0.069820
# 5004  0.074235  0.070810  0.015835

# %% [markdown]
# Normalizando os dados

# %%
df2_scaled = pd.DataFrame(normalizar_eixos_independente(df2_cleaned)[0], columns=df2_cleaned.columns)

print(df2_scaled.head())
# Out:
#           X         Y         Z
# 0  0.638708  0.661980 -0.878276
# 1  0.637388  0.631356 -0.876099
# 2  0.636115  0.692097 -0.875933
# 3  0.637238  0.809816 -0.876206
# 4  0.642660  0.753771 -0.878726

# %% [markdown]
# Preparando os dados de Teste do Sensor 2

# %%
# Supondo que test_data seja seu DataFrame de teste normalizado
# Convertendo para numpy array
values_test2 = df2_scaled.values

# Reformatando os dados para a entrada LSTM
X_test2, y_test2 = [], []
for i in range(len(values_test2) - n_timesteps):
    X_test2.append(values_test2[i:(i + n_timesteps), :])
    y_test2.append(values_test2[i + n_timesteps, :])
X_test2, y_test2 = np.array(X_test2), np.array(y_test2)

# Agora X_test e y_test estão prontos para serem usados para testar o modelo

# %% [markdown]
# Fazendo a predição

# %%
predicted2 = modelo_carregado.predict(X_test2)
# Out:
# 4747/4747 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step

# %% [markdown]
# Plotando os resultados

# %%
# Definindo as dimensões
dims = ['X', 'Y', 'Z']

plt.figure(figsize=(15, 15))

# Criando um gráfico para cada dimensão
for i, dim in enumerate(dims):
    plt.subplot(3, 1, i+1)
    plt.plot(X_test2[:, -1, i], label='Real')
    plt.plot(predicted2[:, i], label='Previsto')
    plt.title(f'Comparação {dim}')
    plt.xlabel('Tempo')
    plt.ylabel(f'Valor {dim}')
    plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Plotando desnormalizado

# %%
dims = ['X', 'Y', 'Z']

plt.figure(figsize=(15, 15))

for i, dim in enumerate(dims):
    plt.subplot(3, 1, i+1)

    # Desnormalizando os valores reais e previstos
    real_denorm = scalers_tuple[dim].inverse_transform(X_test2[:, -1, i].reshape(-1, 1)).flatten()
    pred_denorm = scalers_tuple[dim].inverse_transform(predicted2[:, i].reshape(-1, 1)).flatten()

    plt.plot(real_denorm, label='Real')
    plt.plot(pred_denorm, label='Previsto')
    plt.title(f'Comparação {dim}')
    plt.xlabel('Tempo')
    plt.ylabel(f'Valor {dim}')
    plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Plotando desnormalizado e com escala da amplitude 360

# %%
dims = ['X', 'Y', 'Z']

plt.figure(figsize=(15, 15))

for i, dim in enumerate(dims):
    plt.subplot(3, 1, i+1)

    # Desnormalizando os valores reais e previstos
    real_denorm = scalers_tuple[dim].inverse_transform(X_test2[:, -1, i].reshape(-1, 1)).flatten()
    pred_denorm = scalers_tuple[dim].inverse_transform(predicted2[:, i].reshape(-1, 1)).flatten()

    plt.plot(real_denorm, label='Real')
    plt.plot(pred_denorm, label='Previsto')
    plt.title(f'Comparação {dim}')
    plt.xlabel('Tempo')
    plt.ylabel(f'Valor {dim}')
    plt.legend()
    plt.ylim(-100, 100)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Mean Squared Error e $R^2$ no Sensor 2

# %%
mse = mean_squared_error(y_test2, predicted2)
r2 = r2_score(y_test2, predicted2)

MSE_R2 = {
    "MSE: ":mse,
    "R2: ": r2
}
# Salvar os hiperparâmetros em um arquivo JSON
model_folder = "models_GY87"
config_path = os.path.join(model_folder, "3.Mean Squared Error e R2.Sensor2.json")
with open(config_path, "w") as f:
    json.dump(MSE_R2, f, indent=4)

print(f"Hiperparâmetros salvos em {config_path}")

print("MSE:", mse)
print("R²:", r2)
# Out:
# Hiperparâmetros salvos em models_GY87/3.Mean Squared Error e R2.Sensor2.json
# MSE: 0.008455821703359933
# R²: 0.9820811124344088

# %% [markdown]
# # ________________________________________________________________________________________________
# # Teste em um conjunto de dados do Sensor 3

# %% [markdown]
# Carregando Dados Sensor 2

# %%
# Carregar os dados do arquivo
file_path3 = './Dados/sensor_data GY-87_3.txt'
df3 = pd.read_csv(file_path3, header=None, names=['X', 'Y', 'Z'])
print(len(df3))
print(df3.head())
# Out:
# 114994
#           X         Y         Z
# 0 -0.205137 -0.105514  0.748047
# 1 -0.132356 -0.191959  0.746872
# 2 -0.121365 -0.123298  0.783981
# 3 -0.063406 -0.205762  0.791946
# 4 -0.092916 -0.167150  0.845535

# %% [markdown]
# ### Retirando Outliers

# %%
# se k menor = mais agressivo
df3_cleaned = remove_outliers_rolling_mad(df3, ['X','Y','Z'], window=5000, k=5)
# Exibir as primeiras linhas do DataFrame limpo
print(df3_cleaned.head())
df3=df3_cleaned
# Out:
#              X         Y         Z
# 5000 -0.125962 -0.089450  0.850250
# 5001 -0.157694 -0.267239  0.858673
# 5002 -0.135858 -0.094985  0.747147
# 5003 -0.184662 -0.213227  0.807404
# 5004 -0.203219 -0.260624  0.793213

# %% [markdown]
# Normalizando os dados

# %%
df3_scaled = pd.DataFrame(normalizar_eixos_independente(df3)[0], columns=df3.columns)

print(df3_scaled.head())
# Out:
#           X         Y         Z
# 0  0.524944 -0.307417 -0.083462
# 1  0.522800 -0.484552 -0.082993
# 2  0.524275 -0.312932 -0.089210
# 3  0.520977 -0.430739 -0.085851
# 4  0.519723 -0.477961 -0.086642

# %% [markdown]
# Preparando os dados de Teste do Sensor 3

# %%
# Supondo que test_data seja seu DataFrame de teste normalizado
# Convertendo para numpy array
values_test3 = df3_scaled.values

# Reformatando os dados para a entrada LSTM
X_test3, y_test3 = [], []
for i in range(len(values_test3) - n_timesteps):
    X_test3.append(values_test3[i:(i + n_timesteps), :])
    y_test3.append(values_test3[i + n_timesteps, :])
X_test3, y_test3 = np.array(X_test3), np.array(y_test3)

# Agora X_test e y_test estão prontos para serem usados para testar o modelo

# %% [markdown]
# Fazendo a predição

# %%
predicted3 = modelo_carregado.predict(X_test3)
# Out:
# 3196/3196 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step

# %% [markdown]
# Plotando os resultados

# %%
# Definindo as dimensões
dims = ['X', 'Y', 'Z']

plt.figure(figsize=(15, 15))

# Criando um gráfico para cada dimensão
for i, dim in enumerate(dims):
    plt.subplot(3, 1, i+1)
    plt.plot(X_test3[:, -1, i], label='Real')
    plt.plot(predicted3[:, i], label='Previsto')
    plt.title(f'Comparação {dim}')
    plt.xlabel('Tempo')
    plt.ylabel(f'Valor {dim}')
    plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Plotando desnormalizado

# %%
dims = ['X', 'Y', 'Z']

plt.figure(figsize=(15, 15))

for i, dim in enumerate(dims):
    plt.subplot(3, 1, i+1)

    # Desnormalizando os valores reais e previstos
    real_denorm = scalers_tuple[dim].inverse_transform(X_test3[:, -1, i].reshape(-1, 1)).flatten()
    pred_denorm = scalers_tuple[dim].inverse_transform(predicted3[:, i].reshape(-1, 1)).flatten()

    plt.plot(real_denorm, label='Real')
    plt.plot(pred_denorm, label='Previsto')
    plt.title(f'Comparação {dim}')
    plt.xlabel('Tempo')
    plt.ylabel(f'Valor {dim}')
    plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Plotando desnormalizado e com escala da amplitude 360

# %%
dims = ['X', 'Y', 'Z']

plt.figure(figsize=(15, 15))

for i, dim in enumerate(dims):
    plt.subplot(3, 1, i+1)

    # Desnormalizando os valores reais e previstos
    real_denorm = scalers_tuple[dim].inverse_transform(X_test3[:, -1, i].reshape(-1, 1)).flatten()
    pred_denorm = scalers_tuple[dim].inverse_transform(predicted3[:, i].reshape(-1, 1)).flatten()

    plt.plot(real_denorm, label='Real')
    plt.plot(pred_denorm, label='Previsto')
    plt.title(f'Comparação {dim}')
    plt.xlabel('Tempo')
    plt.ylabel(f'Valor {dim}')
    plt.legend()
    plt.ylim(-180, 180)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Mean Squared Error e $R^2$ no Sensor 3

# %%
mse = mean_squared_error(y_test3, predicted3)
r2 = r2_score(y_test3, predicted3)

MSE_R2 = {
    "MSE: ":mse,
    "R2: ": r2
}
# Salvar os hiperparâmetros em um arquivo JSON
model_folder = "models_GY87"
config_path = os.path.join(model_folder, "4.Mean Squared Error e R2.Sensor3.json")
with open(config_path, "w") as f:
    json.dump(MSE_R2, f, indent=4)

print(f"Hiperparâmetros salvos em {config_path}")

print("MSE:", mse)
print("R²:", r2)
# Out:
# Hiperparâmetros salvos em models_GY87/4.Mean Squared Error e R2.Sensor3.json
# MSE: 0.02148707385144553
# R²: 0.9441435204504428
