# %%
# %pip install --upgrade pip
# %pip install pandas
# %pip install scikit-learn
# %pip install tensorflow
# %pip install keras
# %pip install matplotlib
# %pip install ipympl

# %%
import os
import tensorflow as tf 
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Input
from tensorflow.keras.models import load_model
from keras.callbacks import EarlyStopping
from keras import metrics
from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from tensorflow.keras import backend as K
from tensorflow.keras.optimizers import Nadam
import gc
import pickle
import pandas as pd
import numpy as np
# %matplotlib inline
# %matplotlib widget
import matplotlib.pyplot as plt
# Out:
# 2025-10-27 08:50:26.148957: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-10-27 08:50:26.427149: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1761565826.514571    1412 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1761565826.538098    1412 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1761565826.743091    1412 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1761565826.743122    1412 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1761565826.743123    1412 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1761565826.743124    1412 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-10-27 08:50:26.765710: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ## Lista de hardware para IA

# %%
from tensorflow.python.client import device_lib

print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 1751377225316014237
# xla_global_id: -1
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 10182721536
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 4876157470180204669
# physical_device_desc: "device: 0, name: NVIDIA GeForce RTX 3060, pci bus id: 0000:01:00.0, compute capability: 8.6"
# xla_global_id: 416903419
# ]
# I0000 00:00:1761565831.162590    1412 gpu_device.cc:2019] Created device /device:GPU:0 with 9711 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060, pci bus id: 0000:01:00.0, compute capability: 8.6

# %% [markdown]
# Carregando os dados do sensor 1

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.19.0

# %%
# Carregar os dados do arquivo
file_path = './Dados/dados.txt'
df = pd.read_csv(file_path, header=None, names=['X', 'Y', 'Z'])
# df = df[1300:700000]
df = df[1300:1001300]
print(len(df))
print(df[:10])
# Out:
# 1000000
#              X         Y         Z
# 1300  0.023170  0.031583  0.166704
# 1301  0.055885  0.029131  0.087190
# 1302 -0.098040  0.005832  0.032991
# 1303 -0.007686 -0.042610  0.008653
# 1304  0.059936  0.024195  0.123689
# 1305 -0.087651 -0.004043  0.169130
# 1306 -0.064748 -0.009573  0.237276
# 1307 -0.020850 -0.041289  0.262926
# 1308 -0.024913 -0.071225  0.141740
# 1309  0.073232 -0.026073 -0.021101

# %%
print(f"Intervalo X: {df['X'].min()} a {df['X'].max()}")
print(f"Intervalo Y: {df['Y'].min()} a {df['Y'].max()}")
print(f"Intervalo Z: {df['Z'].min()} a {df['Z'].max()}")


# Supondo que 'df' é seu DataFrame original com as colunas 'X', 'Y', 'Z'
plt.figure(figsize=(12, 6))

# Plotando cada coluna
plt.subplot(3, 1, 1)  # 3 linhas, 1 coluna, posição 1
plt.plot(df['X'], label='X')
plt.title('Sensor Data - X')
plt.ylabel('X')

plt.subplot(3, 1, 2)  # 3 linhas, 1 coluna, posição 2
plt.plot(df['Y'], label='Y')
plt.title('Sensor Data - Y')
plt.ylabel('Y')

plt.subplot(3, 1, 3)  # 3 linhas, 1 coluna, posição 3
plt.plot(df['Z'], label='Z')
plt.title('Sensor Data - Z')
plt.ylabel('Z')
plt.xlabel('Sample Number')

# Mostrando o gráfico
plt.tight_layout()
plt.show()
# Out:
# Intervalo X: -9.461193084716798e+18 a 5.82562255859375e+22
# Intervalo Y: -5898436.275593 a 7.222764015197753e+19
# Intervalo Z: -159.023631 a 0.587022

# %% [markdown]
# ### Retirando os outliers

# %%
def remove_outliers_rolling_mad(df, columns, window=2000, k=6):
    mask_all = pd.Series(True, index=df.index)
    for col in columns:
        med = df[col].rolling(window, center=True).median()
        mad = (df[col] - med).abs().rolling(window, center=True).median() * 1.4826
        mask = ((df[col] - med).abs() <= k*mad).fillna(True)
        mask_all &= mask
    return df[mask_all]
# se k menor = mais agressivo
df_cleaned = remove_outliers_rolling_mad(df, ['X','Y','Z'], window=5000, k=6)
# Exibir as primeiras linhas do DataFrame limpo
print(df_cleaned.head())
# Out:
#              X         Y         Z
# 6300  0.012653 -0.020875 -0.090865
# 6301  0.044998 -0.019577 -0.058516
# 6302  0.034513  0.011652 -0.018782
# 6303 -0.006604  0.014207 -0.005156
# 6304 -0.082959 -0.028364 -0.059187

# %%
print(f"Intervalo X: {df_cleaned['X'].min()} a {df_cleaned['X'].max()}")
print(f"Intervalo Y: {df_cleaned['Y'].min()} a {df_cleaned['Y'].max()}")
print(f"Intervalo Z: {df_cleaned['Z'].min()} a {df_cleaned['Z'].max()}")

plt.figure(figsize=(12, 6))

# Plotar os dados após a remoção de outliers
plt.subplot(3, 1, 1)
plt.plot(df_cleaned['X'], label='X')
plt.title('Sensor Data - X (Sem Outliers)')
plt.ylabel('X')

plt.subplot(3, 1, 2)
plt.plot(df_cleaned['Y'], label='Y')
plt.title('Sensor Data - Y (Sem Outliers)')
plt.ylabel('Y')

plt.subplot(3, 1, 3)
plt.plot(df_cleaned['Z'], label='Z')
plt.title('Sensor Data - Z (Sem Outliers)')
plt.ylabel('Z')
plt.xlabel('Sample Number')

plt.tight_layout()
plt.show()
# Out:
# Intervalo X: -0.311898 a 0.267763
# Intervalo Y: -0.20085 a 0.244633
# Intervalo Z: -0.985228 a 0.587022

# %% [markdown]
# # POR ENQUANDO IGNORE A RETIRADA DOS OUTLIERS

# %%
# COMENTEQUE QUISER QUE IGNORE A RETIRADA DOS OUTLIERS
df=df_cleaned

# %% [markdown]
# ## Normalizando os dados para uso do LSTM

# %%
# Definindo o range para -1 a 1, apropriado para sensores com valores entre -180 e 180
# scaler = MinMaxScaler(feature_range=(-1, 1))
# scaler = StandardScaler()

# Normalizando os dados
# df_scaled = pd.DataFrame(scaler.fit_transform(df), columns=df.columns)

# Salvando o scaler ajustado
# with open('scaler.pkl', 'wb') as f:
#     pickle.dump(scaler, f)

# Visualizando os primeiros dados normalizados
# print(df_scaled.head())
def normalizar_eixos_independente(dataframe):
    """
    Normaliza as colunas 'X', 'Y' e 'Z' de um DataFrame individualmente 
    com MinMaxScaler no intervalo (-1, 1).

    Retorna:
        df_scaled: DataFrame normalizado
        scalers: dicionário com os scalers {'X': scaler_X, 'Y': scaler_Y, 'Z': scaler_Z}
    """
    scaler_X = MinMaxScaler(feature_range=(-1, 1))
    scaler_Y = MinMaxScaler(feature_range=(-1, 1))
    scaler_Z = MinMaxScaler(feature_range=(-1, 1))

    df_scaled = pd.DataFrame()
    df_scaled['X'] = scaler_X.fit_transform(dataframe[['X']]).flatten()
    df_scaled['Y'] = scaler_Y.fit_transform(dataframe[['Y']]).flatten()
    df_scaled['Z'] = scaler_Z.fit_transform(dataframe[['Z']]).flatten()

    scalers = {'X': scaler_X, 'Y': scaler_Y, 'Z': scaler_Z}
    return df_scaled, scalers

df_scaled, scalers_tuple = normalizar_eixos_independente(df)


# # Salvar os scalers em um único arquivo (como uma tupla)
with open('scalers.pkl', 'wb') as f:
    pickle.dump(scalers_tuple, f)

# # Visualizando os primeiros dados normalizados
print(df_scaled.head())
# Out:
#           X         Y         Z
# 0  0.119796 -0.192001  0.137685
# 1  0.231396 -0.186173  0.178835
# 2  0.195219 -0.045970  0.229380
# 3  0.053354 -0.034500  0.246713
# 4 -0.210093 -0.225623  0.177982

# %%
# Histogramas dos valores normalizados

df_scaled.hist(bins=50, figsize=(12, 4), layout=(1, 3))
plt.suptitle("Distribuição Normalizada dos Eixos X, Y e Z")
plt.show()

# %%
print(f"Intervalo X: {df_scaled['X'].min()} a {df_scaled['X'].max()}")
print(f"Intervalo Y: {df_scaled['Y'].min()} a {df_scaled['Y'].max()}")
print(f"Intervalo Z: {df_scaled['Z'].min()} a {df_scaled['Z'].max()}")


# Supondo que 'df' é seu DataFrame original com as colunas 'X', 'Y', 'Z'
plt.figure(figsize=(12, 6))

# Plotando cada coluna
plt.subplot(3, 1, 1)  # 3 linhas, 1 coluna, posição 1
plt.plot(df_scaled['X'], label='X')
plt.title('Sensor Data - X')
plt.ylabel('X')

plt.subplot(3, 1, 2)  # 3 linhas, 1 coluna, posição 2
plt.plot(df_scaled['Y'], label='Y')
plt.title('Sensor Data - Y')
plt.ylabel('Y')

plt.subplot(3, 1, 3)  # 3 linhas, 1 coluna, posição 3
plt.plot(df_scaled['Z'], label='Z')
plt.title('Sensor Data - Z')
plt.ylabel('Z')
plt.xlabel('Sample Number')

# Mostrando o gráfico
plt.tight_layout()
plt.show()
# Out:
# Intervalo X: -1.0 a 1.0
# Intervalo Y: -1.0 a 1.0
# Intervalo Z: -1.0 a 1.0

# %% [markdown]
# # ******************************************************
# # HIPERPARAMETROS

# %%
# Valores dos hiperparâmetros
n_splits=4 # 4
timestepsValue = 80 # 80
pesosValue = tf.constant([ 1.0, 1.0, 1.0]) # ([1.0, 0.1, 1.0])
neuroniosValue = 500 # 262                                                                                                                                                                                                                                 # 25
dropoutValue = 0.14512369139123038
ativacaoType = 'tanh'
best_lr = 0.0019702991167906115
epocasValue = 50 # 50
batchValue = 120 # 120
pacienciaValue = 5 # 10

# Criar uma pasta para salvar os modelos
model_folder = "models_GY87"
os.makedirs(model_folder, exist_ok=True)

# Dicionário com os hiperparâmetros
experiment_config = {
    "Splits": n_splits,
    "timesteps": timestepsValue,
    "wights": pesosValue.numpy().tolist(),
    "neuronios": neuroniosValue,
    "dropout": dropoutValue,
    "ativacao": ativacaoType,
    "learning_rate": best_lr,
    "epocas": epocasValue,
    "batch": batchValue,
    "paciencia": pacienciaValue
}

# Salvar os hiperparâmetros em um arquivo JSON
import json
config_path = os.path.join(model_folder, "hiperparametros.json")
with open(config_path, "w") as f:
    json.dump(experiment_config, f, indent=4)

print(f"Hiperparâmetros salvos em {config_path}")
# Out:
# Hiperparâmetros salvos em models_GY87/hiperparametros.json
# I0000 00:00:1761565837.350191    1412 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9711 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060, pci bus id: 0000:01:00.0, compute capability: 8.6

# %% [markdown]
# ## Definindo Cross Validation TimeSeriesSplit e Variáveis

# %%
# Função de perda ponderada (se quiser usar)
def weighted_mse(y_true, y_pred):
    weights = pesosValue  # Exemplo: np.array([1.0, 1.0, 0.5]) para X, Y, Z
    loss = K.mean(weights * K.square(y_pred - y_true), axis=-1)
    return loss

# Função para monitorar o erro em cada eixo separadamente durante o treinamento.
# Assim, você pode ver se o modelo está realmente aprendendo em todos os eixos.
def mse_x(y_true, y_pred):
    return K.mean(K.square(y_pred[:, 0] - y_true[:, 0]))

def mse_y(y_true, y_pred):
    return K.mean(K.square(y_pred[:, 1] - y_true[:, 1]))

def mse_z(y_true, y_pred):
    return K.mean(K.square(y_pred[:, 2] - y_true[:, 2]))


tscv = TimeSeriesSplit(n_splits)
print(tscv)
# Out:
# TimeSeriesSplit(gap=0, max_train_size=None, n_splits=4, test_size=None)

# %% [markdown]
# ## Criar Sequências para Treino e Teste
# ### Transformando os dados de treino e teste em sequências temporais para serem usados como entrada no modelo LSTM.

# %%
# # Função para criar sequências
def create_sequences(data, n_timesteps):
    X, y = [], []
    for i in range(len(data) - n_timesteps):
        X.append(data[i:i+n_timesteps, :])  # Sequência de entrada
        y.append(data[i+n_timesteps, :])   # Próxima linha como saída
    return np.array(X), np.array(y)

# Definir o número de timesteps (janelas de tempo)
n_timesteps = timestepsValue  # Exemplo: 80 passos no tempo
n_features = df_scaled.shape[1]  # Número de colunas (X, Y, Z)

# %%
# Visualizar os splits gerados
for train_index, test_index in tscv.split(df_scaled):
    print(f"Treino: {len(train_index)} amostras, Teste: {len(test_index)} amostras")
    print(f"Treino: {train_index[:5]}...{train_index[-5:]}, Teste: {test_index[:5]}...{test_index[-5:]}")
# Out:
# Treino: 197688 amostras, Teste: 197688 amostras
# Treino: [0 1 2 3 4]...[197683 197684 197685 197686 197687], Teste: [197688 197689 197690 197691 197692]...[395371 395372 395373 395374 395375]
# Treino: 395376 amostras, Teste: 197688 amostras
# Treino: [0 1 2 3 4]...[395371 395372 395373 395374 395375], Teste: [395376 395377 395378 395379 395380]...[593059 593060 593061 593062 593063]
# Treino: 593064 amostras, Teste: 197688 amostras
# Treino: [0 1 2 3 4]...[593059 593060 593061 593062 593063], Teste: [593064 593065 593066 593067 593068]...[790747 790748 790749 790750 790751]
# Treino: 790752 amostras, Teste: 197688 amostras
# Treino: [0 1 2 3 4]...[790747 790748 790749 790750 790751], Teste: [790752 790753 790754 790755 790756]...[988435 988436 988437 988438 988439]

# %% [markdown]
# ### Caso não queira treinar novamente, mas apenas executar a predição do modelo, descomente!

# %%
# Loop de treinamento para cada split
for split_idx, (train_index, test_index) in enumerate(tscv.split(df_scaled.values), start=1):
    # Criar os dados de treino e teste
    train_data, test_data = df_scaled.values[train_index], df_scaled.values[test_index]
    X_train, y_train = create_sequences(train_data, n_timesteps)
    X_test, y_test = create_sequences(test_data, n_timesteps)
    
    print(f"Split {split_idx}:")
    print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
    print(f"X_test shape: {X_test.shape}, y_test shape: {y_test.shape}")
# Out:
# Split 1:
# X_train shape: (197608, 80, 3), y_train shape: (197608, 3)
# X_test shape: (197608, 80, 3), y_test shape: (197608, 3)
# Split 2:
# X_train shape: (395296, 80, 3), y_train shape: (395296, 3)
# X_test shape: (197608, 80, 3), y_test shape: (197608, 3)
# Split 3:
# X_train shape: (592984, 80, 3), y_train shape: (592984, 3)
# X_test shape: (197608, 80, 3), y_test shape: (197608, 3)
# Split 4:
# X_train shape: (790672, 80, 3), y_train shape: (790672, 3)
# X_test shape: (197608, 80, 3), y_test shape: (197608, 3)

# %% [markdown]
# # LSTM

# %% [markdown]
# ### Treinar o Modelo em Cada Split usando o Early Stopping e Salvando .keras
# Para cada split será treinado o modelo usando os dados de treino e será avaliado nos dados de teste. O EarlyStopping será usado para evitar overfitting.

# %%
# Loop de treinamento para cada split
for split_idx, (train_index, test_index) in enumerate(tscv.split(df_scaled.values), start=1):
    # Limpeza de memória antes de iniciar o próximo modelo
    K.clear_session()
    gc.collect()
    # Criar os dados de treino e teste
    train_data, test_data = df_scaled.values[train_index], df_scaled.values[test_index]
    X_train, y_train = create_sequences(train_data, n_timesteps)
    X_test, y_test = create_sequences(test_data, n_timesteps)
    
    print(f"Split {split_idx}:")
    print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
    print(f"X_test shape: {X_test.shape}, y_test shape: {y_test.shape}")

    # Configurar o modelo LSTM
    model = Sequential()
    model.add(Input(shape=(n_timesteps, n_features)))
    # Se quiser 4 camadas LSTM, descomente as linhas abaixo:
    # model.add(LSTM(units=270, activation='tanh', return_sequences=True))
    # model.add(LSTM(units=150, activation='tanh', return_sequences=True))
    # model.add(LSTM(units=150, activation='tanh', return_sequences=True))
    # model.add(LSTM(units=150, activation=ativacaoType))
    # Se quiser só 1 camada LSTM, use apenas a linha abaixo:
    model.add(LSTM(units=neuroniosValue, activation=ativacaoType))
    # model.add(Dropout(dropoutValue))
    model.add(Dense(n_features))
    
    model.compile(
        optimizer = "Nadam", # Nadam(learning_rate=best_lr),
        loss = weighted_mse, # 'mse',
        metrics=[
            metrics.MeanSquaredError(),
            metrics.MeanAbsoluteError(),
            metrics.RootMeanSquaredError(),
            mse_x, mse_y, mse_z  # métricas customizadas
        ]
    )

    # Treinar o modelo
    print(f"Treinando o modelo para o split {split_idx}...")
    history = model.fit(
        X_train, y_train,
        epochs=epocasValue,
        batch_size=batchValue,
        validation_data=(X_test, y_test),
        callbacks=[EarlyStopping(monitor='val_loss', patience=pacienciaValue, verbose=1, mode='min')],
        verbose=1
    )

    # Salvar o modelo no formato .keras
    model_path = os.path.join(model_folder, f"lstm_split_{split_idx}.keras")
    model.save(model_path)
    print(f"Modelo do split {split_idx} salvo em {model_path}")
# Out:
# Split 1:
# X_train shape: (197608, 80, 3), y_train shape: (197608, 3)
# X_test shape: (197608, 80, 3), y_test shape: (197608, 3)
# Treinando o modelo para o split 1...
# Epoch 1/50
# I0000 00:00:1761565844.572915    2238 cuda_dnn.cc:529] Loaded cuDNN version 90501
# 1647/1647 ━━━━━━━━━━━━━━━━━━━━ 52s 31ms/step - loss: 0.0258 - mean_absolute_error: 0.1197 - mean_squared_error: 0.0258 - mse_x: 0.0454 - mse_y: 0.0223 - mse_z: 0.0097 - root_mean_squared_error: 0.1603 - val_loss: 0.0222 - val_mean_absolute_error: 0.1069 - val_mean_squared_error: 0.0222 - val_mse_x: 0.0395 - val_mse_y: 0.0225 - val_mse_z: 0.0047 - val_root_mean_squared_error: 0.1491
# Epoch 2/50
# 1647/1647 ━━━━━━━━━━━━━━━━━━━━ 50s 30ms/step - loss: 0.0191 - mean_absolute_error: 0.1011 - mean_squared_error: 0.0191 - mse_x: 0.0309 - mse_y: 0.0215 - mse_z: 0.0049 - root_mean_squared_error: 0.1381 - val_loss: 0.0203 - val_mean_absolute_error: 0.1030 - val_mean_squared_error: 0.0203 - val_mse_x: 0.0333 - val_mse_y: 0.0224 - val_mse_z: 0.0051 - val_root_mean_squared_error: 0.1423
# Epoch 3/50
# 1647/1647 ━━━━━━━━━━━━━━━━━━━━ 48s 29ms/step - loss: 0.0177 - mean_absolute_error: 0.0973 - mean_squared_error: 0.0177 - mse_x: 0.0270 - mse_y: 0.0214 - mse_z: 0.0048 - root_mean_squared_error: 0.1330 - val_loss: 0.0201 - val_mean_absolute_error: 0.1022 - val_mean_squared_error: 0.0201 - val_mse_x: 0.0334 - val_mse_y: 0.0221 - val_mse_z: 0.0049 - val_root_mean_squared_error: 0.1419
# Epoch 4/50
# 1647/1647 ━━━━━━━━━━━━━━━━━━━━ 49s 29ms/step - loss: 0.0185 - mean_absolute_error: 0.0990 - mean_squared_error: 0.0185 - mse_x: 0.0292 - mse_y: 0.0214 - mse_z: 0.0048 - root_mean_squared_error: 0.1359 - val_loss: 0.0211 - val_mean_absolute_error: 0.1042 - val_mean_squared_error: 0.0211 - val_mse_x: 0.0364 - val_mse_y: 0.0222 - val_mse_z: 0.0048 - val_root_mean_squared_error: 0.1454
# Epoch 5/50
# 1647/1647 ━━━━━━━━━━━━━━━━━━━━ 48s 29ms/step - loss: 0.0180 - mean_absolute_error: 0.0979 - mean_squared_error: 0.0180 - mse_x: 0.0279 - mse_y: 0.0214 - mse_z: 0.0047 - root_mean_squared_error: 0.1343 - val_loss: 0.0201 - val_mean_absolute_error: 0.1012 - val_mean_squared_error: 0.0201 - val_mse_x: 0.0341 - val_mse_y: 0.0216 - val_mse_z: 0.0047 - val_root_mean_squared_error: 0.1419
# Epoch 6/50
# 1647/1647 ━━━━━━━━━━━━━━━━━━━━ 48s 29ms/step - loss: 0.0173 - mean_absolute_error: 0.0959 - mean_squared_error: 0.0173 - mse_x: 0.0259 - mse_y: 0.0213 - mse_z: 0.0047 - root_mean_squared_error: 0.1316 - val_loss: 0.0197 - val_mean_absolute_error: 0.1010 - val_mean_squared_error: 0.0197 - val_mse_x: 0.0327 - val_mse_y: 0.0216 - val_mse_z: 0.0049 - val_root_mean_squared_error: 0.1405
# Epoch 7/50
# 1647/1647 ━━━━━━━━━━━━━━━━━━━━ 47s 29ms/step - loss: 0.0185 - mean_absolute_error: 0.0967 - mean_squared_error: 0.0185 - mse_x: 0.0269 - mse_y: 0.0220 - mse_z: 0.0067 - root_mean_squared_error: 0.1361 - val_loss: 0.0193 - val_mean_absolute_error: 0.0993 - val_mean_squared_error: 0.0193 - val_mse_x: 0.0316 - val_mse_y: 0.0213 - val_mse_z: 0.0048 - val_root_mean_squared_error: 0.1387
# Epoch 8/50
# 1647/1647 ━━━━━━━━━━━━━━━━━━━━ 48s 29ms/step - loss: 0.0168 - mean_absolute_error: 0.0944 - mean_squared_error: 0.0168 - mse_x: 0.0247 - mse_y: 0.0211 - mse_z: 0.0046 - root_mean_squared_error: 0.1296 - val_loss: 0.0197 - val_mean_absolute_error: 0.1007 - val_mean_squared_error: 0.0197 - val_mse_x: 0.0319 - val_mse_y: 0.0225 - val_mse_z: 0.0047 - val_root_mean_squared_error: 0.1404
# Epoch 9/50
# 1647/1647 ━━━━━━━━━━━━━━━━━━━━ 49s 30ms/step - loss: 0.0167 - mean_absolute_error: 0.0941 - mean_squared_error: 0.0167 - mse_x: 0.0246 - mse_y: 0.0209 - mse_z: 0.0046 - root_mean_squared_error: 0.1293 - val_loss: 0.0195 - val_mean_absolute_error: 0.0997 - val_mean_squared_error: 0.0195 - val_mse_x: 0.0317 - val_mse_y: 0.0220 - val_mse_z: 0.0046 - val_root_mean_squared_error: 0.1395
# Epoch 10/50
# 1647/1647 ━━━━━━━━━━━━━━━━━━━━ 49s 29ms/step - loss: 0.0166 - mean_absolute_error: 0.0938 - mean_squared_error: 0.0166 - mse_x: 0.0247 - mse_y: 0.0207 - mse_z: 0.0045 - root_mean_squared_error: 0.1290 - val_loss: 0.0190 - val_mean_absolute_error: 0.0989 - val_mean_squared_error: 0.0190 - val_mse_x: 0.0310 - val_mse_y: 0.0215 - val_mse_z: 0.0046 - val_root_mean_squared_error: 0.1380
# Epoch 11/50
# 1647/1647 ━━━━━━━━━━━━━━━━━━━━ 47s 29ms/step - loss: 0.0165 - mean_absolute_error: 0.0937 - mean_squared_error: 0.0165 - mse_x: 0.0244 - mse_y: 0.0207 - mse_z: 0.0045 - root_mean_squared_error: 0.1286 - val_loss: 0.0194 - val_mean_absolute_error: 0.0997 - val_mean_squared_error: 0.0194 - val_mse_x: 0.0322 - val_mse_y: 0.0215 - val_mse_z: 0.0047 - val_root_mean_squared_error: 0.1394
# Epoch 12/50
# 1647/1647 ━━━━━━━━━━━━━━━━━━━━ 47s 29ms/step - loss: 0.0165 - mean_absolute_error: 0.0934 - mean_squared_error: 0.0165 - mse_x: 0.0243 - mse_y: 0.0206 - mse_z: 0.0045 - root_mean_squared_error: 0.1284 - val_loss: 0.0195 - val_mean_absolute_error: 0.0993 - val_mean_squared_error: 0.0195 - val_mse_x: 0.0324 - val_mse_y: 0.0215 - val_mse_z: 0.0047 - val_root_mean_squared_error: 0.1397
# Epoch 13/50
# 1647/1647 ━━━━━━━━━━━━━━━━━━━━ 46s 28ms/step - loss: 0.0165 - mean_absolute_error: 0.0935 - mean_squared_error: 0.0165 - mse_x: 0.0244 - mse_y: 0.0206 - mse_z: 0.0045 - root_mean_squared_error: 0.1284 - val_loss: 0.0193 - val_mean_absolute_error: 0.0985 - val_mean_squared_error: 0.0193 - val_mse_x: 0.0320 - val_mse_y: 0.0212 - val_mse_z: 0.0046 - val_root_mean_squared_error: 0.1388
# Epoch 14/50
# 1647/1647 ━━━━━━━━━━━━━━━━━━━━ 49s 30ms/step - loss: 0.0164 - mean_absolute_error: 0.0932 - mean_squared_error: 0.0164 - mse_x: 0.0242 - mse_y: 0.0206 - mse_z: 0.0045 - root_mean_squared_error: 0.1282 - val_loss: 0.0191 - val_mean_absolute_error: 0.0984 - val_mean_squared_error: 0.0191 - val_mse_x: 0.0310 - val_mse_y: 0.0216 - val_mse_z: 0.0046 - val_root_mean_squared_error: 0.1381
# Epoch 15/50
# 1647/1647 ━━━━━━━━━━━━━━━━━━━━ 48s 29ms/step - loss: 0.0164 - mean_absolute_error: 0.0930 - mean_squared_error: 0.0164 - mse_x: 0.0239 - mse_y: 0.0207 - mse_z: 0.0045 - root_mean_squared_error: 0.1279 - val_loss: 0.0185 - val_mean_absolute_error: 0.0969 - val_mean_squared_error: 0.0185 - val_mse_x: 0.0300 - val_mse_y: 0.0210 - val_mse_z: 0.0045 - val_root_mean_squared_error: 0.1361
# Epoch 16/50
# 1647/1647 ━━━━━━━━━━━━━━━━━━━━ 48s 29ms/step - loss: 0.0163 - mean_absolute_error: 0.0928 - mean_squared_error: 0.0163 - mse_x: 0.0241 - mse_y: 0.0206 - mse_z: 0.0044 - root_mean_squared_error: 0.1278 - val_loss: 0.0191 - val_mean_absolute_error: 0.0983 - val_mean_squared_error: 0.0191 - val_mse_x: 0.0313 - val_mse_y: 0.0214 - val_mse_z: 0.0046 - val_root_mean_squared_error: 0.1382
# Epoch 17/50
# 1647/1647 ━━━━━━━━━━━━━━━━━━━━ 47s 29ms/step - loss: 0.0162 - mean_absolute_error: 0.0923 - mean_squared_error: 0.0162 - mse_x: 0.0238 - mse_y: 0.0205 - mse_z: 0.0043 - root_mean_squared_error: 0.1273 - val_loss: 0.0189 - val_mean_absolute_error: 0.0978 - val_mean_squared_error: 0.0189 - val_mse_x: 0.0310 - val_mse_y: 0.0214 - val_mse_z: 0.0045 - val_root_mean_squared_error: 0.1376
# Epoch 18/50
# 1647/1647 ━━━━━━━━━━━━━━━━━━━━ 47s 29ms/step - loss: 0.0163 - mean_absolute_error: 0.0922 - mean_squared_error: 0.0163 - mse_x: 0.0240 - mse_y: 0.0205 - mse_z: 0.0043 - root_mean_squared_error: 0.1275 - val_loss: 0.0186 - val_mean_absolute_error: 0.0967 - val_mean_squared_error: 0.0186 - val_mse_x: 0.0305 - val_mse_y: 0.0210 - val_mse_z: 0.0044 - val_root_mean_squared_error: 0.1365
# Epoch 19/50
# 1647/1647 ━━━━━━━━━━━━━━━━━━━━ 48s 29ms/step - loss: 0.0162 - mean_absolute_error: 0.0919 - mean_squared_error: 0.0162 - mse_x: 0.0240 - mse_y: 0.0205 - mse_z: 0.0042 - root_mean_squared_error: 0.1273 - val_loss: 0.0194 - val_mean_absolute_error: 0.0986 - val_mean_squared_error: 0.0194 - val_mse_x: 0.0318 - val_mse_y: 0.0219 - val_mse_z: 0.0044 - val_root_mean_squared_error: 0.1392
# Epoch 20/50
# 1647/1647 ━━━━━━━━━━━━━━━━━━━━ 47s 29ms/step - loss: 0.0161 - mean_absolute_error: 0.0915 - mean_squared_error: 0.0161 - mse_x: 0.0238 - mse_y: 0.0205 - mse_z: 0.0041 - root_mean_squared_error: 0.1269 - val_loss: 0.0184 - val_mean_absolute_error: 0.0957 - val_mean_squared_error: 0.0184 - val_mse_x: 0.0300 - val_mse_y: 0.0211 - val_mse_z: 0.0042 - val_root_mean_squared_error: 0.1358
# Epoch 21/50
# 1647/1647 ━━━━━━━━━━━━━━━━━━━━ 46s 28ms/step - loss: 0.0160 - mean_absolute_error: 0.0910 - mean_squared_error: 0.0160 - mse_x: 0.0236 - mse_y: 0.0206 - mse_z: 0.0039 - root_mean_squared_error: 0.1267 - val_loss: 0.0185 - val_mean_absolute_error: 0.0959 - val_mean_squared_error: 0.0185 - val_mse_x: 0.0302 - val_mse_y: 0.0212 - val_mse_z: 0.0040 - val_root_mean_squared_error: 0.1359
# Epoch 22/50
# 1647/1647 ━━━━━━━━━━━━━━━━━━━━ 46s 28ms/step - loss: 0.0159 - mean_absolute_error: 0.0903 - mean_squared_error: 0.0159 - mse_x: 0.0236 - mse_y: 0.0204 - mse_z: 0.0037 - root_mean_squared_error: 0.1261 - val_loss: 0.0184 - val_mean_absolute_error: 0.0950 - val_mean_squared_error: 0.0184 - val_mse_x: 0.0302 - val_mse_y: 0.0212 - val_mse_z: 0.0039 - val_root_mean_squared_error: 0.1357
# Epoch 23/50
# 1647/1647 ━━━━━━━━━━━━━━━━━━━━ 47s 28ms/step - loss: 0.0158 - mean_absolute_error: 0.0893 - mean_squared_error: 0.0158 - mse_x: 0.0234 - mse_y: 0.0205 - mse_z: 0.0035 - root_mean_squared_error: 0.1256 - val_loss: 0.0186 - val_mean_absolute_error: 0.0955 - val_mean_squared_error: 0.0186 - val_mse_x: 0.0306 - val_mse_y: 0.0212 - val_mse_z: 0.0040 - val_root_mean_squared_error: 0.1363
# Epoch 24/50
# 1647/1647 ━━━━━━━━━━━━━━━━━━━━ 47s 29ms/step - loss: 0.0157 - mean_absolute_error: 0.0888 - mean_squared_error: 0.0157 - mse_x: 0.0234 - mse_y: 0.0205 - mse_z: 0.0033 - root_mean_squared_error: 0.1254 - val_loss: 0.0185 - val_mean_absolute_error: 0.0947 - val_mean_squared_error: 0.0185 - val_mse_x: 0.0302 - val_mse_y: 0.0213 - val_mse_z: 0.0038 - val_root_mean_squared_error: 0.1358
# Epoch 25/50
# 1647/1647 ━━━━━━━━━━━━━━━━━━━━ 46s 28ms/step - loss: 0.0157 - mean_absolute_error: 0.0884 - mean_squared_error: 0.0157 - mse_x: 0.0233 - mse_y: 0.0204 - mse_z: 0.0033 - root_mean_squared_error: 0.1251 - val_loss: 0.0184 - val_mean_absolute_error: 0.0944 - val_mean_squared_error: 0.0184 - val_mse_x: 0.0301 - val_mse_y: 0.0212 - val_mse_z: 0.0038 - val_root_mean_squared_error: 0.1356
# Epoch 26/50
# 1647/1647 ━━━━━━━━━━━━━━━━━━━━ 46s 28ms/step - loss: 0.0156 - mean_absolute_error: 0.0882 - mean_squared_error: 0.0156 - mse_x: 0.0232 - mse_y: 0.0204 - mse_z: 0.0032 - root_mean_squared_error: 0.1249 - val_loss: 0.0184 - val_mean_absolute_error: 0.0946 - val_mean_squared_error: 0.0184 - val_mse_x: 0.0304 - val_mse_y: 0.0211 - val_mse_z: 0.0038 - val_root_mean_squared_error: 0.1358
# Epoch 27/50
# 1647/1647 ━━━━━━━━━━━━━━━━━━━━ 47s 28ms/step - loss: 0.0156 - mean_absolute_error: 0.0880 - mean_squared_error: 0.0156 - mse_x: 0.0231 - mse_y: 0.0204 - mse_z: 0.0032 - root_mean_squared_error: 0.1247 - val_loss: 0.0187 - val_mean_absolute_error: 0.0954 - val_mean_squared_error: 0.0187 - val_mse_x: 0.0310 - val_mse_y: 0.0212 - val_mse_z: 0.0039 - val_root_mean_squared_error: 0.1368
# Epoch 28/50
# 1647/1647 ━━━━━━━━━━━━━━━━━━━━ 47s 28ms/step - loss: 0.0156 - mean_absolute_error: 0.0881 - mean_squared_error: 0.0156 - mse_x: 0.0229 - mse_y: 0.0205 - mse_z: 0.0032 - root_mean_squared_error: 0.1247 - val_loss: 0.0187 - val_mean_absolute_error: 0.0956 - val_mean_squared_error: 0.0187 - val_mse_x: 0.0306 - val_mse_y: 0.0216 - val_mse_z: 0.0039 - val_root_mean_squared_error: 0.1368
# Epoch 29/50
# 1647/1647 ━━━━━━━━━━━━━━━━━━━━ 47s 28ms/step - loss: 0.0154 - mean_absolute_error: 0.0876 - mean_squared_error: 0.0154 - mse_x: 0.0230 - mse_y: 0.0202 - mse_z: 0.0031 - root_mean_squared_error: 0.1242 - val_loss: 0.0186 - val_mean_absolute_error: 0.0950 - val_mean_squared_error: 0.0186 - val_mse_x: 0.0304 - val_mse_y: 0.0214 - val_mse_z: 0.0039 - val_root_mean_squared_error: 0.1362
# Epoch 30/50
# 1647/1647 ━━━━━━━━━━━━━━━━━━━━ 47s 28ms/step - loss: 0.0154 - mean_absolute_error: 0.0876 - mean_squared_error: 0.0154 - mse_x: 0.0226 - mse_y: 0.0203 - mse_z: 0.0031 - root_mean_squared_error: 0.1240 - val_loss: 0.0186 - val_mean_absolute_error: 0.0951 - val_mean_squared_error: 0.0186 - val_mse_x: 0.0304 - val_mse_y: 0.0215 - val_mse_z: 0.0039 - val_root_mean_squared_error: 0.1364
# Epoch 30: early stopping
# Modelo do split 1 salvo em models_GY87/lstm_split_1.keras
# Split 2:
# X_train shape: (395296, 80, 3), y_train shape: (395296, 3)
# X_test shape: (197608, 80, 3), y_test shape: (197608, 3)
# Treinando o modelo para o split 2...
# Epoch 1/50
# 3295/3295 ━━━━━━━━━━━━━━━━━━━━ 81s 24ms/step - loss: 0.0234 - mean_absolute_error: 0.1123 - mean_squared_error: 0.0234 - mse_x: 0.0414 - mse_y: 0.0219 - mse_z: 0.0068 - root_mean_squared_error: 0.1526 - val_loss: 0.0218 - val_mean_absolute_error: 0.1104 - val_mean_squared_error: 0.0218 - val_mse_x: 0.0371 - val_mse_y: 0.0206 - val_mse_z: 0.0076 - val_root_mean_squared_error: 0.1475
# Epoch 2/50
# 3295/3295 ━━━━━━━━━━━━━━━━━━━━ 79s 24ms/step - loss: 0.0183 - mean_absolute_error: 0.0985 - mean_squared_error: 0.0183 - mse_x: 0.0289 - mse_y: 0.0214 - mse_z: 0.0047 - root_mean_squared_error: 0.1354 - val_loss: 0.0200 - val_mean_absolute_error: 0.1032 - val_mean_squared_error: 0.0200 - val_mse_x: 0.0358 - val_mse_y: 0.0189 - val_mse_z: 0.0054 - val_root_mean_squared_error: 0.1416
# Epoch 3/50
# 3295/3295 ━━━━━━━━━━━━━━━━━━━━ 79s 24ms/step - loss: 0.0178 - mean_absolute_error: 0.0969 - mean_squared_error: 0.0178 - mse_x: 0.0275 - mse_y: 0.0212 - mse_z: 0.0047 - root_mean_squared_error: 0.1333 - val_loss: 0.0204 - val_mean_absolute_error: 0.1055 - val_mean_squared_error: 0.0204 - val_mse_x: 0.0354 - val_mse_y: 0.0192 - val_mse_z: 0.0067 - val_root_mean_squared_error: 0.1429
# Epoch 4/50
# 3295/3295 ━━━━━━━━━━━━━━━━━━━━ 79s 24ms/step - loss: 0.0174 - mean_absolute_error: 0.0957 - mean_squared_error: 0.0174 - mse_x: 0.0268 - mse_y: 0.0208 - mse_z: 0.0046 - root_mean_squared_error: 0.1320 - val_loss: 0.0214 - val_mean_absolute_error: 0.1062 - val_mean_squared_error: 0.0214 - val_mse_x: 0.0376 - val_mse_y: 0.0195 - val_mse_z: 0.0069 - val_root_mean_squared_error: 0.1462
# Epoch 5/50
# 3295/3295 ━━━━━━━━━━━━━━━━━━━━ 79s 24ms/step - loss: 0.0172 - mean_absolute_error: 0.0949 - mean_squared_error: 0.0172 - mse_x: 0.0263 - mse_y: 0.0207 - mse_z: 0.0045 - root_mean_squared_error: 0.1310 - val_loss: 0.0202 - val_mean_absolute_error: 0.1040 - val_mean_squared_error: 0.0202 - val_mse_x: 0.0348 - val_mse_y: 0.0189 - val_mse_z: 0.0070 - val_root_mean_squared_error: 0.1423
# Epoch 6/50
# 3295/3295 ━━━━━━━━━━━━━━━━━━━━ 79s 24ms/step - loss: 0.0169 - mean_absolute_error: 0.0935 - mean_squared_error: 0.0169 - mse_x: 0.0260 - mse_y: 0.0207 - mse_z: 0.0041 - root_mean_squared_error: 0.1301 - val_loss: 0.0211 - val_mean_absolute_error: 0.1055 - val_mean_squared_error: 0.0211 - val_mse_x: 0.0367 - val_mse_y: 0.0191 - val_mse_z: 0.0073 - val_root_mean_squared_error: 0.1451
# Epoch 7/50
# 3295/3295 ━━━━━━━━━━━━━━━━━━━━ 79s 24ms/step - loss: 0.0168 - mean_absolute_error: 0.0926 - mean_squared_error: 0.0168 - mse_x: 0.0258 - mse_y: 0.0206 - mse_z: 0.0039 - root_mean_squared_error: 0.1294 - val_loss: 0.0212 - val_mean_absolute_error: 0.1032 - val_mean_squared_error: 0.0212 - val_mse_x: 0.0393 - val_mse_y: 0.0189 - val_mse_z: 0.0053 - val_root_mean_squared_error: 0.1455
# Epoch 7: early stopping
# Modelo do split 2 salvo em models_GY87/lstm_split_2.keras
# Split 3:
# X_train shape: (592984, 80, 3), y_train shape: (592984, 3)
# X_test shape: (197608, 80, 3), y_test shape: (197608, 3)
# Treinando o modelo para o split 3...
# Epoch 1/50
# 4942/4942 ━━━━━━━━━━━━━━━━━━━━ 114s 23ms/step - loss: 0.0232 - mean_absolute_error: 0.1117 - mean_squared_error: 0.0232 - mse_x: 0.0417 - mse_y: 0.0211 - mse_z: 0.0068 - root_mean_squared_error: 0.1521 - val_loss: 0.0198 - val_mean_absolute_error: 0.1017 - val_mean_squared_error: 0.0198 - val_mse_x: 0.0340 - val_mse_y: 0.0204 - val_mse_z: 0.0049 - val_root_mean_squared_error: 0.1405
# Epoch 2/50
# 4942/4942 ━━━━━━━━━━━━━━━━━━━━ 112s 23ms/step - loss: 0.0182 - mean_absolute_error: 0.0979 - mean_squared_error: 0.0182 - mse_x: 0.0295 - mse_y: 0.0205 - mse_z: 0.0047 - root_mean_squared_error: 0.1350 - val_loss: 0.0185 - val_mean_absolute_error: 0.0984 - val_mean_squared_error: 0.0185 - val_mse_x: 0.0312 - val_mse_y: 0.0197 - val_mse_z: 0.0047 - val_root_mean_squared_error: 0.1361
# Epoch 3/50
# 4942/4942 ━━━━━━━━━━━━━━━━━━━━ 112s 23ms/step - loss: 0.0176 - mean_absolute_error: 0.0962 - mean_squared_error: 0.0176 - mse_x: 0.0280 - mse_y: 0.0202 - mse_z: 0.0046 - root_mean_squared_error: 0.1327 - val_loss: 0.0184 - val_mean_absolute_error: 0.0986 - val_mean_squared_error: 0.0184 - val_mse_x: 0.0306 - val_mse_y: 0.0197 - val_mse_z: 0.0050 - val_root_mean_squared_error: 0.1357
# Epoch 4/50
# 4942/4942 ━━━━━━━━━━━━━━━━━━━━ 113s 23ms/step - loss: 0.0173 - mean_absolute_error: 0.0952 - mean_squared_error: 0.0173 - mse_x: 0.0274 - mse_y: 0.0201 - mse_z: 0.0045 - root_mean_squared_error: 0.1316 - val_loss: 0.0182 - val_mean_absolute_error: 0.0971 - val_mean_squared_error: 0.0182 - val_mse_x: 0.0304 - val_mse_y: 0.0195 - val_mse_z: 0.0047 - val_root_mean_squared_error: 0.1349
# Epoch 5/50
# 4942/4942 ━━━━━━━━━━━━━━━━━━━━ 113s 23ms/step - loss: 0.0170 - mean_absolute_error: 0.0936 - mean_squared_error: 0.0170 - mse_x: 0.0270 - mse_y: 0.0200 - mse_z: 0.0041 - root_mean_squared_error: 0.1305 - val_loss: 0.0179 - val_mean_absolute_error: 0.0952 - val_mean_squared_error: 0.0179 - val_mse_x: 0.0298 - val_mse_y: 0.0199 - val_mse_z: 0.0040 - val_root_mean_squared_error: 0.1339
# Epoch 6/50
# 4942/4942 ━━━━━━━━━━━━━━━━━━━━ 113s 23ms/step - loss: 0.0169 - mean_absolute_error: 0.0925 - mean_squared_error: 0.0169 - mse_x: 0.0267 - mse_y: 0.0200 - mse_z: 0.0039 - root_mean_squared_error: 0.1298 - val_loss: 0.0177 - val_mean_absolute_error: 0.0947 - val_mean_squared_error: 0.0177 - val_mse_x: 0.0297 - val_mse_y: 0.0192 - val_mse_z: 0.0041 - val_root_mean_squared_error: 0.1329
# Epoch 7/50
# 4942/4942 ━━━━━━━━━━━━━━━━━━━━ 114s 23ms/step - loss: 0.0167 - mean_absolute_error: 0.0918 - mean_squared_error: 0.0167 - mse_x: 0.0266 - mse_y: 0.0199 - mse_z: 0.0037 - root_mean_squared_error: 0.1293 - val_loss: 0.0173 - val_mean_absolute_error: 0.0930 - val_mean_squared_error: 0.0173 - val_mse_x: 0.0292 - val_mse_y: 0.0188 - val_mse_z: 0.0040 - val_root_mean_squared_error: 0.1316
# Epoch 8/50
# 4942/4942 ━━━━━━━━━━━━━━━━━━━━ 114s 23ms/step - loss: 0.0165 - mean_absolute_error: 0.0907 - mean_squared_error: 0.0165 - mse_x: 0.0262 - mse_y: 0.0199 - mse_z: 0.0035 - root_mean_squared_error: 0.1286 - val_loss: 0.0173 - val_mean_absolute_error: 0.0926 - val_mean_squared_error: 0.0173 - val_mse_x: 0.0292 - val_mse_y: 0.0190 - val_mse_z: 0.0037 - val_root_mean_squared_error: 0.1316
# Epoch 9/50
# 4942/4942 ━━━━━━━━━━━━━━━━━━━━ 114s 23ms/step - loss: 0.0164 - mean_absolute_error: 0.0901 - mean_squared_error: 0.0164 - mse_x: 0.0259 - mse_y: 0.0198 - mse_z: 0.0034 - root_mean_squared_error: 0.1280 - val_loss: 0.0176 - val_mean_absolute_error: 0.0933 - val_mean_squared_error: 0.0176 - val_mse_x: 0.0290 - val_mse_y: 0.0199 - val_mse_z: 0.0038 - val_root_mean_squared_error: 0.1325
# Epoch 10/50
# 4942/4942 ━━━━━━━━━━━━━━━━━━━━ 114s 23ms/step - loss: 0.0163 - mean_absolute_error: 0.0897 - mean_squared_error: 0.0163 - mse_x: 0.0257 - mse_y: 0.0199 - mse_z: 0.0033 - root_mean_squared_error: 0.1276 - val_loss: 0.0175 - val_mean_absolute_error: 0.0932 - val_mean_squared_error: 0.0175 - val_mse_x: 0.0288 - val_mse_y: 0.0196 - val_mse_z: 0.0042 - val_root_mean_squared_error: 0.1324
# Epoch 11/50
# 4942/4942 ━━━━━━━━━━━━━━━━━━━━ 118s 24ms/step - loss: 0.0162 - mean_absolute_error: 0.0896 - mean_squared_error: 0.0162 - mse_x: 0.0256 - mse_y: 0.0198 - mse_z: 0.0033 - root_mean_squared_error: 0.1274 - val_loss: 0.0173 - val_mean_absolute_error: 0.0925 - val_mean_squared_error: 0.0173 - val_mse_x: 0.0285 - val_mse_y: 0.0197 - val_mse_z: 0.0037 - val_root_mean_squared_error: 0.1315
# Epoch 12/50
# 4942/4942 ━━━━━━━━━━━━━━━━━━━━ 123s 25ms/step - loss: 0.0161 - mean_absolute_error: 0.0891 - mean_squared_error: 0.0161 - mse_x: 0.0253 - mse_y: 0.0198 - mse_z: 0.0032 - root_mean_squared_error: 0.1269 - val_loss: 0.0171 - val_mean_absolute_error: 0.0919 - val_mean_squared_error: 0.0171 - val_mse_x: 0.0288 - val_mse_y: 0.0190 - val_mse_z: 0.0036 - val_root_mean_squared_error: 0.1309
# Epoch 13/50
# 4942/4942 ━━━━━━━━━━━━━━━━━━━━ 123s 25ms/step - loss: 0.0160 - mean_absolute_error: 0.0890 - mean_squared_error: 0.0160 - mse_x: 0.0252 - mse_y: 0.0197 - mse_z: 0.0032 - root_mean_squared_error: 0.1266 - val_loss: 0.0172 - val_mean_absolute_error: 0.0916 - val_mean_squared_error: 0.0172 - val_mse_x: 0.0288 - val_mse_y: 0.0192 - val_mse_z: 0.0036 - val_root_mean_squared_error: 0.1311
# Epoch 14/50
# 4942/4942 ━━━━━━━━━━━━━━━━━━━━ 124s 25ms/step - loss: 0.0160 - mean_absolute_error: 0.0888 - mean_squared_error: 0.0160 - mse_x: 0.0250 - mse_y: 0.0197 - mse_z: 0.0032 - root_mean_squared_error: 0.1263 - val_loss: 0.0171 - val_mean_absolute_error: 0.0916 - val_mean_squared_error: 0.0171 - val_mse_x: 0.0288 - val_mse_y: 0.0187 - val_mse_z: 0.0036 - val_root_mean_squared_error: 0.1306
# Epoch 15/50
# 4942/4942 ━━━━━━━━━━━━━━━━━━━━ 125s 25ms/step - loss: 0.0159 - mean_absolute_error: 0.0887 - mean_squared_error: 0.0159 - mse_x: 0.0249 - mse_y: 0.0197 - mse_z: 0.0032 - root_mean_squared_error: 0.1262 - val_loss: 0.0175 - val_mean_absolute_error: 0.0922 - val_mean_squared_error: 0.0175 - val_mse_x: 0.0297 - val_mse_y: 0.0189 - val_mse_z: 0.0038 - val_root_mean_squared_error: 0.1321
# Epoch 16/50
# 4942/4942 ━━━━━━━━━━━━━━━━━━━━ 124s 25ms/step - loss: 0.0158 - mean_absolute_error: 0.0883 - mean_squared_error: 0.0158 - mse_x: 0.0246 - mse_y: 0.0197 - mse_z: 0.0032 - root_mean_squared_error: 0.1257 - val_loss: 0.0174 - val_mean_absolute_error: 0.0923 - val_mean_squared_error: 0.0174 - val_mse_x: 0.0291 - val_mse_y: 0.0194 - val_mse_z: 0.0036 - val_root_mean_squared_error: 0.1318
# Epoch 17/50
# 4942/4942 ━━━━━━━━━━━━━━━━━━━━ 125s 25ms/step - loss: 0.0157 - mean_absolute_error: 0.0880 - mean_squared_error: 0.0157 - mse_x: 0.0242 - mse_y: 0.0196 - mse_z: 0.0032 - root_mean_squared_error: 0.1251 - val_loss: 0.0174 - val_mean_absolute_error: 0.0925 - val_mean_squared_error: 0.0174 - val_mse_x: 0.0292 - val_mse_y: 0.0194 - val_mse_z: 0.0037 - val_root_mean_squared_error: 0.1321
# Epoch 18/50
# 4942/4942 ━━━━━━━━━━━━━━━━━━━━ 125s 25ms/step - loss: 0.0156 - mean_absolute_error: 0.0880 - mean_squared_error: 0.0156 - mse_x: 0.0241 - mse_y: 0.0196 - mse_z: 0.0032 - root_mean_squared_error: 0.1249 - val_loss: 0.0175 - val_mean_absolute_error: 0.0927 - val_mean_squared_error: 0.0175 - val_mse_x: 0.0295 - val_mse_y: 0.0194 - val_mse_z: 0.0037 - val_root_mean_squared_error: 0.1324
# Epoch 19/50
# 4942/4942 ━━━━━━━━━━━━━━━━━━━━ 126s 25ms/step - loss: 0.0155 - mean_absolute_error: 0.0876 - mean_squared_error: 0.0155 - mse_x: 0.0238 - mse_y: 0.0195 - mse_z: 0.0031 - root_mean_squared_error: 0.1244 - val_loss: 0.0175 - val_mean_absolute_error: 0.0922 - val_mean_squared_error: 0.0175 - val_mse_x: 0.0297 - val_mse_y: 0.0191 - val_mse_z: 0.0036 - val_root_mean_squared_error: 0.1321
# Epoch 19: early stopping
# Modelo do split 3 salvo em models_GY87/lstm_split_3.keras
# Split 4:
# X_train shape: (790672, 80, 3), y_train shape: (790672, 3)
# X_test shape: (197608, 80, 3), y_test shape: (197608, 3)
# Treinando o modelo para o split 4...
# Epoch 1/50
# 6589/6589 ━━━━━━━━━━━━━━━━━━━━ 174s 26ms/step - loss: 0.0226 - mean_absolute_error: 0.1100 - mean_squared_error: 0.0226 - mse_x: 0.0407 - mse_y: 0.0207 - mse_z: 0.0065 - root_mean_squared_error: 0.1501 - val_loss: 0.0189 - val_mean_absolute_error: 0.0997 - val_mean_squared_error: 0.0189 - val_mse_x: 0.0324 - val_mse_y: 0.0196 - val_mse_z: 0.0047 - val_root_mean_squared_error: 0.1375
# Epoch 2/50
# 6589/6589 ━━━━━━━━━━━━━━━━━━━━ 206s 31ms/step - loss: 0.0180 - mean_absolute_error: 0.0972 - mean_squared_error: 0.0180 - mse_x: 0.0293 - mse_y: 0.0200 - mse_z: 0.0047 - root_mean_squared_error: 0.1342 - val_loss: 0.0184 - val_mean_absolute_error: 0.0980 - val_mean_squared_error: 0.0184 - val_mse_x: 0.0313 - val_mse_y: 0.0191 - val_mse_z: 0.0048 - val_root_mean_squared_error: 0.1355
# Epoch 3/50
# 6589/6589 ━━━━━━━━━━━━━━━━━━━━ 214s 32ms/step - loss: 0.0175 - mean_absolute_error: 0.0957 - mean_squared_error: 0.0175 - mse_x: 0.0281 - mse_y: 0.0199 - mse_z: 0.0046 - root_mean_squared_error: 0.1323 - val_loss: 0.0179 - val_mean_absolute_error: 0.0961 - val_mean_squared_error: 0.0179 - val_mse_x: 0.0304 - val_mse_y: 0.0189 - val_mse_z: 0.0044 - val_root_mean_squared_error: 0.1339
# Epoch 4/50
# 6589/6589 ━━━━━━━━━━━━━━━━━━━━ 216s 33ms/step - loss: 0.0171 - mean_absolute_error: 0.0936 - mean_squared_error: 0.0171 - mse_x: 0.0274 - mse_y: 0.0197 - mse_z: 0.0041 - root_mean_squared_error: 0.1307 - val_loss: 0.0180 - val_mean_absolute_error: 0.0953 - val_mean_squared_error: 0.0180 - val_mse_x: 0.0301 - val_mse_y: 0.0197 - val_mse_z: 0.0041 - val_root_mean_squared_error: 0.1340
# Epoch 5/50
# 6589/6589 ━━━━━━━━━━━━━━━━━━━━ 217s 33ms/step - loss: 0.0168 - mean_absolute_error: 0.0922 - mean_squared_error: 0.0168 - mse_x: 0.0271 - mse_y: 0.0196 - mse_z: 0.0038 - root_mean_squared_error: 0.1297 - val_loss: 0.0176 - val_mean_absolute_error: 0.0936 - val_mean_squared_error: 0.0176 - val_mse_x: 0.0298 - val_mse_y: 0.0191 - val_mse_z: 0.0039 - val_root_mean_squared_error: 0.1327
# Epoch 6/50
# 6589/6589 ━━━━━━━━━━━━━━━━━━━━ 220s 33ms/step - loss: 0.0166 - mean_absolute_error: 0.0908 - mean_squared_error: 0.0166 - mse_x: 0.0267 - mse_y: 0.0196 - mse_z: 0.0035 - root_mean_squared_error: 0.1288 - val_loss: 0.0173 - val_mean_absolute_error: 0.0928 - val_mean_squared_error: 0.0173 - val_mse_x: 0.0291 - val_mse_y: 0.0190 - val_mse_z: 0.0038 - val_root_mean_squared_error: 0.1314
# Epoch 7/50
# 6589/6589 ━━━━━━━━━━━━━━━━━━━━ 224s 34ms/step - loss: 0.0165 - mean_absolute_error: 0.0903 - mean_squared_error: 0.0165 - mse_x: 0.0264 - mse_y: 0.0195 - mse_z: 0.0034 - root_mean_squared_error: 0.1283 - val_loss: 0.0173 - val_mean_absolute_error: 0.0926 - val_mean_squared_error: 0.0173 - val_mse_x: 0.0289 - val_mse_y: 0.0192 - val_mse_z: 0.0038 - val_root_mean_squared_error: 0.1316
# Epoch 8/50
# 6589/6589 ━━━━━━━━━━━━━━━━━━━━ 291s 44ms/step - loss: 0.0164 - mean_absolute_error: 0.0900 - mean_squared_error: 0.0164 - mse_x: 0.0262 - mse_y: 0.0195 - mse_z: 0.0034 - root_mean_squared_error: 0.1280 - val_loss: 0.0175 - val_mean_absolute_error: 0.0928 - val_mean_squared_error: 0.0175 - val_mse_x: 0.0298 - val_mse_y: 0.0189 - val_mse_z: 0.0037 - val_root_mean_squared_error: 0.1322
# Epoch 9/50
# 6589/6589 ━━━━━━━━━━━━━━━━━━━━ 373s 57ms/step - loss: 0.0163 - mean_absolute_error: 0.0897 - mean_squared_error: 0.0163 - mse_x: 0.0262 - mse_y: 0.0195 - mse_z: 0.0033 - root_mean_squared_error: 0.1278 - val_loss: 0.0172 - val_mean_absolute_error: 0.0922 - val_mean_squared_error: 0.0172 - val_mse_x: 0.0290 - val_mse_y: 0.0190 - val_mse_z: 0.0037 - val_root_mean_squared_error: 0.1311
# Epoch 10/50
# 6589/6589 ━━━━━━━━━━━━━━━━━━━━ 408s 62ms/step - loss: 0.0162 - mean_absolute_error: 0.0893 - mean_squared_error: 0.0162 - mse_x: 0.0258 - mse_y: 0.0195 - mse_z: 0.0033 - root_mean_squared_error: 0.1272 - val_loss: 0.0173 - val_mean_absolute_error: 0.0920 - val_mean_squared_error: 0.0173 - val_mse_x: 0.0289 - val_mse_y: 0.0194 - val_mse_z: 0.0037 - val_root_mean_squared_error: 0.1316
# Epoch 11/50
# 6589/6589 ━━━━━━━━━━━━━━━━━━━━ 436s 66ms/step - loss: 0.0161 - mean_absolute_error: 0.0890 - mean_squared_error: 0.0161 - mse_x: 0.0257 - mse_y: 0.0194 - mse_z: 0.0033 - root_mean_squared_error: 0.1269 - val_loss: 0.0172 - val_mean_absolute_error: 0.0916 - val_mean_squared_error: 0.0172 - val_mse_x: 0.0286 - val_mse_y: 0.0194 - val_mse_z: 0.0035 - val_root_mean_squared_error: 0.1311
# Epoch 12/50
# 6589/6589 ━━━━━━━━━━━━━━━━━━━━ 453s 69ms/step - loss: 0.0160 - mean_absolute_error: 0.0886 - mean_squared_error: 0.0160 - mse_x: 0.0254 - mse_y: 0.0194 - mse_z: 0.0032 - root_mean_squared_error: 0.1264 - val_loss: 0.0171 - val_mean_absolute_error: 0.0914 - val_mean_squared_error: 0.0171 - val_mse_x: 0.0285 - val_mse_y: 0.0191 - val_mse_z: 0.0035 - val_root_mean_squared_error: 0.1306
# Epoch 13/50
# 6589/6589 ━━━━━━━━━━━━━━━━━━━━ 474s 72ms/step - loss: 0.0159 - mean_absolute_error: 0.0886 - mean_squared_error: 0.0159 - mse_x: 0.0252 - mse_y: 0.0194 - mse_z: 0.0032 - root_mean_squared_error: 0.1263 - val_loss: 0.0171 - val_mean_absolute_error: 0.0915 - val_mean_squared_error: 0.0171 - val_mse_x: 0.0288 - val_mse_y: 0.0189 - val_mse_z: 0.0036 - val_root_mean_squared_error: 0.1308
# Epoch 14/50
# 6589/6589 ━━━━━━━━━━━━━━━━━━━━ 491s 75ms/step - loss: 0.0159 - mean_absolute_error: 0.0884 - mean_squared_error: 0.0159 - mse_x: 0.0251 - mse_y: 0.0194 - mse_z: 0.0032 - root_mean_squared_error: 0.1261 - val_loss: 0.0172 - val_mean_absolute_error: 0.0916 - val_mean_squared_error: 0.0172 - val_mse_x: 0.0289 - val_mse_y: 0.0192 - val_mse_z: 0.0035 - val_root_mean_squared_error: 0.1311
# Epoch 15/50
# 6589/6589 ━━━━━━━━━━━━━━━━━━━━ 500s 76ms/step - loss: 0.0158 - mean_absolute_error: 0.0882 - mean_squared_error: 0.0158 - mse_x: 0.0249 - mse_y: 0.0193 - mse_z: 0.0032 - root_mean_squared_error: 0.1257 - val_loss: 0.0171 - val_mean_absolute_error: 0.0917 - val_mean_squared_error: 0.0171 - val_mse_x: 0.0290 - val_mse_y: 0.0189 - val_mse_z: 0.0036 - val_root_mean_squared_error: 0.1309
# Epoch 16/50
# 6589/6589 ━━━━━━━━━━━━━━━━━━━━ 518s 79ms/step - loss: 0.0157 - mean_absolute_error: 0.0879 - mean_squared_error: 0.0157 - mse_x: 0.0247 - mse_y: 0.0193 - mse_z: 0.0032 - root_mean_squared_error: 0.1253 - val_loss: 0.0171 - val_mean_absolute_error: 0.0912 - val_mean_squared_error: 0.0171 - val_mse_x: 0.0290 - val_mse_y: 0.0188 - val_mse_z: 0.0036 - val_root_mean_squared_error: 0.1309
# Epoch 17/50
# 6589/6589 ━━━━━━━━━━━━━━━━━━━━ 532s 81ms/step - loss: 0.0157 - mean_absolute_error: 0.0878 - mean_squared_error: 0.0157 - mse_x: 0.0246 - mse_y: 0.0192 - mse_z: 0.0032 - root_mean_squared_error: 0.1251 - val_loss: 0.0172 - val_mean_absolute_error: 0.0917 - val_mean_squared_error: 0.0172 - val_mse_x: 0.0289 - val_mse_y: 0.0192 - val_mse_z: 0.0035 - val_root_mean_squared_error: 0.1312
# Epoch 17: early stopping
# Modelo do split 4 salvo em models_GY87/lstm_split_4.keras

# %% [markdown]
# ### Salvar o Histórico do Treinamento (history.json)

# %%
import json

# Criar uma pasta para salvar os modelos
model_folder = "models_GY87"
config_path = os.path.join(model_folder, "history.json")
# Salvar o histórico do treinamento em um arquivo JSON
with open(config_path, "w") as f:
    json.dump(history.history, f)

# %% [markdown]
# ### Carregar o Histórico (history.json)

# %%
import json

model_folder = "models_GY87"
config_path = os.path.join(model_folder, "history.json")
# Carregar o histórico salvo
with open(config_path, "r") as f:
    loaded_history = json.load(f)

# Exemplo de acesso aos dados carregados
print("Chaves do histórico:", loaded_history.keys())
print("Perda final:", loaded_history["loss"][-1])
print("Validação final:", loaded_history["val_loss"][-1])
# Out:
# Chaves do histórico: dict_keys(['loss', 'mean_absolute_error', 'mean_squared_error', 'mse_x', 'mse_y', 'mse_z', 'root_mean_squared_error', 'val_loss', 'val_mean_absolute_error', 'val_mean_squared_error', 'val_mse_x', 'val_mse_y', 'val_mse_z', 'val_root_mean_squared_error'])
# Perda final: 0.01568184234201908
# Validação final: 0.01721033826470375

# %% [markdown]
# ### Visualizar o Histórico de Treinamento

# %%
import matplotlib.pyplot as plt

# Plotando a perda de treino e validação
plt.figure(figsize=(10,1))
plt.plot(loaded_history["loss"], label="loss")
plt.plot(loaded_history["val_loss"], label="val_loss")
plt.xlabel("Épocas")
plt.ylabel("Perda (Loss)")
plt.title("Evolução da Perda durante o Treinamento")
plt.legend()
plt.show()

# %% [markdown]
# # Avaliar o Modelo ******************************
# #### Após o treinamento de cada split, é avaliado o desempenho do modelo no conjunto de teste.

# %%
import sys
import os
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import load_model
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import TimeSeriesSplit
from sklearn.preprocessing import MinMaxScaler
import pickle

# Função para criar sequências
def create_sequences(data, n_timesteps):
    X, y = [], []
    for i in range(len(data) - n_timesteps):
        X.append(data[i:(i + n_timesteps)])
        y.append(data[i + n_timesteps])
    return np.array(X), np.array(y)

# Classe Tee para duplicar a saída (console e arquivo)
class Tee:
    def __init__(self, *files):
        self.files = files
        self.encoding = getattr(files[0], 'encoding', 'utf-8')
    def write(self, obj):
        for f in self.files:
            f.write(obj)
    def flush(self):
        for f in self.files:
            f.flush()

# Carregar dados e scaler
# print("Carregando dados...")
# file_path = './Dados/dados.txt'
# df = pd.read_csv(file_path, header=None, names=['X', 'Y', 'Z'])
# df = df[1300:1001300]

# Carregar o scaler
# with open('scaler.pkl', 'rb') as f:
#     scaler = pickle.load(f)

# Diretório onde salvar os resultados
model_folder = "models_GY87"
os.makedirs(model_folder, exist_ok=True)

# Arquivo de log para salvar o output com a mesma estrutura
log_path = os.path.join(model_folder, "evaluation.log")

# Abrir o arquivo com encoding 'utf-8' para evitar erros de caracteres
with open(log_path, "w", encoding="utf-8") as log_file:
    # Redireciona a saída padrão para imprimir tanto no console quanto no arquivo
    original_stdout = sys.stdout
    sys.stdout = Tee(original_stdout, log_file)
    
    print("Iniciando avaliação dos modelos...")
    
    # Inicializar lista para métricas
    results = []
    
    # Avaliar os modelos salvos
    for split_idx, (train_index, test_index) in enumerate(tscv.split(df_scaled.values), start=1):
        print(f"\n=== Avaliando Split {split_idx} ===")
        
        # Carregar o modelo salvo
        model_path = os.path.join(model_folder, f"lstm_split_{split_idx}.keras")
        
        if not os.path.exists(model_path):
            print(f"Modelo {model_path} não encontrado. Pulando...")
            continue
            
        try:
            model = load_model(model_path, custom_objects={
                "weighted_mse": weighted_mse,
                "mse_x": mse_x,
                "mse_y": mse_y,
                "mse_z": mse_z
            })
            print(f"Modelo carregado: {model_path}")
        except Exception as e:
            print(f"Erro ao carregar modelo {model_path}: {e}")
            continue
        
        # Criar os dados de teste
        test_data = df_scaled.values[test_index]
        X_test, y_test = create_sequences(test_data, n_timesteps)
        
        print(f"Dados de teste - X_test shape: {X_test.shape}, y_test shape: {y_test.shape}")
        
        # Validar shapes dos dados
        assert X_test.shape[0] == y_test.shape[0], "Número de exemplos em X_test e y_test não coincidem!"
        assert X_test.shape[1] == n_timesteps, "Número de timesteps em X_test está incorreto!"
        assert X_test.shape[2] == n_features, "Número de features em X_test está incorreto!"
        
        # Temporariamente restaura a saída padrão para evitar que o progress bar seja capturado no log
        temp_stdout = sys.stdout
        sys.stdout = original_stdout
        
        print(f"Fazendo predições para o split {split_idx}...")
        # Fazer previsões (verbose=1 para exibir o progress bar no console)
        y_pred = model.predict(X_test, verbose=1)
        
        # Após a predição, volta a redirecionar a saída para o nosso Tee
        sys.stdout = temp_stdout
        
        print(f"Predições concluídas - shape: {y_pred.shape}")
        
        # Cálculo das métricas
        mse_total = mean_squared_error(y_test, y_pred)
        r2_total = r2_score(y_test, y_pred)
        mse_x_val = mean_squared_error(y_test[:, 0], y_pred[:, 0])
        r2_x = r2_score(y_test[:, 0], y_pred[:, 0])
        mse_y_val = mean_squared_error(y_test[:, 1], y_pred[:, 1])
        r2_y = r2_score(y_test[:, 1], y_pred[:, 1])
        mse_z_val = mean_squared_error(y_test[:, 2], y_pred[:, 2])
        r2_z = r2_score(y_test[:, 2], y_pred[:, 2])
        
        # Salvando métricas
        results.append({
            'split': split_idx,
            'mse_total': mse_total, 'r2_total': r2_total,
            'mse_x': mse_x_val, 'r2_x': r2_x,
            'mse_y': mse_y_val, 'r2_y': r2_y,
            'mse_z': mse_z_val, 'r2_z': r2_z
        })
        
        # Imprimir output no formato desejado (sem os updates do progress bar)
        print(f"Split {split_idx} - MSE Total: {mse_total:.6f}, R² Total: {r2_total:.6f}")
        print(f"Split {split_idx} - MSE X: {mse_x_val:.6f}, R² X: {r2_x:.6f}")
        print(f"Split {split_idx} - MSE Y: {mse_y_val:.6f}, R² Y: {r2_y:.6f}")
        print(f"Split {split_idx} - MSE Z: {mse_z_val:.6f}, R² Z: {r2_z:.6f}")
    
    # Consolidar os resultados em um DataFrame
    if results:
        df_results = pd.DataFrame(results)
        
        # Salvar os resultados em CSV
        csv_path = os.path.join(model_folder, "evaluation_results.csv")
        df_results.to_csv(csv_path, index=False)
        print(f"\nResultados salvos em {csv_path}")
        
        # Calcular e exibir estatísticas resumidas
        print("\n=== RESUMO DOS RESULTADOS ===")
        print("Médias das métricas:")
        for col in df_results.columns:
            if col != 'split':
                print(f"{col}: {df_results[col].mean():.6f} ± {df_results[col].std():.6f}")
    else:
        print("Nenhum modelo foi avaliado com sucesso.")
    
    # Restaurar a saída padrão
    sys.stdout = original_stdout

print("Avaliação concluída!")
# Out:
# Iniciando avaliação dos modelos...
#
# === Avaliando Split 1 ===
# Modelo carregado: models_GY87/lstm_split_1.keras
# Dados de teste - X_test shape: (197608, 80, 3), y_test shape: (197608, 3)
# Fazendo predições para o split 1...
# 6176/6176 ━━━━━━━━━━━━━━━━━━━━ 23s 4ms/step
# Predições concluídas - shape: (197608, 3)
# Split 1 - MSE Total: 0.018596, R² Total: 0.431821
# Split 1 - MSE X: 0.030402, R² X: 0.427724
# Split 1 - MSE Y: 0.021506, R² Y: 0.103871
# Split 1 - MSE Z: 0.003880, R² Z: 0.763868
#
# === Avaliando Split 2 ===
# Modelo carregado: models_GY87/lstm_split_2.keras
# Dados de teste - X_test shape: (197608, 80, 3), y_test shape: (197608, 3)
# Fazendo predições para o split 2...
# 6176/6176 ━━━━━━━━━━━━━━━━━━━━ 22s 4ms/step
# Predições concluídas - shape: (197608, 3)
# Split 2 - MSE Total: 0.021174, R² Total: 0.349994
# Split 2 - MSE X: 0.039258, R² X: 0.252772
# Split 2 - MSE Y: 0.018934, R² Y: 0.120443
# Split 2 - MSE Z: 0.005331, R² Z: 0.676766
#
# === Avaliando Split 3 ===
# Modelo carregado: models_GY87/lstm_split_3.keras
# Dados de teste - X_test shape: (197608, 80, 3), y_test shape: (197608, 3)
# Fazendo predições para o split 3...
# 6176/6176 ━━━━━━━━━━━━━━━━━━━━ 22s 4ms/step
# Predições concluídas - shape: (197608, 3)
# Split 3 - MSE Total: 0.017457, R² Total: 0.427810
# Split 3 - MSE X: 0.029672, R² X: 0.432827
# Split 3 - MSE Y: 0.019089, R² Y: 0.109692
# Split 3 - MSE Z: 0.003611, R² Z: 0.740912
#
# === Avaliando Split 4 ===
# Modelo carregado: models_GY87/lstm_split_4.keras
# Dados de teste - X_test shape: (197608, 80, 3), y_test shape: (197608, 3)
# Fazendo predições para o split 4...
# 6176/6176 ━━━━━━━━━━━━━━━━━━━━ 23s 4ms/step
# Predições concluídas - shape: (197608, 3)
# Split 4 - MSE Total: 0.017210, R² Total: 0.435802
# Split 4 - MSE X: 0.028921, R² X: 0.448410
# Split 4 - MSE Y: 0.019168, R² Y: 0.107382
# Split 4 - MSE Z: 0.003542, R² Z: 0.751616
#
# Resultados salvos em models_GY87/evaluation_results.csv
#
# === RESUMO DOS RESULTADOS ===
# Médias das métricas:
# mse_total: 0.018610 ± 0.001813
# r2_total: 0.411357 ± 0.041039
# mse_x: 0.032063 ± 0.004834
# r2_x: 0.390433 ± 0.092195
# mse_y: 0.019674 ± 0.001225
# r2_y: 0.110347 ± 0.007144
# mse_z: 0.004091 ± 0.000839
# r2_z: 0.733291 ± 0.038833
# Avaliação concluída!

# %% [markdown]
# # Carregando o modelo desejado pelo split

# %%
import os
import tensorflow as tf
from tensorflow.keras.models import load_model
from tensorflow.keras import backend as K

# Definindo o diretório onde o modelo está salvo
model_folder = "models_GY87"
model_path = os.path.join(model_folder, 'lstm_split_3.keras')

# Carregando o modelo com todas as funções customizadas
modelo_carregado = load_model(
    model_path, 
    custom_objects={
        "weighted_mse": weighted_mse,
        "mse_x": mse_x,
        "mse_y": mse_y,
        "mse_z": mse_z
    }
)

print(modelo_carregado.summary())
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 500)            │     1,008,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 3)              │         1,503 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,028,512 (11.55 MB)
#  Trainable params: 1,009,503 (3.85 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 2,019,009 (7.70 MB)
# None

# %% [markdown]
# Fazendo previsões

# %%
predicted = modelo_carregado.predict(X_test)
# predicted = y_pred
# Out:
# 3681/6176 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step
# 6176/6176 ━━━━━━━━━━━━━━━━━━━━ 23s 4ms/step

# %% [markdown]
# Plotando os Resultados

# %%
epochs = range(1, len(history.history['loss']) + 1)

plt.plot(epochs, history.history['loss'], label='Train Loss')
plt.plot(epochs, history.history['val_loss'], label='Validation Loss')
plt.plot(epochs, history.history['mean_squared_error'], label='MSE')
plt.plot(epochs, history.history['mean_absolute_error'], label='MAE')
plt.plot(epochs, history.history['root_mean_squared_error'], label='RMSE')
plt.title('Training and Validation Metrics')
plt.xlabel('Epochs')
plt.ylabel('Value')
plt.legend()
plt.show()

# %%
# Definindo as dimensões
dims = ['X', 'Y', 'Z']

plt.figure(figsize=(15, 15))

# Criando um gráfico para cada dimensão
for i, dim in enumerate(dims):
    plt.subplot(3, 1, i+1)
    plt.plot(X_test[:, -1, i], label='Real')
    plt.plot(predicted[:, i], label='Previsto')
    plt.title(f'Comparação {dim}')
    plt.xlabel('Tempo')
    plt.ylabel(f'Valor {dim}')
    plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Plotando desnormalizado

# %%
dims = ['X', 'Y', 'Z']

plt.figure(figsize=(15, 15))

for i, dim in enumerate(dims):
    plt.subplot(3, 1, i+1)

    # Desnormalizando os valores reais e previstos
    real_denorm = scalers_tuple[dim].inverse_transform(X_test[:, -1, i].reshape(-1, 1)).flatten()
    pred_denorm = scalers_tuple[dim].inverse_transform(predicted[:, i].reshape(-1, 1)).flatten()

    plt.plot(real_denorm, label='Real')
    plt.plot(pred_denorm, label='Previsto')
    plt.title(f'Comparação {dim}')
    plt.xlabel('Tempo')
    plt.ylabel(f'Valor {dim}')
    plt.legend()
    plt.ylim(-5, 26)

plt.tight_layout()
plt.show()

# %%
# Criando a figura
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

# Plotando os valores reais
ax.scatter(X_test[:, -1, 0], X_test[:, -1, 1], X_test[:, -1, 2], color='blue', label='Real')

# Plotando os valores previstos
ax.scatter(predicted[:, 0], predicted[:, 1], predicted[:, 2], color='red', label='Previsto')

ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
plt.title('Comparação 3D entre Valores Reais e Previstos')
plt.legend()
plt.show()

# %% [markdown]
# ## Mean Squared Error e $R^2$

# %%
mse = mean_squared_error(y_test, predicted)
r2 = r2_score(y_test, predicted)

MSE_R2 = {
    "MSE: ":mse,
    "R2: ": r2
}
# Salvar os hiperparâmetros em um arquivo JSON
model_folder = "models_GY87"
config_path = os.path.join(model_folder, "1.Mean Squared Error e R2.Teste.json")
with open(config_path, "w") as f:
    json.dump(MSE_R2, f, indent=4)

print(f"Hiperparâmetros salvos em {config_path}")

print("MSE:", mse)
print("R²:", r2)
# Out:
# Hiperparâmetros salvos em models_GY87/1.Mean Squared Error e R2.Teste.json
# MSE: 0.018429481401070074
# R²: 0.3967287391401347

# %% [markdown]
# # _________________________________________________________________________________________________
# # Teste em um NOVO conjunto de dados do mesmo sensor, o Sensor 1

# %% [markdown]
# Carregando Dados Sensor 1

# %%
# Carregar os dados do arquivo
file_path1 = './Dados/sensor_data GY-87_1.1.txt'
df1_1 = pd.read_csv(file_path1, header=None, names=['X', 'Y', 'Z'])
print(len(df1_1))
print(df1_1.head())
# Out:
# 1299898
#           X         Y          Z
# 0 -3.736581 -0.152489  25.189524
# 1 -3.736485 -0.231394  25.326841
# 2 -3.707388 -0.197384  25.064035
# 3 -3.719643 -0.209985  25.205494
# 4 -3.717307 -0.222134  25.306988

# %% [markdown]
# ### Retirando Outliers

# %%
df_cleaned1_1 = remove_outliers_rolling_mad(df1_1, ['X','Y','Z'], window=5000, k=6)
# Exibir as primeiras linhas do DataFrame limpo
print(df_cleaned1_1.head())
df1_1=df_cleaned1_1
# Out:
#              X         Y          Z
# 5000 -3.638407 -0.126549  25.126545
# 5001 -3.683064 -0.222179  25.254637
# 5002 -3.586048 -0.170395  25.262722
# 5003 -3.658927 -0.179215  25.145668
# 5004 -3.649549 -0.200385  25.268583

# %% [markdown]
# Normalizando os dados

# %%
df1_1_scaled = normalizar_eixos_independente(df1_1)[0]

print(df1_1_scaled.head())
# Out:
#           X         Y         Z
# 0  0.191689  0.209085 -0.467601
# 1 -0.027928 -0.216188 -0.189012
# 2  0.449187  0.014098 -0.171427
# 3  0.090774 -0.025125 -0.426010
# 4  0.136897 -0.119268 -0.158679

# %% [markdown]
# Preparando os dados de Teste do Sensor 1

# %%
# Supondo que test_data seja seu DataFrame de teste normalizado
# Convertendo para numpy array
values_test1 = df1_1_scaled.values

# Reformatando os dados para a entrada LSTM
X_test1_1, y_test1_1 = [], []
for i in range(len(values_test1) - n_timesteps):
    X_test1_1.append(values_test1[i:(i + n_timesteps), :])
    y_test1_1.append(values_test1[i + n_timesteps, :])
X_test1_1, y_test1_1 = np.array(X_test1_1), np.array(y_test1_1)

# Agora X_test e y_test estão prontos para serem usados para testar o modelo

# %% [markdown]
# Fazendo a predição

# %%
predicted1_1 = modelo_carregado.predict(X_test1_1)
# Out:
#  4448/40307 ━━━━━━━━━━━━━━━━━━━━ 2:11 4ms/step
# 40307/40307 ━━━━━━━━━━━━━━━━━━━━ 144s 4ms/step

# %% [markdown]
# Plotando os resultados

# %%
# Definindo as dimensões
dims = ['X', 'Y', 'Z']

plt.figure(figsize=(15, 15))

# Criando um gráfico para cada dimensão
for i, dim in enumerate(dims):
    plt.subplot(3, 1, i+1)
    plt.plot(X_test1_1[:, -1, i], label='Real')
    plt.plot(predicted1_1[:, i], label='Previsto')
    plt.title(f'Comparação {dim}')
    plt.xlabel('Tempo')
    plt.ylabel(f'Valor {dim}')
    plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Plotando desnormalizado

# %%
dims = ['X', 'Y', 'Z']

plt.figure(figsize=(15, 15))

for i, dim in enumerate(dims):
    plt.subplot(3, 1, i+1)

    # Desnormalizando os valores reais e previstos
    real_denorm = scalers_tuple[dim].inverse_transform(X_test1_1[:, -1, i].reshape(-1, 1)).flatten()
    pred_denorm = scalers_tuple[dim].inverse_transform(predicted1_1[:, i].reshape(-1, 1)).flatten()

    plt.plot(real_denorm, label='Real')
    plt.plot(pred_denorm, label='Previsto')
    plt.title(f'Comparação {dim}')
    plt.xlabel('Tempo')
    plt.ylabel(f'Valor {dim}')
    plt.legend()
    plt.ylim(-5, 26)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Mean Squared Error e $R^2$ nos novos dados do Sensor 1 ******************

# %%
mse = mean_squared_error(y_test1_1, predicted1_1)
r2 = r2_score(y_test1_1, predicted1_1)

MSE_R2 = {
    "MSE: ":mse,
    "R2: ": r2
}
# Salvar os hiperparâmetros em um arquivo JSON
model_folder = "models_GY87"
config_path = os.path.join(model_folder, "2.Mean Squared Error e R2.NewData.json")
with open(config_path, "w") as f:
    json.dump(MSE_R2, f, indent=4)

print(f"Hiperparâmetros salvos em {config_path}")

print("MSE:", mse)
print("R²:", r2)
# Out:
# Hiperparâmetros salvos em models_GY87/2.Mean Squared Error e R2.NewData.json
# MSE: 0.07376913655645995
# R²: -0.5604870958945944
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# # Estabilizando os dados estaticos (POC)

# %%
# Suponha que df_novos_dados seja o DataFrame com os novos dados do sensor
# e que o modelo já tenha sido carregado e esteja pronto para uso
# Carregar os novos dados do sensor
file_path = './Dados/sensor_data GY-87_3.txt'  # Substitua pelo caminho correto do arquivo
# file_path = './Dados/sensor_data GY-87_1.1.txt'  # Substitua pelo caminho correto do arquivo

df_novos_dados = pd.read_csv(file_path, header=None, names=['X', 'Y', 'Z'])

df_novos_dados_cleaned = remove_outliers_rolling_mad(df_novos_dados, ['X', 'Y', 'Z'], window=5000, k=6)
# Normalizar os novos dados
df_novos_dados_scaled = pd.DataFrame(normalizar_eixos_independente(df_novos_dados_cleaned)[0], columns=df_novos_dados_cleaned.columns)

# Preparar os dados para o modelo
values_novos_dados = df_novos_dados_scaled.values
X_novos_dados = []
for i in range(len(values_novos_dados) - n_timesteps):
    X_novos_dados.append(values_novos_dados[i:(i + n_timesteps)])
X_novos_dados = np.array(X_novos_dados)

# Fazer previsões com o modelo para cada sequência
predicted_novos_dados = modelo_carregado.predict(X_novos_dados)

# %%
# Plotar comparações entre os dados originais e preditos para cada eixo
def plot_comparacao_original_predito(values_novos_dados, predicted_novos_dados, n_timesteps):
    valores_originais = values_novos_dados[n_timesteps:]  # alinhar com predição

    plt.figure(figsize=(15, 10))

    # Eixo X
    plt.subplot(3, 1, 1)
    plt.plot(valores_originais[:, 0], label='Original X', color='darkblue', alpha=0.7)
    plt.plot(predicted_novos_dados[:, 0], label='Predito X', color='darkorange', alpha=0.7, linestyle='--')
    plt.title('Comparação dos Dados - Eixo X')
    plt.ylabel('X')
    plt.legend()

    # Eixo Y
    plt.subplot(3, 1, 2)
    plt.plot(valores_originais[:, 1], label='Original Y', color='darkblue', alpha=0.7)
    plt.plot(predicted_novos_dados[:, 1], label='Predito Y', color='darkorange', alpha=0.7, linestyle='--')
    plt.title('Comparação dos Dados - Eixo Y')
    plt.ylabel('Y')
    plt.legend()

    # Eixo Z
    plt.subplot(3, 1, 3)
    plt.plot(valores_originais[:, 2], label='Original Z', color='darkblue', alpha=0.7)
    plt.plot(predicted_novos_dados[:, 2], label='Predito Z', color='darkorange', alpha=0.7, linestyle='--')
    plt.title('Comparação dos Dados - Eixo Z')
    plt.ylabel('Z')
    plt.legend()

    plt.tight_layout()
    plt.show()

plot_comparacao_original_predito(values_novos_dados, predicted_novos_dados, n_timesteps)

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# ==============================================
# BLOCO: Aplicar Filtro de Kalman sobre X_test
# ==============================================

class KalmanFilter:
    def __init__(self, D, M, Sigma_d, Sigma_m, x_0, Sigma_0):
        self.D = D
        self.M = M
        self.Sigma_d = Sigma_d
        self.Sigma_m = Sigma_m
        self.x = x_0
        self.Sigma = Sigma_0

    def update(self, y):
        # Predição
        x_pred = self.D @ self.x
        Sigma_pred = self.Sigma_d + self.D @ self.Sigma @ self.D.T

        # Correção
        K = Sigma_pred @ self.M.T @ np.linalg.inv(self.M @ Sigma_pred @ self.M.T + self.Sigma_m)
        self.x = x_pred + K @ (y - self.M @ x_pred)
        self.Sigma = (np.identity(self.D.shape[0]) - K @ self.M) @ Sigma_pred
        return self.x[0]

# ==============================================
# Inicializa os filtros de Kalman
# ==============================================

D = np.identity(1)
M = np.identity(1)
x_0 = np.array([0.0])
Sigma_0 = np.array([[1.0]])

Sigma_d_val = 1.0   # variância do processo 0.1
Sigma_m_val = 80.0  # variância da medição 10

kf_x = KalmanFilter(D, M, Sigma_d_val, Sigma_m_val, x_0, Sigma_0)
kf_y = KalmanFilter(D, M, Sigma_d_val, Sigma_m_val, x_0, Sigma_0)
kf_z = KalmanFilter(D, M, Sigma_d_val, Sigma_m_val, x_0, Sigma_0)

# ==============================================
# Aplicar filtro aos dados reais de teste
# ==============================================
# JanelaDados = X_test[10000:]  # Ajustando a faixa de dados para melhor visualização
real = X_test [:, -1, :]  # últimas amostras de cada janela
filtered_x, filtered_y, filtered_z = [], [], []

for i in range(real.shape[0]):
    filtered_x.append(kf_x.update(real[i, 0]))
    filtered_y.append(kf_y.update(real[i, 1]))
    filtered_z.append(kf_z.update(real[i, 2]))

filtered = np.stack([filtered_x, filtered_y, filtered_z], axis=1)

# ==============================================
# Predições da LSTM
# ==============================================

predicted = modelo_carregado.predict(X_test)

# ==============================================
# Desnormalizar todos os conjuntos
# ==============================================

real_denorm, pred_denorm, kalman_denorm = {}, {}, {}

for i, dim in enumerate(['X', 'Y', 'Z']):
    real_denorm[dim] = scalers_tuple[dim].inverse_transform(real[:, i].reshape(-1, 1)).flatten()
    pred_denorm[dim] = scalers_tuple[dim].inverse_transform(predicted[:, i].reshape(-1, 1)).flatten()
    kalman_denorm[dim] = scalers_tuple[dim].inverse_transform(np.array(filtered[:, i]).reshape(-1, 1)).flatten()

# ==============================================
# Cálculo das métricas
# ==============================================

print("\n=== Métricas Quantitativas (LSTM vs Kalman) ===\n")
metrics_table = []

for dim in ['X', 'Y', 'Z']:
    mae_lstm = mean_absolute_error(real_denorm[dim], pred_denorm[dim])
    rmse_lstm = np.sqrt(mean_squared_error(real_denorm[dim], pred_denorm[dim]))
    r2_lstm = r2_score(real_denorm[dim], pred_denorm[dim])

    mae_kalman = mean_absolute_error(real_denorm[dim], kalman_denorm[dim])
    rmse_kalman = np.sqrt(mean_squared_error(real_denorm[dim], kalman_denorm[dim]))
    r2_kalman = r2_score(real_denorm[dim], kalman_denorm[dim])

    metrics_table.append({
        "Eixo": dim,
        "MAE_LSTM": mae_lstm,
        "RMSE_LSTM": rmse_lstm,
        "R2_LSTM": r2_lstm,
        "MAE_Kalman": mae_kalman,
        "RMSE_Kalman": rmse_kalman,
        "R2_Kalman": r2_kalman
    })

    print(f"{dim} → LSTM: MAE={mae_lstm:.4f}, RMSE={rmse_lstm:.4f}, R²={r2_lstm:.4f}")
    print(f"{dim} → Kalman: MAE={mae_kalman:.4f}, RMSE={rmse_kalman:.4f}, R²={r2_kalman:.4f}\n")

# ==============================================
# Plot comparativo
# ==============================================

dims = ['X', 'Y', 'Z']
plt.figure(figsize=(15, 15))

for i, dim in enumerate(dims):
    plt.subplot(3, 1, i+1)
    plt.plot(real_denorm[dim], label='Real', color='black', linewidth=1.5)
    plt.plot(pred_denorm[dim], label='LSTM', color='orange', linestyle='--')
    plt.plot(kalman_denorm[dim], label='Kalman', color='blue', linestyle=':')
    plt.title(f'Comparação {dim} (Real x LSTM x Kalman)')
    plt.xlabel('Tempo')
    plt.ylabel(f'Valor {dim}')
    plt.legend()

plt.tight_layout()
plt.show()

# ==============================================
# Resultado em DataFrame (opcional)
# ==============================================

import pandas as pd
df_metrics = pd.DataFrame(metrics_table)
display(df_metrics)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[40], line 38
#      36 # Plot: uma figura por fator, com 3 subplots (X,Y,Z)
#      37 for fator_correcao in fatores:
# ---> 38     dados_corrigidos = values_novos_dados - df_pred.values * fator_correcao
#      39     df_corrigido = pd.DataFrame(dados_corrigidos, columns=eixos)
#      41     # Calcular métricas e guardar
#
# ValueError: operands could not be broadcast together with shapes (1289940,3) (1289860,3)

# %%
print("Iniciando simulação (Cumulativa de Erro de Variação)")

fator_correcao = 0.2

# Alinhar os dados
min_len = min(len(predicted_novos_dados), len(values_novos_dados[n_timesteps:]))
original_base = values_novos_dados[n_timesteps:][:min_len]
predicted_base = predicted_novos_dados[:min_len]

# Inicializar o array de resultados
dados_corrigidos_logica2 = np.zeros_like(original_base)

# Ponto de partida: O primeiro valor corrigido é o primeiro valor original
dados_corrigidos_logica2[0] = original_base[0]

# Loop de simulação
for i in range(1, len(original_base)):
    # Variação (delta) do sinal original no último passo
    delta_original = original_base[i] - original_base[i-1]
    
    # Variação (delta) do sinal predito no último passo
    delta_predito = predicted_base[i] - predicted_base[i-1]
    
    # O erro na variação é a diferença entre os deltas
    erro_de_variacao = delta_original - delta_predito * fator_correcao
    
    # O novo valor corrigido é o anterior mais o erro de variação
    dados_corrigidos_logica2[i] = dados_corrigidos_logica2[i-1] + erro_de_variacao

# --- Preparar para plotagem ---
dados_finais_para_plotar = np.full_like(values_novos_dados, np.nan)
inicio_plot = n_timesteps
fim_plot = inicio_plot + len(dados_corrigidos_logica2)
dados_finais_para_plotar[inicio_plot:fim_plot, :] = dados_corrigidos_logica2

df_original_full = pd.DataFrame(values_novos_dados, columns=['X', 'Y', 'Z'])
df_corrigido_simulado = pd.DataFrame(dados_finais_para_plotar, columns=['X', 'Y', 'Z'])

# --- PLOTAGEM ---
plt.figure(figsize=(20, 12))
# ... (código de plotagem idêntico ao anterior) ...
for i, eixo in enumerate(['X', 'Y', 'Z']):
    plt.subplot(3, 1, i + 1)
    plt.plot(df_original_full.index, df_original_full[eixo], label=f'Original {eixo}', alpha=0.7, color='darkblue')
    plt.plot(df_corrigido_simulado.index, df_corrigido_simulado[eixo], label=f'Corrigido {eixo}', linestyle='-', alpha=0.7, color='darkorange', linewidth=1.5)
    plt.title(f'Resultado - Eixo {eixo}', fontsize=14)
    plt.ylabel(eixo)
    plt.ylim(-1, 1)
    plt.legend()
    plt.grid(True, linestyle='--', alpha=0.6)
    plt.xlim(0, len(df_original_full))
plt.suptitle('Análise Cumulativa de Erro de Variação (Delta)', fontsize=18, y=0.95)
plt.tight_layout(rect=[0, 0.03, 1, 0.93])
plt.show()
# Out:
# Iniciando simulação (Cumulativa de Erro de Variação)

# %% [markdown]
# # _________________________________________________________________________________________________
# # Teste em um conjunto de dados do Sensor 2

# %% [markdown]
# Carregando Dados Sensor 2

# %%
# Carregar os dados do arquivo
file_path2 = './Dados/sensor_data GY-87_2.txt'
df2 = pd.read_csv(file_path2, header=None, names=['X', 'Y', 'Z'])
print(len(df2))
print(df2.head())
# Out:
# 445846
#            X          Y           Z
# 0  -2.637427   1.013351   64.970947
# 1  -7.161852  14.286690  216.706161
# 2  -4.434565  16.858095  277.176514
# 3   7.768209  30.107044  299.119263
# 4  12.414790  30.107452  302.826050

# %% [markdown]
# #### Retirando Outliers

# %%
# se k menor = mais agressivo
df2_cleaned = remove_outliers_rolling_mad(df2, ['X','Y','Z'], window=5000, k=6)
# Exibir as primeiras linhas do DataFrame limpo
print(df2_cleaned.head())
df2=df2_cleaned
# Out:
#              X         Y          Z
# 5000 -2.895964 -0.777294  22.608480
# 5001 -2.891136 -0.752049  22.763153
# 5002 -2.855855 -0.770969  22.574169
# 5003 -2.895225 -0.870218  22.601610
# 5004 -2.830539 -0.810251  22.744089

# %% [markdown]
# Normalizando os dados

# %%
df2_scaled = pd.DataFrame(normalizar_eixos_independente(df2_cleaned)[0], columns=df2_cleaned.columns)

print(df2_scaled.head())
# Out:
#           X         Y         Z
# 0 -0.094647  0.292811  0.243418
# 1 -0.062230  0.440948  0.668018
# 2  0.174651  0.329926  0.149228
# 3 -0.089683 -0.252472  0.224558
# 4  0.344623  0.099418  0.615685

# %% [markdown]
# Preparando os dados de Teste do Sensor 2

# %%
# Supondo que test_data seja seu DataFrame de teste normalizado
# Convertendo para numpy array
values_test2 = df2_scaled.values

# Reformatando os dados para a entrada LSTM
X_test2, y_test2 = [], []
for i in range(len(values_test2) - n_timesteps):
    X_test2.append(values_test2[i:(i + n_timesteps), :])
    y_test2.append(values_test2[i + n_timesteps, :])
X_test2, y_test2 = np.array(X_test2), np.array(y_test2)

# Agora X_test e y_test estão prontos para serem usados para testar o modelo

# %% [markdown]
# Fazendo a predição

# %%
predicted2 = modelo_carregado.predict(X_test2)
# Out:
# 13618/13618 ━━━━━━━━━━━━━━━━━━━━ 60s 4ms/step

# %% [markdown]
# Plotando os resultados

# %%
# Definindo as dimensões
dims = ['X', 'Y', 'Z']

plt.figure(figsize=(15, 15))

# Criando um gráfico para cada dimensão
for i, dim in enumerate(dims):
    plt.subplot(3, 1, i+1)
    plt.plot(X_test2[:, -1, i], label='Real')
    plt.plot(predicted2[:, i], label='Previsto')
    plt.title(f'Comparação {dim}')
    plt.xlabel('Tempo')
    plt.ylabel(f'Valor {dim}')
    plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Plotando desnormalizado

# %%
dims = ['X', 'Y', 'Z']

plt.figure(figsize=(15, 15))

for i, dim in enumerate(dims):
    plt.subplot(3, 1, i+1)

    # Desnormalizando os valores reais e previstos
    real_denorm = scalers_tuple[dim].inverse_transform(X_test2[:, -1, i].reshape(-1, 1)).flatten()
    pred_denorm = scalers_tuple[dim].inverse_transform(predicted2[:, i].reshape(-1, 1)).flatten()

    plt.plot(real_denorm, label='Real')
    plt.plot(pred_denorm, label='Previsto')
    plt.title(f'Comparação {dim}')
    plt.xlabel('Tempo')
    plt.ylabel(f'Valor {dim}')
    plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Mean Squared Error e $R^2$ no Sensor 2

# %%
mse = mean_squared_error(y_test2, predicted2)
r2 = r2_score(y_test2, predicted2)

MSE_R2 = {
    "MSE: ":mse,
    "R2: ": r2
}
# Salvar os hiperparâmetros em um arquivo JSON
model_folder = "models_GY87"
config_path = os.path.join(model_folder, "3.Mean Squared Error e R2.Sensor2.json")
with open(config_path, "w") as f:
    json.dump(MSE_R2, f, indent=4)

print(f"Hiperparâmetros salvos em {config_path}")

print("MSE:", mse)
print("R²:", r2)
# Out:
# Hiperparâmetros salvos em models_GY87/3.Mean Squared Error e R2.Sensor2.json
# MSE: 0.10273073041782872
# R²: -0.7908736896374116

# %% [markdown]
# # ________________________________________________________________________________________________
# # Teste em um conjunto de dados do Sensor 3

# %% [markdown]
# Carregando Dados Sensor 2

# %%
# Carregar os dados do arquivo
file_path3 = './Dados/sensor_data GY-87_3.txt'
df3 = pd.read_csv(file_path3, header=None, names=['X', 'Y', 'Z'])
print(len(df3))
print(df3.head())
# Out:
# 1300000
#           X         Y          Z
# 0 -0.782148 -0.559195   8.820220
# 1 -2.359465 -0.160205  30.010538
# 2 -2.360485 -1.969254  38.947186
# 3 -2.123916 -2.056271  42.387650
# 4 -2.195343 -2.090273  43.794254

# %% [markdown]
# ### Retirando Outliers

# %%
# se k menor = mais agressivo
df3_cleaned = remove_outliers_rolling_mad(df3, ['X','Y','Z'], window=5000, k=6)
# Exibir as primeiras linhas do DataFrame limpo
print(df3_cleaned.head())
df3=df3_cleaned
# Out:
#              X         Y          Z
# 5000 -2.228961 -2.154576  44.995651
# 5001 -2.242494 -2.226608  44.633247
# 5002 -2.244047 -2.235712  44.824234
# 5003 -2.196619 -2.185066  44.915642
# 5004 -2.206492 -2.162731  44.617508

# %% [markdown]
# Normalizando os dados

# %%
df3_scaled = pd.DataFrame(normalizar_eixos_independente(df3)[0], columns=df3.columns)

print(df3_scaled.head())
# Out:
#           X         Y         Z
# 0 -0.077154  0.261425  0.430500
# 1 -0.161304 -0.075164  0.082496
# 2 -0.170960 -0.117705  0.265894
# 3  0.123950  0.118954  0.353670
# 4  0.062556  0.223320  0.067381
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# Preparando os dados de Teste do Sensor 3

# %%
# Supondo que test_data seja seu DataFrame de teste normalizado
# Convertendo para numpy array
values_test3 = df3_scaled.values

# Reformatando os dados para a entrada LSTM
X_test3, y_test3 = [], []
for i in range(len(values_test3) - n_timesteps):
    X_test3.append(values_test3[i:(i + n_timesteps), :])
    y_test3.append(values_test3[i + n_timesteps, :])
X_test3, y_test3 = np.array(X_test3), np.array(y_test3)

# Agora X_test e y_test estão prontos para serem usados para testar o modelo

# %% [markdown]
# Fazendo a predição

# %%
predicted3 = modelo_carregado.predict(X_test3)

# %% [markdown]
# Plotando os resultados

# %%
# Definindo as dimensões
dims = ['X', 'Y', 'Z']

plt.figure(figsize=(15, 15))

# Criando um gráfico para cada dimensão
for i, dim in enumerate(dims):
    plt.subplot(3, 1, i+1)
    plt.plot(X_test3[:, -1, i], label='Real')
    plt.plot(predicted3[:, i], label='Previsto')
    plt.title(f'Comparação {dim}')
    plt.xlabel('Tempo')
    plt.ylabel(f'Valor {dim}')
    plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Plotando desnormalizado

# %%
dims = ['X', 'Y', 'Z']

plt.figure(figsize=(15, 15))

for i, dim in enumerate(dims):
    plt.subplot(3, 1, i+1)

    # Desnormalizando os valores reais e previstos
    real_denorm = scalers_tuple[dim].inverse_transform(X_test3[:, -1, i].reshape(-1, 1)).flatten()
    pred_denorm = scalers_tuple[dim].inverse_transform(predicted3[:, i].reshape(-1, 1)).flatten()

    plt.plot(real_denorm, label='Real')
    plt.plot(pred_denorm, label='Previsto')
    plt.title(f'Comparação {dim}')
    plt.xlabel('Tempo')
    plt.ylabel(f'Valor {dim}')
    plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Mean Squared Error e $R^2$ no Sensor 3

# %%
mse = mean_squared_error(y_test3, predicted3)
r2 = r2_score(y_test3, predicted3)

MSE_R2 = {
    "MSE: ":mse,
    "R2: ": r2
}
# Salvar os hiperparâmetros em um arquivo JSON
model_folder = "models_GY87"
config_path = os.path.join(model_folder, "4.Mean Squared Error e R2.Sensor3.json")
with open(config_path, "w") as f:
    json.dump(MSE_R2, f, indent=4)

print(f"Hiperparâmetros salvos em {config_path}")

print("MSE:", mse)
print("R²:", r2)
