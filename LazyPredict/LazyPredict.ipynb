# %%
# pip install lazypredict

# %%
import lazypredict

# %%
from lazypredict.Supervised import LazyRegressor
from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split
import numpy as np

# Carregando o dataset California Housing
housing = fetch_california_housing()
X = housing.data
y = housing.target

# Dividindo os dados em treino e teste
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=13)

# Aplicando LazyRegressor
reg = LazyRegressor(verbose=0, ignore_warnings=False, custom_metric=None)
models, predictions = reg.fit(X_train, X_test, y_train, y_test)

# Exibindo os modelos e suas métricas
print(models)
# Out:
# 100%|██████████| 42/42 [02:52<00:00,  4.11s/it]
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000443 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1837
# [LightGBM] [Info] Number of data points in the train set: 18576, number of used features: 8
# [LightGBM] [Info] Start training from score 2.065921
#                                Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# XGBRegressor                                 0.83       0.83  0.48        0.18
# LGBMRegressor                                0.83       0.83  0.48        0.13
# HistGradientBoostingRegressor                0.82       0.82  0.49        0.48
# ExtraTreesRegressor                          0.80       0.80  0.51        4.69
# RandomForestRegressor                        0.80       0.80  0.53       14.11
# GradientBoostingRegressor                    0.77       0.77  0.55        3.85
# MLPRegressor                                 0.77       0.77  0.56       14.12
# BaggingRegressor                             0.76       0.76  0.56        1.44
# NuSVR                                        0.72       0.73  0.61       15.14
# SVR                                          0.72       0.72  0.61       12.44
# KNeighborsRegressor                          0.67       0.67  0.67        0.16
# LinearSVR                                    0.59       0.59  0.74        0.82
# HuberRegressor                               0.59       0.59  0.74        0.11
# DecisionTreeRegressor                        0.59       0.59  0.74        0.22
# RidgeCV                                      0.59       0.59  0.74        0.02
# BayesianRidge                                0.59       0.59  0.74        0.02
# Ridge                                        0.59       0.59  0.74        0.01
# Lars                                         0.59       0.59  0.74        0.02
# LassoLarsIC                                  0.59       0.59  0.74        0.02
# TransformedTargetRegressor                   0.59       0.59  0.74        0.02
# LinearRegression                             0.59       0.59  0.74        0.01
# LassoLarsCV                                  0.59       0.59  0.74        0.03
# LarsCV                                       0.59       0.59  0.74        0.04
# ElasticNetCV                                 0.59       0.59  0.74        0.40
# LassoCV                                      0.59       0.59  0.74        0.47
# OrthogonalMatchingPursuitCV                  0.58       0.58  0.75        0.03
# ExtraTreeRegressor                           0.55       0.55  0.78        0.06
# RANSACRegressor                              0.54       0.54  0.79        0.13
# SGDRegressor                                 0.53       0.53  0.80        0.02
# OrthogonalMatchingPursuit                    0.47       0.47  0.84        0.01
# PassiveAggressiveRegressor                   0.44       0.44  0.87        0.02
# PoissonRegressor                             0.44       0.44  0.87        0.02
# TweedieRegressor                             0.38       0.39  0.91        0.02
# GammaRegressor                               0.37       0.37  0.92        0.02
# AdaBoostRegressor                            0.32       0.32  0.96        1.22
# ElasticNet                                   0.20       0.20  1.04        0.01
# Lasso                                       -0.00      -0.00  1.16        0.02
# DummyRegressor                              -0.00      -0.00  1.16        0.01
# LassoLars                                   -0.00      -0.00  1.16        0.01
# QuantileRegressor                           -0.07      -0.07  1.20        7.99
# KernelRidge                                 -2.60      -2.58  2.20       40.53
# GaussianProcessRegressor                 -4708.19   -4689.92 79.63       53.57

# %%
from lazypredict.Supervised import LazyRegressor
from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split

# Carregando o dataset California Housing
housing = fetch_california_housing()
X = housing.data
y = housing.target

# Dividindo os dados em treino e teste
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=13)

# Aplicar LazyRegressor
reg = LazyRegressor(verbose=0, ignore_warnings=False, custom_metric=None)
models, predictions = reg.fit(X_train, X_test, y_train, y_test)

# Exibindo os resultados
print(models)
# Out:
# 100%|██████████| 42/42 [02:27<00:00,  3.52s/it]
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000395 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1837
# [LightGBM] [Info] Number of data points in the train set: 16512, number of used features: 8
# [LightGBM] [Info] Start training from score 2.067396
#                                Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# HistGradientBoostingRegressor                0.83       0.83  0.48        0.32
# LGBMRegressor                                0.83       0.83  0.48        0.11
# XGBRegressor                                 0.83       0.83  0.48        0.18
# ExtraTreesRegressor                          0.80       0.80  0.51        4.19
# RandomForestRegressor                        0.80       0.80  0.52       12.40
# GradientBoostingRegressor                    0.78       0.78  0.55        3.56
# MLPRegressor                                 0.78       0.78  0.55       10.76
# BaggingRegressor                             0.77       0.78  0.55        1.28
# NuSVR                                        0.73       0.73  0.60       14.03
# SVR                                          0.73       0.73  0.60       13.17
# KNeighborsRegressor                          0.67       0.67  0.66        0.27
# DecisionTreeRegressor                        0.62       0.62  0.72        0.19
# LinearRegression                             0.60       0.60  0.73        0.01
# Lars                                         0.60       0.60  0.73        0.01
# LassoLarsIC                                  0.60       0.60  0.73        0.02
# TransformedTargetRegressor                   0.60       0.60  0.73        0.02
# Ridge                                        0.60       0.60  0.73        0.01
# BayesianRidge                                0.60       0.60  0.73        0.02
# RidgeCV                                      0.60       0.60  0.73        0.02
# ElasticNetCV                                 0.60       0.60  0.73        0.32
# LassoCV                                      0.60       0.60  0.73        0.37
# LassoLarsCV                                  0.60       0.60  0.73        0.03
# LarsCV                                       0.60       0.60  0.73        0.03
# HuberRegressor                               0.60       0.60  0.73        0.09
# LinearSVR                                    0.60       0.60  0.74        0.72
# OrthogonalMatchingPursuitCV                  0.60       0.60  0.74        0.03
# SGDRegressor                                 0.58       0.58  0.75        0.02
# ExtraTreeRegressor                           0.54       0.54  0.79        0.05
# OrthogonalMatchingPursuit                    0.48       0.48  0.84        0.01
# PoissonRegressor                             0.45       0.45  0.86        0.02
# TweedieRegressor                             0.39       0.40  0.90        0.02
# PassiveAggressiveRegressor                   0.39       0.39  0.91        0.02
# GammaRegressor                               0.38       0.38  0.91        0.02
# AdaBoostRegressor                            0.37       0.37  0.92        1.22
# RANSACRegressor                              0.33       0.33  0.95        0.12
# ElasticNet                                   0.21       0.21  1.03        0.01
# Lasso                                       -0.00      -0.00  1.16        0.01
# DummyRegressor                              -0.00      -0.00  1.16        0.01
# LassoLars                                   -0.00      -0.00  1.16        0.01
# QuantileRegressor                           -0.06      -0.06  1.19        6.53
# KernelRidge                                 -2.54      -2.53  2.18       35.54
# GaussianProcessRegressor                 -4004.92   -3997.15 73.40       42.13
